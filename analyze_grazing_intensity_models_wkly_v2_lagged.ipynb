# %%
import os
import re
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from sklearn.preprocessing import StandardScaler
from matplotlib.ticker import FormatStrFormatter, MultipleLocator
from matplotlib import ticker
from scipy.stats import ttest_1samp
import statsmodels.stats.api as sms
import pickle
#%config Completer.use_jedi = False
#%matplotlib widget

# %%
"""
Define I/O paths
"""
# input directores
inDIR_data = '/mnt/c/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/data/'
inDIR_mods = '/mnt/c/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/models/'

# output directories
outDIR_tables = '/mnt/c/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/models/results_tables/'

# file name of gridded path intensity data (output from gps_to_gridded_path_intensity.ipynb)
griddata_f = 'full_grazing_time_gridded_all_for_model.csv'

# file name of model results
results_f = 'full_grazing_intensity_model_results.csv'

# file name of model coefficients
coefs_f = 'full_grazing_intensity_model_coefficients.csv'

# %%
"""
Define models for analyzing
"""
# create list of saved models
#mod_list = ['M0', 'M1', 'M2_bm', 'M2_top', 'M3_pc', 'M3_top', 'M4_top', 'M_best']
mod_list = ['M2_top', 'M3_top', 'M4_top', 'M_best']

# create dictionary to map top models to original models
top_mod_dict = {
    'M2_top': 'M2g',
    'M3_top': 'M3d',
    'M4_top': 'M4h',
    'M5_top': 'M5'
}

# create dictionaries of saved model results for AIC comparison
mod_aic_dict = {
    'TPC2': [top_mod_dict['M2_top'], 'M2_tpc'],
    'TPC3': [top_mod_dict['M3_top'], 'M3_tpc'],
    'TPC4': [top_mod_dict['M4_top'], top_mod_dict['M5_top']],
    'Hw1': ['M1', 'M5'],
    'Hw2': ['M2a', 'M2b', 'M2c', 'M2d', 'M2e', 'M2f', 'M2g'],
    'Hw3': ['M2a', 'M2b', 'M2c', 'M2d', 'M2e', 'M2f', 'M2g'],
    'Hw4a': ['M2a', 'M2b'],
    'Hw4b': ['M2f', 'M2g'],
    'Hw5': ['M2a', 'M2b', 'M2c', 'M2d', 'M2e', 'M2f', 'M2g'],
    'Hw6': ['M2a', 'M2b', 'M2c', 'M2d', 'M2e', 'M2f', 'M2g'],
    'Hw7': ['M3a', 'M3b', 'M3c', 'M3d'],
    'Hw8': ['M3a', 'M3b', 'M3c', 'M3d'],
    'Hw9': ['M3a', 'M3b', 'M3c', 'M3d'],
    'Ha1': ['M0', 'M1', 'M2', 'M3'],
    'Ha2': ['M0', 'M1', 'M2', 'M3', 'M4'],
    'Ha3': ['M0', 'M1', 'M2', 'M3', 'M4'],
    'Ha4': ['M0', 'M1', 'M2', 'M3', 'M4'],
}

# create dictionaries of saved scalers
scaler_dict = {}
for yr in [2016, 2017, 2018]:
    scaler_dict[yr] = {}
    for seas in ['early', 'mid', 'late']:
        scaler_dict[yr][seas] = {}
        for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
            with open(os.path.join(inDIR_mods, 'scaler_' + str(yr) + '_' + seas + '_' + c + '.pkl'), 'rb') as f:
                scaler_dict[yr][seas][c] = pickle.load(f)

# %%
"""
Define helper functions
"""
def abline(slope, intercept, color='black', linewidth=None):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '-', c=color, linewidth=linewidth)

def season_func(wk):
    if wk <= 26:
        return 'early'
    elif wk <= 32:
        return 'mid'
    elif wk >= 33:
        return 'late'

# %%
"""
Load data and models
"""
# read gridded data into dataframe
df_wkly_grid_full = pd.read_csv(os.path.join(inDIR_data, griddata_f), engine='python')

# read model results into dataframe
df_results = pd.read_csv(os.path.join(inDIR_mods, results_f), engine='python')

# read model results into dataframe
df_coefs = pd.read_csv(os.path.join(inDIR_mods, coefs_f), engine='python')

# create dictionary of the yearly models
yrly_mod_dict = {}
for yr in tqdm(df_coefs['Year'].unique()):
    yrly_mod_dict[yr] = {}
    for wk in df_coefs[df_coefs['Year'] == yr]['week'].unique():
        yrly_mod_dict[yr][wk] = {}
        for past in df_coefs[(df_coefs['Year'] == yr) &
                             (df_coefs['week'] == wk)]['Pasture'].unique():
            yrly_mod_dict[yr][wk][past] = {}
            for mod in mod_list:
                f_matched = [f for f in os.listdir(os.path.join(inDIR_mods, 'wkly')) if mod in f and '_' + str(wk) + '_' in f and str(yr) in f and past in f]
                if len(f_matched) == 1:
                    yrly_mod_dict[yr][wk][past][mod] = sm.load(os.path.join(
                        inDIR_mods, 'wkly', f_matched[0]))
                else:
                    print('ERROR: None and/or multiple matching files found:')
                    display(f_matched)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [raw]
# # create dictionary of the seasonal models
# seas_mod_dict = {}
# for seas in df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'train']['season'].unique():
#     seas_mod_dict[seas] = {}
#     for mod in mod_list:
#         f_matched = [f for f in os.listdir(os.path.join(inDIR_mods, 'seas')) if mod in f and seas in f]
#         if len(f_matched) == 1:
#             seas_mod_dict[seas][mod] = sm.load(os.path.join(
#                 inDIR_mods, 'seas', f_matched[0]))
#         else:
#             print('ERROR: None and/or multiple matching files found:')
#             display(f_matched)
#
# # create dictionary of the pasture-specific models
# past_mod_dict = {}
# for past in df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'train']['Pasture'].unique():
#     past_mod_dict[past] = {}
#     for seas in df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'train']['season'].unique():
#         past_mod_dict[past][seas] = {}
#         for mod in mod_list:
#             f_matched = [f for f in os.listdir(os.path.join(inDIR_mods, 'past')) if past in f and mod in f and seas in f]
#             if len(f_matched) == 1:
#                 past_mod_dict[past][seas][mod] = sm.load(os.path.join(
#                     inDIR_mods, 'past', f_matched[0]))
#             else:
#                 print('ERROR: None and/or multiple matching files found:')
#                 display(f_matched)

# %%
"""
Predict grazing intensity for chosen model
"""
# Change rare classes to 'Other' to match training data
df_wkly_grid_full['PC_dmt'].replace({'Bare_veg': 'Other', 'Bare': 'Other', 'UNK': 'Other', 'Shrub': 'Other'}, 
                               inplace=True)

# set the model for prediction
#mod_list = ['M_best']

min_class_n = 10


# predict relative probability of grazing across all data from seasonal models
for mod in mod_list:
    print('------ ' + mod + ' ------')
    for yr in tqdm(yrly_mod_dict):
        for wk in yrly_mod_dict[yr]:
            for past in yrly_mod_dict[yr][wk]:
                
                # get data from previous weeks for calculating grazing lag
                data_lag = df_wkly_grid_full[(df_wkly_grid_full['Year'] == yr) &
                                        (df_wkly_grid_full['Pasture'] == past) & 
                                        (df_wkly_grid_full['week'] >= wk - 6) &
                                        (df_wkly_grid_full['week'] < wk)]
                if len(data_lag) == 0:
                    print('Skipping ', yr, past, wk, ' due to lack of lagged data')
                    continue
                else:
                    # create average lagged grazing secs               
                    df_sub = df_wkly_grid_full.loc[(df_wkly_grid_full['Year'] == yr) &
                                                   (df_wkly_grid_full['week'] == wk) &
                                                   (df_wkly_grid_full['Pasture'] == past), :]
                    df_sub = df_sub.set_index(['UTM_X', 'UTM_Y', 'Pasture'])
                    df_sub['lag_avg'] = data_lag.groupby(['UTM_X', 'UTM_Y', 'Pasture'])['grazing_secs'].mean().reindex(df_sub.index)
                    df_sub = df_sub.reset_index()
                    df_sub.set_index('Unnamed: 0')
                
                    pc_drop_list = df_sub['PC_dmt'].value_counts().index[
                        df_sub['PC_dmt'].value_counts() < min_class_n]
                    tpc_drop_list = df_sub['TPC_c'].value_counts().index[
                        df_sub['TPC_c'].value_counts() < min_class_n]
                    
                    df_sub = df_sub[~df_sub['PC_dmt'].isin(pc_drop_list)]
                    df_sub = df_sub[~df_sub['TPC_c'].isin(tpc_drop_list)]
                    
                    df_wkly_grid_full.loc[(df_wkly_grid_full['Year'] == yr) &
                                          (df_wkly_grid_full['week'] == wk) &
                                          (df_wkly_grid_full['Pasture'] == past) &
                                          (~df_wkly_grid_full['PC_dmt'].isin(pc_drop_list)) &
                                          (~df_wkly_grid_full['TPC_c'].isin(tpc_drop_list)), 
                                          'pred_prop_' + mod] = yrly_mod_dict[yr][wk][past][mod].predict(df_sub).values

for mod in mod_list:                
    df_wkly_grid_full['pred_rel_freq_' + mod] = df_wkly_grid_full[
        'pred_prop_' + mod] * df_wkly_grid_full['grazing_wkly_sum'] / (df_wkly_grid_full['grazing_wkly_sum'] / 
                                                                       df_wkly_grid_full.groupby(
                                                                           ['Pasture', 
                                                                            'Year',
                                                                            'week',
                                                                            'Pasture',
                                                                            'mod_data'])['grazing_secs'].transform('count'))
# Out:
# ------ M2_top ------
#   0%|          | 0/3 [00:00<?, ?it/s]
# ------ M3_top ------
#   0%|          | 0/3 [00:00<?, ?it/s]
# ------ M4_top ------
#   0%|          | 0/3 [00:00<?, ?it/s]
# ------ M_best ------
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
test = df_wkly_grid_full.loc[(df_wkly_grid_full['Year'] == 2016) &
                      (df_wkly_grid_full['week'] == 20) &
                      (df_wkly_grid_full['Pasture'] == '26E'), :]
test[test['pred_prop_M4_top'].isnull()]['PC_dmt']#.sum()
#test['grazing_secs'].isnull().sum()
#test[test['PC_dmt'] == 'C3']
test.loc[253887]
test['TPC_c'].value_counts()
# Out:
# Flat Plains    799
# Open Slopes    242
# Lowlands       164
# Highlands       87
# Other            1
# Name: TPC_c, dtype: int64

# %%
#df_wkly_grid_full['pred_rel_freq_M_best'].describe().round(2)
for mod in mod_list:
    df_wkly_grid_full.loc[df_wkly_grid_full['pred_rel_freq_' + mod] > 10.0, 
                          'pred_rel_freq_' + mod] = 10.0
    # * df_wkly_grid_full['grazing_wkly_sum'] / (df_wkly_grid_full['grazing_wkly_sum'] / 
                                                                             #df_wkly_grid_full.groupby(
                                                                              #  ['Pasture', 'mod_data'])['grazing_secs'].transform('count'))

# %%
#df_wkly_grid_full['pred_rel_freq_M_best'].describe().round(2)

# %%
"""
Bin seasonal predictions for categorical plotting and mapping
"""
rel_freq_bins = [0.0, 0.6, 0.8, 1.2, 1.4, 10.0]
bin_labs = ['Low', 'Mod. Low', 'Avg.', 'Mod. Hi', 'Hi']
df_wkly_grid_full['grazing_grp'] = pd.cut(df_wkly_grid_full['grazing_rel_freq'], 
                                          bins=rel_freq_bins, 
                                          labels=bin_labs,
                                          include_lowest=True)
for mod in mod_list:
    df_wkly_grid_full['pred_grp_' + mod] = pd.cut(df_wkly_grid_full['pred_rel_freq_' + mod],
                                                  bins=rel_freq_bins, 
                                                  labels=bin_labs,
                                                  include_lowest=True)

# %%
"""
Create and organize subsets of gridded data for plotting and analyses
"""
df_wkly_grid_full['season'] = pd.Categorical(df_wkly_grid_full['season_str'], ['early', 'mid', 'late'])
df_wkly_grid_train = df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'train']
df_wkly_grid_test = df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'test']

# %%
#df_wkly_grid_train[df_wkly_grid_train['pred_seas'] == 10]['pred_seas_grp'].value_counts()

# %%
df_wkly_grid_train_long = pd.wide_to_long(df_wkly_grid_train, stubnames='pred_grp', 
                i='Unnamed: 0',
                j='mod_pred_grp', sep='_', suffix='.*').reset_index()
df_wkly_grid_train_long['pred_grp'] = pd.Categorical(df_wkly_grid_train_long['pred_grp'], categories=['Low', 'Mod. Low', 'Avg.', 'Mod. Hi', 'Hi'])
df_wkly_grid_train_long['mod_pred_grp'].unique()
# Out:
# array(['M2_top', 'M3_top', 'M4_top', 'M_best'], dtype=object)

# %%
"""
Plot overall observed versus predicted relative grazing intensity for best model
"""
fig, ax = plt.subplots(figsize=(10, 6))
sns.pointplot(x='pred_grp', y='grazing_rel_freq', hue='mod_pred_grp', palette=sns.color_palette('deep'),
              data=df_wkly_grid_train_long, ax=ax, 
              errorbar=('ci', 95), n_boot=500, color='green', capsize=0.1, join=True)
#sns.pointplot(x='pred_grp_M3_top', y='grazing_rel_freq',
#              data=df_wkly_grid_train, ax=ax, 
#              ci=95, n_boot=500, color='orange', capsize=0.1, join=True)
#sns.pointplot(x='pred_grp_M4_top', y='grazing_rel_freq',
#              data=df_wkly_grid_train, ax=ax, 
#              ci=95, n_boot=500, color='purple', capsize=0.1, join=True)
#sns.pointplot(x='pred_grp_M_best', y='grazing_rel_freq',
#              data=df_wkly_grid_train, ax=ax, 
#              ci=95, n_boot=500, color='blue', capsize=0.1, join=True)
ax.axhline(y=1.0, linestyle='dashed', c='gray')
ax.set_xlabel('Predicted relative grazing intensity (binned)',  size=12.0, labelpad=15)
ax.set_ylabel('Observed relative grazing intensity', size=12.0, labelpad=15)
ax.tick_params(axis='y', labelsize=14.0)
ax.set_xticklabels(ax.get_xticklabels(), size=14.0)
#plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/Best_model_fit.png', 
#           bbox_inches='tight', dpi=300)
# Out:
# [Text(0, 0, 'Low'),
#  Text(1, 0, 'Mod. Low'),
#  Text(2, 0, 'Avg.'),
#  Text(3, 0, 'Mod. Hi'),
#  Text(4, 0, 'Hi')]

# %%
"""
Plot seasonal observed versus predicted relative grazing intensity for best model
"""
g = sns.catplot(data=df_wkly_grid_train_long, x='pred_grp', y='grazing_rel_freq', hue='mod_pred_grp', col='season', row='Year', kind='point',
                legend=False, sharey=True, height=2.5, aspect=1.2, margin_titles=True, palette=sns.color_palette('deep'),
                errorbar=('ci', 95), n_boot=500, color='black', capsize=0.1, join=True).add_legend()
g.set(xlabel='',
     ylabel='')
g.fig.supxlabel('Predicted relative grazing intensity (binned)', y=-0.1)
g.fig.supylabel('Observed relative grazing intensity', x=-0.05)
for ax in g.axes.flat:
    ax.axhline(y=1.0, linestyle='dashed', color='black')
    ax.tick_params(axis='y', labelsize=12.0)
    ax.set_xticklabels(ax.get_xticklabels(), size=12.0, rotation=45, horizontalalignment='right')
    plt.setp(ax.texts, text="") # remove the original texts


g.set_axis_labels()
g.set_titles(row_template = '{row_name}', 
             col_template = '{col_name}-season', 
             size=14.0,
             fontweight='bold')
plt.subplots_adjust(hspace=0.2, wspace=0.2)
#plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/Best_model_fit_X_season.png', 
#           bbox_inches='tight', dpi=300, pad_inches=0.25)

# %%
"""
Get DataFrame of coefficients for best models for each season
"""
coefs_dict = {}

for yr in tqdm(yrly_mod_dict):
    coefs_dict[yr] = {}
    for wk in yrly_mod_dict[yr]:
        coefs_dict[yr][wk] = {}
        for past in yrly_mod_dict[yr][wk]:
            coefs_dict[yr][wk][past] = {}
            for mod in yrly_mod_dict[yr][wk][past]:
                coefs_dict[yr][wk][past][mod] = pd.read_html((yrly_mod_dict[yr][wk][past][mod].summary().tables[1]).as_html(), 
                                                         header=0, index_col=0)[0]
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
"""
Reformat and save coefficients for final model for table
"""
for yr in tqdm(coefs_dict):
    for wk in coefs_dict[yr]:
        for past in coefs_dict[yr][wk]:
            for mod in coefs_dict[yr][wk][past]:
                coefs_dict[yr][wk][past][mod] = coefs_dict[yr][wk][past][mod].rename_axis('Param').reset_index()
                coefs_dict[yr][wk][past][mod]['Param'] = coefs_dict[yr][wk][past][mod]['Param'].apply(
                    lambda x: re.sub('\]', 
                                     '',
                                     re.sub('C\(PC_dmt, Treatment\(reference\="C3_C4_mix"\)\)\[T\.', 
                                            '', 
                                            str(x))))
                coefs_dict[yr][wk][past][mod]['Param'] = coefs_dict[yr][wk][past][mod]['Param'].apply(
                    lambda x: re.sub('\]', 
                                     '',
                                     re.sub('C\(TPC_c, Treatment\(reference\="Flat Plains"\)\)\[T\.', 
                                            'TPC:', 
                                            str(x))))
                coefs_dict[yr][wk][past][mod]['Param'] = coefs_dict[yr][wk][past][mod]['Param'].apply(
                    lambda x: re.sub('TPC:', '', re.sub('TPC:Other', 'Complex', x)))
        
idx = 0
for yr in coefs_dict:
    for wk in coefs_dict[yr]:
        for past in coefs_dict[yr][wk]:
            if idx == 0:
                df_coefs_wk = coefs_dict[yr][wk][past]['M_best']
                df_coefs_wk['week'] = wk
                df_coefs_wk['Year'] = yr
                df_coefs_wk['Pasture'] = past
            else:
                df_tmp = coefs_dict[yr][wk][past]['M_best']
                df_tmp['week'] = wk
                df_tmp['Year'] = yr
                df_tmp['Pasture'] = past
                df_coefs_wk = df_coefs_wk.append(df_tmp)
            idx += 1
    #        coefs_dict[yr][wk]['M_best'].to_csv(os.path.join(outDIR_tables, 'M_best_coefs_' + str(yr) + '_' + wk + '.csv'))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
df_coefs_wk['Model'] = 'M_best'
df_coefs_wk['coef_ci_lwr'] = df_coefs_wk['[0.025']
df_coefs_wk['coef_ci_upr'] = df_coefs_wk['0.975]']
df_coefs_wk['Param'] = df_coefs_wk['Param'].apply(
                lambda x: re.sub('\]', 
                                 '',
                                 re.sub('C\(PC_dmt, Treatment\(reference\="C3_C4_mix"\)\)\[T\.', 
                                        '', 
                                        str(x))))

df_coefs_wk['Param'] = df_coefs_wk['Param'].apply(
                lambda x: re.sub('\]', 
                                 '',
                                 re.sub('C\(TPC_c, Treatment\(reference\="Flat Plains"\)\)\[T\.', 
                                        'TPC:', 
                                        str(x))))

df_coefs_wk['Param'] = df_coefs_wk['Param'].apply(
                lambda x: re.sub('TPC:', '', re.sub('TPC:Other', 'Complex', x)))

# %%
df_coefs_wk['season'] = df_coefs_wk['week'].apply(lambda x: season_func(x))
df_coefs_wk['season'] = pd.Categorical(df_coefs_wk['season'], ['early', 'mid', 'late'])

# %%
df_coefs_wk
# Out:
#         Param    coef  std err       z  P>|z|  [0.025  0.975]  week    Year  \
# 0   Intercept -8.3676    0.151 -55.388  0.000  -8.664  -8.071    21  2016.0
# 1          C3  0.2261    0.403   0.561  0.574  -0.563   1.015    21  2016.0
# 2          C4 -0.8025    0.166  -4.838  0.000  -1.128  -0.477    21  2016.0
# 3       Other  0.1219    0.533   0.229  0.819  -0.924   1.168    21  2016.0
# 4   Saltgrass -0.0536    0.151  -0.354  0.723  -0.350   0.243    21  2016.0
# ..        ...     ...      ...     ...    ...     ...     ...   ...     ...
# 0   Intercept -8.0924    0.140 -57.988  0.000  -8.366  -7.819    32  2018.0
# 1     lag_avg  0.0025    0.001   4.518  0.000   0.001   0.004    32  2018.0
# 2      dFence  0.1045    0.074   1.412  0.158  -0.041   0.249    32  2018.0
# 3       dTank -0.6310    0.151  -4.191  0.000  -0.926  -0.336    32  2018.0
# 4       alpha  8.3896    0.364  23.066  0.000   7.677   9.103    32  2018.0
#
#    Pasture   Model  coef_ci_lwr  coef_ci_upr season
# 0      17N  M_best       -8.664       -8.071  early
# 1      17N  M_best       -0.563        1.015  early
# 2      17N  M_best       -1.128       -0.477  early
# 3      17N  M_best       -0.924        1.168  early
# 4      17N  M_best       -0.350        0.243  early
# ..     ...     ...          ...          ...    ...
# 0      7NW  M_best       -8.366       -7.819    mid
# 1      7NW  M_best        0.001        0.004    mid
# 2      7NW  M_best       -0.041        0.249    mid
# 3      7NW  M_best       -0.926       -0.336    mid
# 4      7NW  M_best        7.677        9.103    mid
#
# [2840 rows x 14 columns]

# %%
import numpy as np
import scipy.stats

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

df_coefs_seas = df_coefs_wk.groupby(['Year', 'season', 'Model', 'Param']).agg({'coef': [('coef', lambda x: mean_confidence_interval(x)[0]),
                                                                                   ('coef_ci_lwr', lambda x: mean_confidence_interval(x)[1]),
                                                                                   ('coef_ci_upr', lambda x: mean_confidence_interval(x)[2])]})
df_coefs_seas.columns = df_coefs_seas.columns.droplevel(0)
df_coefs_seas = df_coefs_seas.dropna(axis=0, how='all')
# Out:
# /home/spkearney/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/spkearney/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df_coefs_seas['significant'] = df_coefs_seas.apply(lambda v: 'Yes' if np.sign(v['coef_ci_lwr']) == np.sign(v['coef_ci_upr']) else 'No', axis=1)
df_coefs_seas = df_coefs_seas.sort_values(['Year', 'season']).reset_index()
df_coefs_seas
# Out:
#        Year season   Model               Param      coef  coef_ci_lwr  \
# 0    2016.0  early  M_best             Biomass -0.206005    -0.411384
# 1    2016.0  early  M_best          Biomass:CP  0.071745    -0.243379
# 2    2016.0  early  M_best                  C3 -0.672360    -2.190574
# 3    2016.0  early  M_best          C3:Biomass  0.345000          NaN
# 4    2016.0  early  M_best  C3:I(Biomass ** 2) -0.131300          NaN
# ..      ...    ...     ...                 ...       ...          ...
# 296  2018.0   late  M_best    Saltgrass:PC_div  0.117700          NaN
# 297  2018.0   late  M_best               alpha  8.898005     7.639494
# 298  2018.0   late  M_best              dFence  0.056459    -0.029439
# 299  2018.0   late  M_best               dTank  0.033032    -0.068307
# 300  2018.0   late  M_best             lag_avg  0.000609     0.000360
#
#      coef_ci_upr significant
# 0      -0.000626         Yes
# 1       0.386870          No
# 2       0.845854          No
# 3            NaN          No
# 4            NaN          No
# ..           ...         ...
# 296          NaN          No
# 297    10.156515         Yes
# 298     0.142357          No
# 299     0.134370          No
# 300     0.000859         Yes
#
# [301 rows x 8 columns]

# %%
 
"""df_coefs_wkly = df_coefs.drop(columns='Unnamed: 0').groupby(['Year', 
                                             'Season',
                                             'Model', 
                                             'week', 
                                             'Pasture', 
                                             'Param']).mean().reset_index()
df_coefs_past = df_coefs_wkly.groupby(['Year',
                                       'Season',
                                       'Model',
                                       'Pasture',
                                       'Param']).mean().reset_index().drop(columns='week')"""
"""
df_coefs_seas = df_coefs.drop(columns='Unnamed: 0').groupby(['Year',                                             
                       'season_str',
                       'Model',
                       'Param']).mean().reset_index()#.drop(columns='week')
df_coefs_seas['coef_ci_lwr'] = df_coefs.drop(columns='Unnamed: 0').groupby(['Year',                                             
                       'season_str',
                       'Model',
                       'Param'])['coef'].apply(lambda x: np.mean(x) - 1.97*(np.std(x)/np.sqrt(len(x)))).values
df_coefs_seas['coef_ci_upr'] = df_coefs.drop(columns='Unnamed: 0').groupby(['Year',                                             
                       'season_str',
                       'Model',
                       'Param'])['coef'].apply(lambda x: np.mean(x) + 1.97*(np.std(x)/np.sqrt(len(x)))).values
df_coefs_seas['Param'] = df_coefs_seas['Param'].apply(
                lambda x: re.sub('\]', 
                                 '',
                                 re.sub('C\(PC_dmt, Treatment\(reference\="C3_C4_mix"\)\)\[T\.', 
                                        '', 
                                        str(x))))

df_coefs_seas['Param'] = df_coefs_seas['Param'].apply(
                lambda x: re.sub('\]', 
                                 '',
                                 re.sub('C\(TPC_c, Treatment\(reference\="Flat Plains"\)\)\[T\.', 
                                        'TPC:', 
                                        str(x))))

df_coefs_seas['Param'] = df_coefs_seas['Param'].apply(
                lambda x: re.sub('TPC:', '', re.sub('TPC:Other', 'Complex', x)))

df_coefs_seas['significant'] = df_coefs_seas.apply(lambda v: 'Yes' if np.sign(v['coef_ci_lwr']) == np.sign(v['coef_ci_upr']) else 'No', axis=1)

df_coefs_seas['season'] = pd.Categorical(df_coefs_seas['season_str'], ['early', 'mid', 'late'])
"""
for yr in df_coefs_seas['Year'].unique():
    for seas in df_coefs_seas['season'].unique():
        df_coefs_seas[(df_coefs_seas['Year'] == yr) &
                              (df_coefs_seas['season'] == seas) &
                              (df_coefs_seas['Model'] == 'M_best')].to_csv(os.path.join(outDIR_tables, 'M_best_coefs_' + str(yr) + '_' + seas + '.csv'))

# %%
"""
Display best model coefficients for chosen season. Significant if red
"""

def style_sig(v, props=''):
    return np.repeat(props, len(v)) if v['significant'] == 'Yes' else None

for yr in tqdm(df_coefs_seas['Year'].unique()):
    for seas in df_coefs_seas[df_coefs_seas['Year'] == yr]['season'].unique():
        print('\n---------------------- ' + str(yr) + ': ' + seas + ' --------------------')
        display(df_coefs_seas[(df_coefs_seas['Year'] == yr) &
                              (df_coefs_seas['season'] == seas) &
                              (df_coefs_seas['Model'] == 'M_best')].style.apply(style_sig, 
                                                                                props='color:red;',
                                                                                axis=1))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------- 2016.0: early --------------------
# <style type="text/css">
# #T_5d91a_row0_col0, #T_5d91a_row0_col1, #T_5d91a_row0_col2, #T_5d91a_row0_col3, #T_5d91a_row0_col4, #T_5d91a_row0_col5, #T_5d91a_row0_col6, #T_5d91a_row0_col7, #T_5d91a_row10_col0, #T_5d91a_row10_col1, #T_5d91a_row10_col2, #T_5d91a_row10_col3, #T_5d91a_row10_col4, #T_5d91a_row10_col5, #T_5d91a_row10_col6, #T_5d91a_row10_col7, #T_5d91a_row11_col0, #T_5d91a_row11_col1, #T_5d91a_row11_col2, #T_5d91a_row11_col3, #T_5d91a_row11_col4, #T_5d91a_row11_col5, #T_5d91a_row11_col6, #T_5d91a_row11_col7, #T_5d91a_row16_col0, #T_5d91a_row16_col1, #T_5d91a_row16_col2, #T_5d91a_row16_col3, #T_5d91a_row16_col4, #T_5d91a_row16_col5, #T_5d91a_row16_col6, #T_5d91a_row16_col7, #T_5d91a_row17_col0, #T_5d91a_row17_col1, #T_5d91a_row17_col2, #T_5d91a_row17_col3, #T_5d91a_row17_col4, #T_5d91a_row17_col5, #T_5d91a_row17_col6, #T_5d91a_row17_col7, #T_5d91a_row33_col0, #T_5d91a_row33_col1, #T_5d91a_row33_col2, #T_5d91a_row33_col3, #T_5d91a_row33_col4, #T_5d91a_row33_col5, #T_5d91a_row33_col6, #T_5d91a_row33_col7, #T_5d91a_row34_col0, #T_5d91a_row34_col1, #T_5d91a_row34_col2, #T_5d91a_row34_col3, #T_5d91a_row34_col4, #T_5d91a_row34_col5, #T_5d91a_row34_col6, #T_5d91a_row34_col7, #T_5d91a_row36_col0, #T_5d91a_row36_col1, #T_5d91a_row36_col2, #T_5d91a_row36_col3, #T_5d91a_row36_col4, #T_5d91a_row36_col5, #T_5d91a_row36_col6, #T_5d91a_row36_col7 {
#   color: red;
# }
# </style>
# <table id="T_5d91a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >season</th>
#       <th class="col_heading level0 col2" >Model</th>
#       <th class="col_heading level0 col3" >Param</th>
#       <th class="col_heading level0 col4" >coef</th>
#       <th class="col_heading level0 col5" >coef_ci_lwr</th>
#       <th class="col_heading level0 col6" >coef_ci_upr</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d91a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d91a_row0_col0" class="data row0 col0" >2016.000000</td>
#       <td id="T_5d91a_row0_col1" class="data row0 col1" >early</td>
#       <td id="T_5d91a_row0_col2" class="data row0 col2" >M_best</td>
#       <td id="T_5d91a_row0_col3" class="data row0 col3" >Biomass</td>
#       <td id="T_5d91a_row0_col4" class="data row0 col4" >-0.206005</td>
#       <td id="T_5d91a_row0_col5" class="data row0 col5" >-0.411384</td>
#       <td id="T_5d91a_row0_col6" class="data row0 col6" >-0.000626</td>
#       <td id="T_5d91a_row0_col7" class="data row0 col7" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d91a_row1_col0" class="data row1 col0" >2016.000000</td>
#       <td id="T_5d91a_row1_col1" class="data row1 col1" >early</td>
#       <td id="T_5d91a_row1_col2" class="data row1 col2" >M_best</td>
#       <td id="T_5d91a_row1_col3" class="data row1 col3" >Biomass:CP</td>
#       <td id="T_5d91a_row1_col4" class="data row1 col4" >0.071745</td>
#       <td id="T_5d91a_row1_col5" class="data row1 col5" >-0.243379</td>
#       <td id="T_5d91a_row1_col6" class="data row1 col6" >0.386870</td>
#       <td id="T_5d91a_row1_col7" class="data row1 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d91a_row2_col0" class="data row2 col0" >2016.000000</td>
#       <td id="T_5d91a_row2_col1" class="data row2 col1" >early</td>
#       <td id="T_5d91a_row2_col2" class="data row2 col2" >M_best</td>
#       <td id="T_5d91a_row2_col3" class="data row2 col3" >C3</td>
#       <td id="T_5d91a_row2_col4" class="data row2 col4" >-0.672360</td>
#       <td id="T_5d91a_row2_col5" class="data row2 col5" >-2.190574</td>
#       <td id="T_5d91a_row2_col6" class="data row2 col6" >0.845854</td>
#       <td id="T_5d91a_row2_col7" class="data row2 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d91a_row3_col0" class="data row3 col0" >2016.000000</td>
#       <td id="T_5d91a_row3_col1" class="data row3 col1" >early</td>
#       <td id="T_5d91a_row3_col2" class="data row3 col2" >M_best</td>
#       <td id="T_5d91a_row3_col3" class="data row3 col3" >C3:Biomass</td>
#       <td id="T_5d91a_row3_col4" class="data row3 col4" >0.345000</td>
#       <td id="T_5d91a_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_5d91a_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_5d91a_row3_col7" class="data row3 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d91a_row4_col0" class="data row4 col0" >2016.000000</td>
#       <td id="T_5d91a_row4_col1" class="data row4 col1" >early</td>
#       <td id="T_5d91a_row4_col2" class="data row4 col2" >M_best</td>
#       <td id="T_5d91a_row4_col3" class="data row4 col3" >C3:I(Biomass ** 2)</td>
#       <td id="T_5d91a_row4_col4" class="data row4 col4" >-0.131300</td>
#       <td id="T_5d91a_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_5d91a_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_5d91a_row4_col7" class="data row4 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d91a_row5_col0" class="data row5 col0" >2016.000000</td>
#       <td id="T_5d91a_row5_col1" class="data row5 col1" >early</td>
#       <td id="T_5d91a_row5_col2" class="data row5 col2" >M_best</td>
#       <td id="T_5d91a_row5_col3" class="data row5 col3" >C3:PC_div</td>
#       <td id="T_5d91a_row5_col4" class="data row5 col4" >0.940000</td>
#       <td id="T_5d91a_row5_col5" class="data row5 col5" >-2.173285</td>
#       <td id="T_5d91a_row5_col6" class="data row5 col6" >4.053285</td>
#       <td id="T_5d91a_row5_col7" class="data row5 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5d91a_row6_col0" class="data row6 col0" >2016.000000</td>
#       <td id="T_5d91a_row6_col1" class="data row6 col1" >early</td>
#       <td id="T_5d91a_row6_col2" class="data row6 col2" >M_best</td>
#       <td id="T_5d91a_row6_col3" class="data row6 col3" >C4</td>
#       <td id="T_5d91a_row6_col4" class="data row6 col4" >0.030755</td>
#       <td id="T_5d91a_row6_col5" class="data row6 col5" >-0.165944</td>
#       <td id="T_5d91a_row6_col6" class="data row6 col6" >0.227453</td>
#       <td id="T_5d91a_row6_col7" class="data row6 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5d91a_row7_col0" class="data row7 col0" >2016.000000</td>
#       <td id="T_5d91a_row7_col1" class="data row7 col1" >early</td>
#       <td id="T_5d91a_row7_col2" class="data row7 col2" >M_best</td>
#       <td id="T_5d91a_row7_col3" class="data row7 col3" >C4:Biomass</td>
#       <td id="T_5d91a_row7_col4" class="data row7 col4" >0.539900</td>
#       <td id="T_5d91a_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_5d91a_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_5d91a_row7_col7" class="data row7 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5d91a_row8_col0" class="data row8 col0" >2016.000000</td>
#       <td id="T_5d91a_row8_col1" class="data row8 col1" >early</td>
#       <td id="T_5d91a_row8_col2" class="data row8 col2" >M_best</td>
#       <td id="T_5d91a_row8_col3" class="data row8 col3" >C4:CP</td>
#       <td id="T_5d91a_row8_col4" class="data row8 col4" >-0.571050</td>
#       <td id="T_5d91a_row8_col5" class="data row8 col5" >-1.730127</td>
#       <td id="T_5d91a_row8_col6" class="data row8 col6" >0.588027</td>
#       <td id="T_5d91a_row8_col7" class="data row8 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d91a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5d91a_row9_col0" class="data row9 col0" >2016.000000</td>
#       <td id="T_5d91a_
# ---------------------- 2016.0: mid --------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _repr_html_(self)
#     214         Hooks into Jupyter notebook rich display system.
#     215         """
# --> 216         return self.render()
#     217
#     218     def render(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in render(self, sparse_index, sparse_columns, **kwargs)
#     270         if sparse_columns is None:
#     271             sparse_columns = get_option("styler.sparse.columns")
# --> 272         return self._render_html(sparse_index, sparse_columns, **kwargs)
#     273
#     274     def set_tooltips(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _render_html(self, sparse_index, sparse_columns, **kwargs)
#     119         Generates a dict with necessary kwargs passed to jinja2 template.
#     120         """
# --> 121         self._compute()
#     122         # TODO: namespace all the pandas keys
#     123         d = self._translate(sparse_index, sparse_columns)
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _compute(self)
#     158         r = self
#     159         for func, args, kwargs in self._todo:
# --> 160             r = func(self)(*args, **kwargs)
#     161         return r
#     162
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#    1079
#    1080         if result.shape != data.shape:
# -> 1081             raise ValueError(
#    1082                 f"Function {repr(func)} returned the wrong shape.\n"
#    1083                 f"Result has shape: {result.shape}\n"
#
# ValueError: Function <function style_sig at 0x7f9f4944d310> returned the wrong shape.
# Result has shape: (30,)
# Expected shape:   (30, 8)
# ---------------------- 2016.0: late --------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _repr_html_(self)
#     214         Hooks into Jupyter notebook rich display system.
#     215         """
# --> 216         return self.render()
#     217
#     218     def render(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in render(self, sparse_index, sparse_columns, **kwargs)
#     270         if sparse_columns is None:
#     271             sparse_columns = get_option("styler.sparse.columns")
# --> 272         return self._render_html(sparse_index, sparse_columns, **kwargs)
#     273
#     274     def set_tooltips(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _render_html(self, sparse_index, sparse_columns, **kwargs)
#     119         Generates a dict with necessary kwargs passed to jinja2 template.
#     120         """
# --> 121         self._compute()
#     122         # TODO: namespace all the pandas keys
#     123         d = self._translate(sparse_index, sparse_columns)
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _compute(self)
#     158         r = self
#     159         for func, args, kwargs in self._todo:
# --> 160             r = func(self)(*args, **kwargs)
#     161         return r
#     162
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#    1079
#    1080         if result.shape != data.shape:
# -> 1081             raise ValueError(
#    1082                 f"Function {repr(func)} returned the wrong shape.\n"
#    1083                 f"Result has shape: {result.shape}\n"
#
# ValueError: Function <function style_sig at 0x7f9f4944d310> returned the wrong shape.
# Result has shape: (37,)
# Expected shape:   (37, 8)
# ---------------------- 2017.0: early --------------------
# <style type="text/css">
# #T_db0cf_row0_col0, #T_db0cf_row0_col1, #T_db0cf_row0_col2, #T_db0cf_row0_col3, #T_db0cf_row0_col4, #T_db0cf_row0_col5, #T_db0cf_row0_col6, #T_db0cf_row0_col7, #T_db0cf_row12_col0, #T_db0cf_row12_col1, #T_db0cf_row12_col2, #T_db0cf_row12_col3, #T_db0cf_row12_col4, #T_db0cf_row12_col5, #T_db0cf_row12_col6, #T_db0cf_row12_col7, #T_db0cf_row15_col0, #T_db0cf_row15_col1, #T_db0cf_row15_col2, #T_db0cf_row15_col3, #T_db0cf_row15_col4, #T_db0cf_row15_col5, #T_db0cf_row15_col6, #T_db0cf_row15_col7, #T_db0cf_row16_col0, #T_db0cf_row16_col1, #T_db0cf_row16_col2, #T_db0cf_row16_col3, #T_db0cf_row16_col4, #T_db0cf_row16_col5, #T_db0cf_row16_col6, #T_db0cf_row16_col7, #T_db0cf_row28_col0, #T_db0cf_row28_col1, #T_db0cf_row28_col2, #T_db0cf_row28_col3, #T_db0cf_row28_col4, #T_db0cf_row28_col5, #T_db0cf_row28_col6, #T_db0cf_row28_col7, #T_db0cf_row30_col0, #T_db0cf_row30_col1, #T_db0cf_row30_col2, #T_db0cf_row30_col3, #T_db0cf_row30_col4, #T_db0cf_row30_col5, #T_db0cf_row30_col6, #T_db0cf_row30_col7, #T_db0cf_row31_col0, #T_db0cf_row31_col1, #T_db0cf_row31_col2, #T_db0cf_row31_col3, #T_db0cf_row31_col4, #T_db0cf_row31_col5, #T_db0cf_row31_col6, #T_db0cf_row31_col7 {
#   color: red;
# }
# </style>
# <table id="T_db0cf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >season</th>
#       <th class="col_heading level0 col2" >Model</th>
#       <th class="col_heading level0 col3" >Param</th>
#       <th class="col_heading level0 col4" >coef</th>
#       <th class="col_heading level0 col5" >coef_ci_lwr</th>
#       <th class="col_heading level0 col6" >coef_ci_upr</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db0cf_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_db0cf_row0_col0" class="data row0 col0" >2017.000000</td>
#       <td id="T_db0cf_row0_col1" class="data row0 col1" >early</td>
#       <td id="T_db0cf_row0_col2" class="data row0 col2" >M_best</td>
#       <td id="T_db0cf_row0_col3" class="data row0 col3" >Biomass</td>
#       <td id="T_db0cf_row0_col4" class="data row0 col4" >-0.467355</td>
#       <td id="T_db0cf_row0_col5" class="data row0 col5" >-0.629276</td>
#       <td id="T_db0cf_row0_col6" class="data row0 col6" >-0.305433</td>
#       <td id="T_db0cf_row0_col7" class="data row0 col7" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row1" class="row_heading level0 row1" >105</th>
#       <td id="T_db0cf_row1_col0" class="data row1 col0" >2017.000000</td>
#       <td id="T_db0cf_row1_col1" class="data row1 col1" >early</td>
#       <td id="T_db0cf_row1_col2" class="data row1 col2" >M_best</td>
#       <td id="T_db0cf_row1_col3" class="data row1 col3" >Biomass:CP</td>
#       <td id="T_db0cf_row1_col4" class="data row1 col4" >0.104580</td>
#       <td id="T_db0cf_row1_col5" class="data row1 col5" >-0.558495</td>
#       <td id="T_db0cf_row1_col6" class="data row1 col6" >0.767655</td>
#       <td id="T_db0cf_row1_col7" class="data row1 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row2" class="row_heading level0 row2" >106</th>
#       <td id="T_db0cf_row2_col0" class="data row2 col0" >2017.000000</td>
#       <td id="T_db0cf_row2_col1" class="data row2 col1" >early</td>
#       <td id="T_db0cf_row2_col2" class="data row2 col2" >M_best</td>
#       <td id="T_db0cf_row2_col3" class="data row2 col3" >C3</td>
#       <td id="T_db0cf_row2_col4" class="data row2 col4" >-0.475133</td>
#       <td id="T_db0cf_row2_col5" class="data row2 col5" >-1.916804</td>
#       <td id="T_db0cf_row2_col6" class="data row2 col6" >0.966537</td>
#       <td id="T_db0cf_row2_col7" class="data row2 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row3" class="row_heading level0 row3" >107</th>
#       <td id="T_db0cf_row3_col0" class="data row3 col0" >2017.000000</td>
#       <td id="T_db0cf_row3_col1" class="data row3 col1" >early</td>
#       <td id="T_db0cf_row3_col2" class="data row3 col2" >M_best</td>
#       <td id="T_db0cf_row3_col3" class="data row3 col3" >C3:Biomass</td>
#       <td id="T_db0cf_row3_col4" class="data row3 col4" >-4.897300</td>
#       <td id="T_db0cf_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_db0cf_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_db0cf_row3_col7" class="data row3 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row4" class="row_heading level0 row4" >108</th>
#       <td id="T_db0cf_row4_col0" class="data row4 col0" >2017.000000</td>
#       <td id="T_db0cf_row4_col1" class="data row4 col1" >early</td>
#       <td id="T_db0cf_row4_col2" class="data row4 col2" >M_best</td>
#       <td id="T_db0cf_row4_col3" class="data row4 col3" >C3:I(Biomass ** 2)</td>
#       <td id="T_db0cf_row4_col4" class="data row4 col4" >2.657300</td>
#       <td id="T_db0cf_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_db0cf_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_db0cf_row4_col7" class="data row4 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row5" class="row_heading level0 row5" >109</th>
#       <td id="T_db0cf_row5_col0" class="data row5 col0" >2017.000000</td>
#       <td id="T_db0cf_row5_col1" class="data row5 col1" >early</td>
#       <td id="T_db0cf_row5_col2" class="data row5 col2" >M_best</td>
#       <td id="T_db0cf_row5_col3" class="data row5 col3" >C3:PC_div</td>
#       <td id="T_db0cf_row5_col4" class="data row5 col4" >0.173767</td>
#       <td id="T_db0cf_row5_col5" class="data row5 col5" >-1.542223</td>
#       <td id="T_db0cf_row5_col6" class="data row5 col6" >1.889756</td>
#       <td id="T_db0cf_row5_col7" class="data row5 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row6" class="row_heading level0 row6" >110</th>
#       <td id="T_db0cf_row6_col0" class="data row6 col0" >2017.000000</td>
#       <td id="T_db0cf_row6_col1" class="data row6 col1" >early</td>
#       <td id="T_db0cf_row6_col2" class="data row6 col2" >M_best</td>
#       <td id="T_db0cf_row6_col3" class="data row6 col3" >C4</td>
#       <td id="T_db0cf_row6_col4" class="data row6 col4" >0.089583</td>
#       <td id="T_db0cf_row6_col5" class="data row6 col5" >-0.203303</td>
#       <td id="T_db0cf_row6_col6" class="data row6 col6" >0.382469</td>
#       <td id="T_db0cf_row6_col7" class="data row6 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row7" class="row_heading level0 row7" >111</th>
#       <td id="T_db0cf_row7_col0" class="data row7 col0" >2017.000000</td>
#       <td id="T_db0cf_row7_col1" class="data row7 col1" >early</td>
#       <td id="T_db0cf_row7_col2" class="data row7 col2" >M_best</td>
#       <td id="T_db0cf_row7_col3" class="data row7 col3" >C4:Biomass</td>
#       <td id="T_db0cf_row7_col4" class="data row7 col4" >-0.678060</td>
#       <td id="T_db0cf_row7_col5" class="data row7 col5" >-1.644808</td>
#       <td id="T_db0cf_row7_col6" class="data row7 col6" >0.288688</td>
#       <td id="T_db0cf_row7_col7" class="data row7 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row8" class="row_heading level0 row8" >112</th>
#       <td id="T_db0cf_row8_col0" class="data row8 col0" >2017.000000</td>
#       <td id="T_db0cf_row8_col1" class="data row8 col1" >early</td>
#       <td id="T_db0cf_row8_col2" class="data row8 col2" >M_best</td>
#       <td id="T_db0cf_row8_col3" class="data row8 col3" >C4:I(Biomass ** 2)</td>
#       <td id="T_db0cf_row8_col4" class="data row8 col4" >0.053640</td>
#       <td id="T_db0cf_row8_col5" class="data row8 col5" >-1.281911</td>
#       <td id="T_db0cf_row8_col6" class="data row8 col6" >1.389191</td>
#       <td id="T_db0cf_row8_col7" class="data row8 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_db0cf_level0_row9" class="row_heading level0 row9" >113</th>
#       <td id="T_db0cf_row9_col0" class="data row9 col0" >2017.000000</td>
#       <td id="T_db0cf_row9_col1" class="data row9 col1" >early</td>
#       <td id="T_db0cf_row9_col2" class="data row9 col2" >M_best</td>
#       <td
# ---------------------- 2017.0: mid --------------------
# <style type="text/css">
# #T_d66a8_row0_col0, #T_d66a8_row0_col1, #T_d66a8_row0_col2, #T_d66a8_row0_col3, #T_d66a8_row0_col4, #T_d66a8_row0_col5, #T_d66a8_row0_col6, #T_d66a8_row0_col7, #T_d66a8_row11_col0, #T_d66a8_row11_col1, #T_d66a8_row11_col2, #T_d66a8_row11_col3, #T_d66a8_row11_col4, #T_d66a8_row11_col5, #T_d66a8_row11_col6, #T_d66a8_row11_col7, #T_d66a8_row13_col0, #T_d66a8_row13_col1, #T_d66a8_row13_col2, #T_d66a8_row13_col3, #T_d66a8_row13_col4, #T_d66a8_row13_col5, #T_d66a8_row13_col6, #T_d66a8_row13_col7, #T_d66a8_row14_col0, #T_d66a8_row14_col1, #T_d66a8_row14_col2, #T_d66a8_row14_col3, #T_d66a8_row14_col4, #T_d66a8_row14_col5, #T_d66a8_row14_col6, #T_d66a8_row14_col7, #T_d66a8_row16_col0, #T_d66a8_row16_col1, #T_d66a8_row16_col2, #T_d66a8_row16_col3, #T_d66a8_row16_col4, #T_d66a8_row16_col5, #T_d66a8_row16_col6, #T_d66a8_row16_col7, #T_d66a8_row17_col0, #T_d66a8_row17_col1, #T_d66a8_row17_col2, #T_d66a8_row17_col3, #T_d66a8_row17_col4, #T_d66a8_row17_col5, #T_d66a8_row17_col6, #T_d66a8_row17_col7, #T_d66a8_row32_col0, #T_d66a8_row32_col1, #T_d66a8_row32_col2, #T_d66a8_row32_col3, #T_d66a8_row32_col4, #T_d66a8_row32_col5, #T_d66a8_row32_col6, #T_d66a8_row32_col7, #T_d66a8_row35_col0, #T_d66a8_row35_col1, #T_d66a8_row35_col2, #T_d66a8_row35_col3, #T_d66a8_row35_col4, #T_d66a8_row35_col5, #T_d66a8_row35_col6, #T_d66a8_row35_col7 {
#   color: red;
# }
# </style>
# <table id="T_d66a8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >season</th>
#       <th class="col_heading level0 col2" >Model</th>
#       <th class="col_heading level0 col3" >Param</th>
#       <th class="col_heading level0 col4" >coef</th>
#       <th class="col_heading level0 col5" >coef_ci_lwr</th>
#       <th class="col_heading level0 col6" >coef_ci_upr</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d66a8_level0_row0" class="row_heading level0 row0" >136</th>
#       <td id="T_d66a8_row0_col0" class="data row0 col0" >2017.000000</td>
#       <td id="T_d66a8_row0_col1" class="data row0 col1" >mid</td>
#       <td id="T_d66a8_row0_col2" class="data row0 col2" >M_best</td>
#       <td id="T_d66a8_row0_col3" class="data row0 col3" >Biomass</td>
#       <td id="T_d66a8_row0_col4" class="data row0 col4" >-0.635030</td>
#       <td id="T_d66a8_row0_col5" class="data row0 col5" >-1.135730</td>
#       <td id="T_d66a8_row0_col6" class="data row0 col6" >-0.134331</td>
#       <td id="T_d66a8_row0_col7" class="data row0 col7" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row1" class="row_heading level0 row1" >137</th>
#       <td id="T_d66a8_row1_col0" class="data row1 col0" >2017.000000</td>
#       <td id="T_d66a8_row1_col1" class="data row1 col1" >mid</td>
#       <td id="T_d66a8_row1_col2" class="data row1 col2" >M_best</td>
#       <td id="T_d66a8_row1_col3" class="data row1 col3" >Biomass:CP</td>
#       <td id="T_d66a8_row1_col4" class="data row1 col4" >0.770567</td>
#       <td id="T_d66a8_row1_col5" class="data row1 col5" >-0.034631</td>
#       <td id="T_d66a8_row1_col6" class="data row1 col6" >1.575764</td>
#       <td id="T_d66a8_row1_col7" class="data row1 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row2" class="row_heading level0 row2" >138</th>
#       <td id="T_d66a8_row2_col0" class="data row2 col0" >2017.000000</td>
#       <td id="T_d66a8_row2_col1" class="data row2 col1" >mid</td>
#       <td id="T_d66a8_row2_col2" class="data row2 col2" >M_best</td>
#       <td id="T_d66a8_row2_col3" class="data row2 col3" >C3</td>
#       <td id="T_d66a8_row2_col4" class="data row2 col4" >0.409275</td>
#       <td id="T_d66a8_row2_col5" class="data row2 col5" >-0.863407</td>
#       <td id="T_d66a8_row2_col6" class="data row2 col6" >1.681957</td>
#       <td id="T_d66a8_row2_col7" class="data row2 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row3" class="row_heading level0 row3" >139</th>
#       <td id="T_d66a8_row3_col0" class="data row3 col0" >2017.000000</td>
#       <td id="T_d66a8_row3_col1" class="data row3 col1" >mid</td>
#       <td id="T_d66a8_row3_col2" class="data row3 col2" >M_best</td>
#       <td id="T_d66a8_row3_col3" class="data row3 col3" >C3:Biomass</td>
#       <td id="T_d66a8_row3_col4" class="data row3 col4" >-1.218767</td>
#       <td id="T_d66a8_row3_col5" class="data row3 col5" >-5.826863</td>
#       <td id="T_d66a8_row3_col6" class="data row3 col6" >3.389330</td>
#       <td id="T_d66a8_row3_col7" class="data row3 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row4" class="row_heading level0 row4" >140</th>
#       <td id="T_d66a8_row4_col0" class="data row4 col0" >2017.000000</td>
#       <td id="T_d66a8_row4_col1" class="data row4 col1" >mid</td>
#       <td id="T_d66a8_row4_col2" class="data row4 col2" >M_best</td>
#       <td id="T_d66a8_row4_col3" class="data row4 col3" >C3:I(Biomass ** 2)</td>
#       <td id="T_d66a8_row4_col4" class="data row4 col4" >-2.592000</td>
#       <td id="T_d66a8_row4_col5" class="data row4 col5" >-13.170266</td>
#       <td id="T_d66a8_row4_col6" class="data row4 col6" >7.986266</td>
#       <td id="T_d66a8_row4_col7" class="data row4 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row5" class="row_heading level0 row5" >141</th>
#       <td id="T_d66a8_row5_col0" class="data row5 col0" >2017.000000</td>
#       <td id="T_d66a8_row5_col1" class="data row5 col1" >mid</td>
#       <td id="T_d66a8_row5_col2" class="data row5 col2" >M_best</td>
#       <td id="T_d66a8_row5_col3" class="data row5 col3" >C3:PC_div</td>
#       <td id="T_d66a8_row5_col4" class="data row5 col4" >-1.275450</td>
#       <td id="T_d66a8_row5_col5" class="data row5 col5" >-17.941543</td>
#       <td id="T_d66a8_row5_col6" class="data row5 col6" >15.390643</td>
#       <td id="T_d66a8_row5_col7" class="data row5 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row6" class="row_heading level0 row6" >142</th>
#       <td id="T_d66a8_row6_col0" class="data row6 col0" >2017.000000</td>
#       <td id="T_d66a8_row6_col1" class="data row6 col1" >mid</td>
#       <td id="T_d66a8_row6_col2" class="data row6 col2" >M_best</td>
#       <td id="T_d66a8_row6_col3" class="data row6 col3" >C4</td>
#       <td id="T_d66a8_row6_col4" class="data row6 col4" >0.238323</td>
#       <td id="T_d66a8_row6_col5" class="data row6 col5" >-0.231901</td>
#       <td id="T_d66a8_row6_col6" class="data row6 col6" >0.708547</td>
#       <td id="T_d66a8_row6_col7" class="data row6 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row7" class="row_heading level0 row7" >143</th>
#       <td id="T_d66a8_row7_col0" class="data row7 col0" >2017.000000</td>
#       <td id="T_d66a8_row7_col1" class="data row7 col1" >mid</td>
#       <td id="T_d66a8_row7_col2" class="data row7 col2" >M_best</td>
#       <td id="T_d66a8_row7_col3" class="data row7 col3" >C4:Biomass</td>
#       <td id="T_d66a8_row7_col4" class="data row7 col4" >-1.155525</td>
#       <td id="T_d66a8_row7_col5" class="data row7 col5" >-2.794663</td>
#       <td id="T_d66a8_row7_col6" class="data row7 col6" >0.483613</td>
#       <td id="T_d66a8_row7_col7" class="data row7 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row8" class="row_heading level0 row8" >144</th>
#       <td id="T_d66a8_row8_col0" class="data row8 col0" >2017.000000</td>
#       <td id="T_d66a8_row8_col1" class="data row8 col1" >mid</td>
#       <td id="T_d66a8_row8_col2" class="data row8 col2" >M_best</td>
#       <td id="T_d66a8_row8_col3" class="data row8 col3" >C4:CP</td>
#       <td id="T_d66a8_row8_col4" class="data row8 col4" >0.593050</td>
#       <td id="T_d66a8_row8_col5" class="data row8 col5" >-8.291764</td>
#       <td id="T_d66a8_row8_col6" class="data row8 col6" >9.477864</td>
#       <td id="T_d66a8_row8_col7" class="data row8 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d66a8_level0_row9" class="row_heading level0 row9" >145</th>
#       <td id="T_d66a8_row9_col0" class="data row9 col0" >
# ---------------------- 2017.0: late --------------------
# <style type="text/css">
# #T_0e86e_row0_col0, #T_0e86e_row0_col1, #T_0e86e_row0_col2, #T_0e86e_row0_col3, #T_0e86e_row0_col4, #T_0e86e_row0_col5, #T_0e86e_row0_col6, #T_0e86e_row0_col7, #T_0e86e_row15_col0, #T_0e86e_row15_col1, #T_0e86e_row15_col2, #T_0e86e_row15_col3, #T_0e86e_row15_col4, #T_0e86e_row15_col5, #T_0e86e_row15_col6, #T_0e86e_row15_col7, #T_0e86e_row22_col0, #T_0e86e_row22_col1, #T_0e86e_row22_col2, #T_0e86e_row22_col3, #T_0e86e_row22_col4, #T_0e86e_row22_col5, #T_0e86e_row22_col6, #T_0e86e_row22_col7, #T_0e86e_row27_col0, #T_0e86e_row27_col1, #T_0e86e_row27_col2, #T_0e86e_row27_col3, #T_0e86e_row27_col4, #T_0e86e_row27_col5, #T_0e86e_row27_col6, #T_0e86e_row27_col7, #T_0e86e_row30_col0, #T_0e86e_row30_col1, #T_0e86e_row30_col2, #T_0e86e_row30_col3, #T_0e86e_row30_col4, #T_0e86e_row30_col5, #T_0e86e_row30_col6, #T_0e86e_row30_col7 {
#   color: red;
# }
# </style>
# <table id="T_0e86e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >season</th>
#       <th class="col_heading level0 col2" >Model</th>
#       <th class="col_heading level0 col3" >Param</th>
#       <th class="col_heading level0 col4" >coef</th>
#       <th class="col_heading level0 col5" >coef_ci_lwr</th>
#       <th class="col_heading level0 col6" >coef_ci_upr</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e86e_level0_row0" class="row_heading level0 row0" >172</th>
#       <td id="T_0e86e_row0_col0" class="data row0 col0" >2017.000000</td>
#       <td id="T_0e86e_row0_col1" class="data row0 col1" >late</td>
#       <td id="T_0e86e_row0_col2" class="data row0 col2" >M_best</td>
#       <td id="T_0e86e_row0_col3" class="data row0 col3" >Biomass</td>
#       <td id="T_0e86e_row0_col4" class="data row0 col4" >-0.631187</td>
#       <td id="T_0e86e_row0_col5" class="data row0 col5" >-1.252770</td>
#       <td id="T_0e86e_row0_col6" class="data row0 col6" >-0.009605</td>
#       <td id="T_0e86e_row0_col7" class="data row0 col7" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row1" class="row_heading level0 row1" >173</th>
#       <td id="T_0e86e_row1_col0" class="data row1 col0" >2017.000000</td>
#       <td id="T_0e86e_row1_col1" class="data row1 col1" >late</td>
#       <td id="T_0e86e_row1_col2" class="data row1 col2" >M_best</td>
#       <td id="T_0e86e_row1_col3" class="data row1 col3" >Biomass:CP</td>
#       <td id="T_0e86e_row1_col4" class="data row1 col4" >0.711233</td>
#       <td id="T_0e86e_row1_col5" class="data row1 col5" >-1.990693</td>
#       <td id="T_0e86e_row1_col6" class="data row1 col6" >3.413160</td>
#       <td id="T_0e86e_row1_col7" class="data row1 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row2" class="row_heading level0 row2" >174</th>
#       <td id="T_0e86e_row2_col0" class="data row2 col0" >2017.000000</td>
#       <td id="T_0e86e_row2_col1" class="data row2 col1" >late</td>
#       <td id="T_0e86e_row2_col2" class="data row2 col2" >M_best</td>
#       <td id="T_0e86e_row2_col3" class="data row2 col3" >C3</td>
#       <td id="T_0e86e_row2_col4" class="data row2 col4" >0.100550</td>
#       <td id="T_0e86e_row2_col5" class="data row2 col5" >-0.541268</td>
#       <td id="T_0e86e_row2_col6" class="data row2 col6" >0.742368</td>
#       <td id="T_0e86e_row2_col7" class="data row2 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row3" class="row_heading level0 row3" >175</th>
#       <td id="T_0e86e_row3_col0" class="data row3 col0" >2017.000000</td>
#       <td id="T_0e86e_row3_col1" class="data row3 col1" >late</td>
#       <td id="T_0e86e_row3_col2" class="data row3 col2" >M_best</td>
#       <td id="T_0e86e_row3_col3" class="data row3 col3" >C3:Biomass</td>
#       <td id="T_0e86e_row3_col4" class="data row3 col4" >1.195300</td>
#       <td id="T_0e86e_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_0e86e_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_0e86e_row3_col7" class="data row3 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row4" class="row_heading level0 row4" >176</th>
#       <td id="T_0e86e_row4_col0" class="data row4 col0" >2017.000000</td>
#       <td id="T_0e86e_row4_col1" class="data row4 col1" >late</td>
#       <td id="T_0e86e_row4_col2" class="data row4 col2" >M_best</td>
#       <td id="T_0e86e_row4_col3" class="data row4 col3" >C3:I(Biomass ** 2)</td>
#       <td id="T_0e86e_row4_col4" class="data row4 col4" >-1.548200</td>
#       <td id="T_0e86e_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_0e86e_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_0e86e_row4_col7" class="data row4 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row5" class="row_heading level0 row5" >177</th>
#       <td id="T_0e86e_row5_col0" class="data row5 col0" >2017.000000</td>
#       <td id="T_0e86e_row5_col1" class="data row5 col1" >late</td>
#       <td id="T_0e86e_row5_col2" class="data row5 col2" >M_best</td>
#       <td id="T_0e86e_row5_col3" class="data row5 col3" >C3:PC_div</td>
#       <td id="T_0e86e_row5_col4" class="data row5 col4" >0.150867</td>
#       <td id="T_0e86e_row5_col5" class="data row5 col5" >-1.196595</td>
#       <td id="T_0e86e_row5_col6" class="data row5 col6" >1.498328</td>
#       <td id="T_0e86e_row5_col7" class="data row5 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row6" class="row_heading level0 row6" >178</th>
#       <td id="T_0e86e_row6_col0" class="data row6 col0" >2017.000000</td>
#       <td id="T_0e86e_row6_col1" class="data row6 col1" >late</td>
#       <td id="T_0e86e_row6_col2" class="data row6 col2" >M_best</td>
#       <td id="T_0e86e_row6_col3" class="data row6 col3" >C4</td>
#       <td id="T_0e86e_row6_col4" class="data row6 col4" >-0.092736</td>
#       <td id="T_0e86e_row6_col5" class="data row6 col5" >-0.410250</td>
#       <td id="T_0e86e_row6_col6" class="data row6 col6" >0.224777</td>
#       <td id="T_0e86e_row6_col7" class="data row6 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row7" class="row_heading level0 row7" >179</th>
#       <td id="T_0e86e_row7_col0" class="data row7 col0" >2017.000000</td>
#       <td id="T_0e86e_row7_col1" class="data row7 col1" >late</td>
#       <td id="T_0e86e_row7_col2" class="data row7 col2" >M_best</td>
#       <td id="T_0e86e_row7_col3" class="data row7 col3" >C4:Biomass</td>
#       <td id="T_0e86e_row7_col4" class="data row7 col4" >-0.339850</td>
#       <td id="T_0e86e_row7_col5" class="data row7 col5" >-1.899537</td>
#       <td id="T_0e86e_row7_col6" class="data row7 col6" >1.219837</td>
#       <td id="T_0e86e_row7_col7" class="data row7 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row8" class="row_heading level0 row8" >180</th>
#       <td id="T_0e86e_row8_col0" class="data row8 col0" >2017.000000</td>
#       <td id="T_0e86e_row8_col1" class="data row8 col1" >late</td>
#       <td id="T_0e86e_row8_col2" class="data row8 col2" >M_best</td>
#       <td id="T_0e86e_row8_col3" class="data row8 col3" >C4:I(Biomass ** 2)</td>
#       <td id="T_0e86e_row8_col4" class="data row8 col4" >-0.196550</td>
#       <td id="T_0e86e_row8_col5" class="data row8 col5" >-24.415212</td>
#       <td id="T_0e86e_row8_col6" class="data row8 col6" >24.022112</td>
#       <td id="T_0e86e_row8_col7" class="data row8 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e86e_level0_row9" class="row_heading level0 row9" >181</th>
#       <td id="T_0e86e_row9_col0" class="data row9 col0" >2017.000000</td>
#       <td id="T_0e86e_row9_col1" class="data row9 col1" >late</td>
#       <td id="T_0e86e_row9_col2" class="data row9 col2" >M_best</td>
#       <td id="T_0e86e_row9_col3" class="data row9 col3" >C4:PC_div</td>
#       <td id="T_0e86e_row9_col4" class="data row9 col4" >0.012300</td>
#       <td id="T_0e86e_row9_col5" class="data row9 col5" >-0.520690</td>
#       <td id="T_0e86e_row9_col6" class="data row9 col6" >0.545290</td>
#       <td id="T_0e86e_row9_col7" class="data row9 col7" >No</td>
# ---------------------- 2018.0: early --------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _repr_html_(self)
#     214         Hooks into Jupyter notebook rich display system.
#     215         """
# --> 216         return self.render()
#     217
#     218     def render(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in render(self, sparse_index, sparse_columns, **kwargs)
#     270         if sparse_columns is None:
#     271             sparse_columns = get_option("styler.sparse.columns")
# --> 272         return self._render_html(sparse_index, sparse_columns, **kwargs)
#     273
#     274     def set_tooltips(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _render_html(self, sparse_index, sparse_columns, **kwargs)
#     119         Generates a dict with necessary kwargs passed to jinja2 template.
#     120         """
# --> 121         self._compute()
#     122         # TODO: namespace all the pandas keys
#     123         d = self._translate(sparse_index, sparse_columns)
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _compute(self)
#     158         r = self
#     159         for func, args, kwargs in self._todo:
# --> 160             r = func(self)(*args, **kwargs)
#     161         return r
#     162
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#    1079
#    1080         if result.shape != data.shape:
# -> 1081             raise ValueError(
#    1082                 f"Function {repr(func)} returned the wrong shape.\n"
#    1083                 f"Result has shape: {result.shape}\n"
#
# ValueError: Function <function style_sig at 0x7f9f4944d310> returned the wrong shape.
# Result has shape: (33,)
# Expected shape:   (33, 8)
# ---------------------- 2018.0: mid --------------------
# <style type="text/css">
# #T_d956e_row0_col0, #T_d956e_row0_col1, #T_d956e_row0_col2, #T_d956e_row0_col3, #T_d956e_row0_col4, #T_d956e_row0_col5, #T_d956e_row0_col6, #T_d956e_row0_col7, #T_d956e_row9_col0, #T_d956e_row9_col1, #T_d956e_row9_col2, #T_d956e_row9_col3, #T_d956e_row9_col4, #T_d956e_row9_col5, #T_d956e_row9_col6, #T_d956e_row9_col7, #T_d956e_row15_col0, #T_d956e_row15_col1, #T_d956e_row15_col2, #T_d956e_row15_col3, #T_d956e_row15_col4, #T_d956e_row15_col5, #T_d956e_row15_col6, #T_d956e_row15_col7, #T_d956e_row22_col0, #T_d956e_row22_col1, #T_d956e_row22_col2, #T_d956e_row22_col3, #T_d956e_row22_col4, #T_d956e_row22_col5, #T_d956e_row22_col6, #T_d956e_row22_col7, #T_d956e_row26_col0, #T_d956e_row26_col1, #T_d956e_row26_col2, #T_d956e_row26_col3, #T_d956e_row26_col4, #T_d956e_row26_col5, #T_d956e_row26_col6, #T_d956e_row26_col7, #T_d956e_row27_col0, #T_d956e_row27_col1, #T_d956e_row27_col2, #T_d956e_row27_col3, #T_d956e_row27_col4, #T_d956e_row27_col5, #T_d956e_row27_col6, #T_d956e_row27_col7, #T_d956e_row29_col0, #T_d956e_row29_col1, #T_d956e_row29_col2, #T_d956e_row29_col3, #T_d956e_row29_col4, #T_d956e_row29_col5, #T_d956e_row29_col6, #T_d956e_row29_col7, #T_d956e_row30_col0, #T_d956e_row30_col1, #T_d956e_row30_col2, #T_d956e_row30_col3, #T_d956e_row30_col4, #T_d956e_row30_col5, #T_d956e_row30_col6, #T_d956e_row30_col7 {
#   color: red;
# }
# </style>
# <table id="T_d956e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >season</th>
#       <th class="col_heading level0 col2" >Model</th>
#       <th class="col_heading level0 col3" >Param</th>
#       <th class="col_heading level0 col4" >coef</th>
#       <th class="col_heading level0 col5" >coef_ci_lwr</th>
#       <th class="col_heading level0 col6" >coef_ci_upr</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d956e_level0_row0" class="row_heading level0 row0" >236</th>
#       <td id="T_d956e_row0_col0" class="data row0 col0" >2018.000000</td>
#       <td id="T_d956e_row0_col1" class="data row0 col1" >mid</td>
#       <td id="T_d956e_row0_col2" class="data row0 col2" >M_best</td>
#       <td id="T_d956e_row0_col3" class="data row0 col3" >Biomass</td>
#       <td id="T_d956e_row0_col4" class="data row0 col4" >-1.441571</td>
#       <td id="T_d956e_row0_col5" class="data row0 col5" >-2.629626</td>
#       <td id="T_d956e_row0_col6" class="data row0 col6" >-0.253516</td>
#       <td id="T_d956e_row0_col7" class="data row0 col7" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row1" class="row_heading level0 row1" >237</th>
#       <td id="T_d956e_row1_col0" class="data row1 col0" >2018.000000</td>
#       <td id="T_d956e_row1_col1" class="data row1 col1" >mid</td>
#       <td id="T_d956e_row1_col2" class="data row1 col2" >M_best</td>
#       <td id="T_d956e_row1_col3" class="data row1 col3" >Biomass:CP</td>
#       <td id="T_d956e_row1_col4" class="data row1 col4" >-0.396220</td>
#       <td id="T_d956e_row1_col5" class="data row1 col5" >-3.068551</td>
#       <td id="T_d956e_row1_col6" class="data row1 col6" >2.276111</td>
#       <td id="T_d956e_row1_col7" class="data row1 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row2" class="row_heading level0 row2" >238</th>
#       <td id="T_d956e_row2_col0" class="data row2 col0" >2018.000000</td>
#       <td id="T_d956e_row2_col1" class="data row2 col1" >mid</td>
#       <td id="T_d956e_row2_col2" class="data row2 col2" >M_best</td>
#       <td id="T_d956e_row2_col3" class="data row2 col3" >C3</td>
#       <td id="T_d956e_row2_col4" class="data row2 col4" >0.860112</td>
#       <td id="T_d956e_row2_col5" class="data row2 col5" >-0.478382</td>
#       <td id="T_d956e_row2_col6" class="data row2 col6" >2.198607</td>
#       <td id="T_d956e_row2_col7" class="data row2 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row3" class="row_heading level0 row3" >239</th>
#       <td id="T_d956e_row3_col0" class="data row3 col0" >2018.000000</td>
#       <td id="T_d956e_row3_col1" class="data row3 col1" >mid</td>
#       <td id="T_d956e_row3_col2" class="data row3 col2" >M_best</td>
#       <td id="T_d956e_row3_col3" class="data row3 col3" >C3:Biomass</td>
#       <td id="T_d956e_row3_col4" class="data row3 col4" >10.499400</td>
#       <td id="T_d956e_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_d956e_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_d956e_row3_col7" class="data row3 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row4" class="row_heading level0 row4" >240</th>
#       <td id="T_d956e_row4_col0" class="data row4 col0" >2018.000000</td>
#       <td id="T_d956e_row4_col1" class="data row4 col1" >mid</td>
#       <td id="T_d956e_row4_col2" class="data row4 col2" >M_best</td>
#       <td id="T_d956e_row4_col3" class="data row4 col3" >C3:I(Biomass ** 2)</td>
#       <td id="T_d956e_row4_col4" class="data row4 col4" >-10.318500</td>
#       <td id="T_d956e_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_d956e_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_d956e_row4_col7" class="data row4 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row5" class="row_heading level0 row5" >241</th>
#       <td id="T_d956e_row5_col0" class="data row5 col0" >2018.000000</td>
#       <td id="T_d956e_row5_col1" class="data row5 col1" >mid</td>
#       <td id="T_d956e_row5_col2" class="data row5 col2" >M_best</td>
#       <td id="T_d956e_row5_col3" class="data row5 col3" >C3:PC_div</td>
#       <td id="T_d956e_row5_col4" class="data row5 col4" >-1.870767</td>
#       <td id="T_d956e_row5_col5" class="data row5 col5" >-6.895540</td>
#       <td id="T_d956e_row5_col6" class="data row5 col6" >3.154006</td>
#       <td id="T_d956e_row5_col7" class="data row5 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row6" class="row_heading level0 row6" >242</th>
#       <td id="T_d956e_row6_col0" class="data row6 col0" >2018.000000</td>
#       <td id="T_d956e_row6_col1" class="data row6 col1" >mid</td>
#       <td id="T_d956e_row6_col2" class="data row6 col2" >M_best</td>
#       <td id="T_d956e_row6_col3" class="data row6 col3" >C4</td>
#       <td id="T_d956e_row6_col4" class="data row6 col4" >0.334990</td>
#       <td id="T_d956e_row6_col5" class="data row6 col5" >-0.022441</td>
#       <td id="T_d956e_row6_col6" class="data row6 col6" >0.692421</td>
#       <td id="T_d956e_row6_col7" class="data row6 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row7" class="row_heading level0 row7" >243</th>
#       <td id="T_d956e_row7_col0" class="data row7 col0" >2018.000000</td>
#       <td id="T_d956e_row7_col1" class="data row7 col1" >mid</td>
#       <td id="T_d956e_row7_col2" class="data row7 col2" >M_best</td>
#       <td id="T_d956e_row7_col3" class="data row7 col3" >C4:Biomass</td>
#       <td id="T_d956e_row7_col4" class="data row7 col4" >-0.770000</td>
#       <td id="T_d956e_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_d956e_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_d956e_row7_col7" class="data row7 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row8" class="row_heading level0 row8" >244</th>
#       <td id="T_d956e_row8_col0" class="data row8 col0" >2018.000000</td>
#       <td id="T_d956e_row8_col1" class="data row8 col1" >mid</td>
#       <td id="T_d956e_row8_col2" class="data row8 col2" >M_best</td>
#       <td id="T_d956e_row8_col3" class="data row8 col3" >C4:I(Biomass ** 2)</td>
#       <td id="T_d956e_row8_col4" class="data row8 col4" >0.577700</td>
#       <td id="T_d956e_row8_col5" class="data row8 col5" >nan</td>
#       <td id="T_d956e_row8_col6" class="data row8 col6" >nan</td>
#       <td id="T_d956e_row8_col7" class="data row8 col7" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d956e_level0_row9" class="row_heading level0 row9" >245</th>
#       <td id="T_d956e_row9_col0" class="data row9 col0" >2018.000000</td>
#       <td id="T_d956e_r
# ---------------------- 2018.0: late --------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _repr_html_(self)
#     214         Hooks into Jupyter notebook rich display system.
#     215         """
# --> 216         return self.render()
#     217
#     218     def render(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in render(self, sparse_index, sparse_columns, **kwargs)
#     270         if sparse_columns is None:
#     271             sparse_columns = get_option("styler.sparse.columns")
# --> 272         return self._render_html(sparse_index, sparse_columns, **kwargs)
#     273
#     274     def set_tooltips(
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _render_html(self, sparse_index, sparse_columns, **kwargs)
#     119         Generates a dict with necessary kwargs passed to jinja2 template.
#     120         """
# --> 121         self._compute()
#     122         # TODO: namespace all the pandas keys
#     123         d = self._translate(sparse_index, sparse_columns)
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style_render.py in _compute(self)
#     158         r = self
#     159         for func, args, kwargs in self._todo:
# --> 160             r = func(self)(*args, **kwargs)
#     161         return r
#     162
#
# ~/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/io/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#    1079
#    1080         if result.shape != data.shape:
# -> 1081             raise ValueError(
#    1082                 f"Function {repr(func)} returned the wrong shape.\n"
#    1083                 f"Result has shape: {result.shape}\n"
#
# ValueError: Function <function style_sig at 0x7f9f4944d310> returned the wrong shape.
# Result has shape: (34,)
# Expected shape:   (34, 8)

# %%
"""
FIGURE: Varibility in crude protein (a) and biomass (b) by sub-season and year
"""
fig, axs = plt.subplots(nrows=2, figsize=(8, 6), sharex=True)
p1 = sns.violinplot(x='season', y='CP_orig', hue='Year', bw=0.5, cut=0, linewidth=0.75, inner=None,
            data=df_wkly_grid_train, ax=axs[0], zorder=10)
#axs[0].fill_between(range(-1, 4), 8, 13, color='#117733', alpha=0.2, edgecolor=None, zorder=0)
p1.fill_between(np.arange(-0.5, 3), 7, 8, color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
p1.fill_between(np.arange(-0.5, 3), 0, 7, color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
p1.set_ylim((5,13))
p1.set_xmargin(0.0)
p1.text(x=-0.9, y=13.0, s='(a)', fontsize=16.0)
h, l = p1.get_legend_handles_labels()
#leg.update_from(p1)
p1_mean = sns.pointplot(x='season', y='CP_orig',  hue='Year', errorbar=None,
          join=False, dodge=0.535, scale=0.4, color='black',
          data=df_wkly_grid_train, ax=axs[0])
p1_mean.legend().remove()
axs[0].set_xlabel(None)
p1.set_ylabel('Crude protein (%)')
p1.legend(h, l)

p2 = sns.violinplot(x='season', y='Biomass_orig', hue='Year', bw=0.5, cut=0, linewidth=0.75, inner=None,
            data=df_wkly_grid_train, ax=axs[1])
#axs[1].fill_between(range(-1, 4), 700, 3500, color='#117733', alpha=0.2, edgecolor=None, zorder=0)
p2.fill_between(np.arange(-0.5, 3), 350, 700, color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
p2.fill_between(np.arange(-0.5, 3), 0, 350, color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
p2.set_ylim((0, 3500))
p2.legend().remove()
p2.set_xmargin(0.0)
p2.text(x=-0.9, y=3750, s='(b)', fontsize=16.0)
p2_mean = sns.pointplot(x='season', y='Biomass_orig',  hue='Year', errorbar=None,
          join=False, dodge=0.535, scale=0.4, color='black',
          data=df_wkly_grid_train, ax=axs[1])
p2_mean.legend().remove()
p2.set_xticklabels([x.get_text() + '-season' for x in p2.get_xticklabels()])
axs[1].set_xlabel(None)
p2.set_ylabel('Biomass (kg/ha)')

#plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/violinplots_CP_BM_X_Year_X_Season.png', 
#            bbox_inches='tight', dpi=300)
# Out:
# Text(0, 0.5, 'Biomass (kg/ha)')

# %%
"""
FIGURE: Covariance in crude protein and biomass by year, sub-season and pasture
"""
def get_cov_ellipse(cov, centre, nstd, **kwargs):
    from matplotlib.patches import Ellipse
    """
    Return a matplotlib Ellipse patch representing the covariance matrix
    cov centred at centre and scaled by the factor nstd.

    """

    # Find and sort eigenvalues and eigenvectors into descending order
    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]

    # The anti-clockwise angle to rotate our ellipse by 
    vx, vy = eigvecs[:,0][0], eigvecs[:,0][1]
    theta = np.arctan2(vy, vx)

    # Width and height of ellipse to draw
    width, height = 2 * nstd * np.sqrt(eigvals)
    return Ellipse(xy=centre, width=width, height=height,
                   angle=np.degrees(theta), **kwargs)

def draw_cov_ellipse(*args, **kwargs):
    data = kwargs.pop('data')
    c = kwargs.pop('color')
    x = kwargs.pop('x')
    y = kwargs.pop('y')
    cov = np.cov(data.dropna(axis=0)[x], data.dropna(axis=0)[y])
    e = get_cov_ellipse(cov, (data.dropna(axis=0)[x].mean(), 
                              data.dropna(axis=0)[y].mean()), 2, fc='none', ec=c, alpha=1.0)
    ax = plt.gca()
    ax.scatter(data.dropna(axis=0)[x], data.dropna(axis=0)[y], s=0.0, alpha=0.3)
    ax.add_artist(e)

g = sns.FacetGrid(data=df_wkly_grid_train,#[df_wkly_grid_train['Pasture'].isin(['17N', '20SE'])],#[df_wkly_grid_train['week'].isin([23, 29, 36])], 
                 col='season', row='Year', hue='Pasture', legend_out=True, margin_titles=True)
g.map_dataframe(sns.scatterplot, x='Biomass_orig', y='CP_orig', edgecolor=None, alpha=0.1, s=4.0).add_legend()
g.map_dataframe(draw_cov_ellipse, x='Biomass_orig', y='CP_orig')#.add_legend()
g.set_xlabels('Biomass (kg/ha)')
g.set_ylabels('Crude protein (%)')

leg = g.legend
for hand in leg.legendHandles:
    hand._sizes = [22.0]
    hand.set_alpha(1.0)

for ax in g.axes.flat:
    ax.fill_between(np.arange(0, 3600), 7, 8,
                       color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
    ax.fill_between(np.arange(0, 3600), 5.5, 7,
                       color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
    ax.fill_between(range(350, 700), 5.5, 12.5, 
                    color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
    ax.fill_between(range(0, 350), 5.5, 12.5, 
                    color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
    plt.setp(ax.texts, text="") # remove the original texts

g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
#plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/covariance_CP_BM_X_Year_X_Season_X_Pasture.png', 
#            bbox_inches='tight', dpi=300)

# %%
"""
FIGURE: Varibility in crude protein (a) and biomass (b) by sub-season across plant communities
"""
fig, axs = plt.subplots(nrows=2, ncols=len(df_wkly_grid_train['Year'].unique()),
                        figsize=(12, 6), sharex=True, gridspec_kw={'right': 0.825})
for idx, yr in enumerate(df_wkly_grid_train['Year'].unique()):
    p1 = sns.violinplot(x='season', y='CP_orig', hue='PC_dmt',  bw=0.5, cut=0, inner=None, linewidth=0.75,
                data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[0, idx],
                       hue_order=['C4', 'C3_C4_mix', 'C3', 'Saltgrass', 'Other'])
    
    axs[0, idx].fill_between(np.arange(-0.5, 3), 7, 8, color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
    axs[0, idx].fill_between(np.arange(-0.5, 3), 0, 7, color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
    handles, labels = axs[0,idx].get_legend_handles_labels()
    labels = ['C4/C3 mix' if x == 'C3_C4_mix' else x for x in labels] 
    p1.legend().remove()
    p1.set_ylim((5,13))
    p1.set_xmargin(0.0)
    p1.set_title(yr, size=12.0)
    p1_mean = sns.pointplot(x='season', y='CP_orig',  hue='PC_dmt', errorbar=None,
                  hue_order=['C4', 'C3_C4_mix', 'C3', 'Saltgrass', 'Other'], join=False, dodge=0.65, scale=0.3, color='black',
                  data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[0, idx])
    p1_mean.legend().remove()
    axs[0,idx].set_ylabel('Crude protein (%)', size=12, labelpad=5)
    axs[0,idx].set_xlabel(None)

    p2 = sns.violinplot(x='season', y='Biomass_orig', hue='PC_dmt',  bw=0.5, cut=0, inner=None, linewidth=0.75,
                data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[1, idx],
                       hue_order=['C4', 'C3_C4_mix', 'C3', 'Saltgrass', 'Other'])
    axs[1,idx].fill_between(np.arange(-0.5, 3), 350, 700, color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
    axs[1,idx].fill_between(np.arange(-0.5, 3), 0, 350, color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
    p2.legend().remove()
    p2.set_ylim((0, 3500))
    p2.set_xmargin(0.0)
    p2_mean = sns.pointplot(x='season', y='Biomass_orig',  hue='PC_dmt', errorbar=None,
              hue_order=['C4', 'C3_C4_mix', 'C3', 'Saltgrass', 'Other'], join=False, dodge=0.65, scale=0.3, color='black',
              data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[1, idx])
    p2_mean.legend().remove()
    axs[1,idx].set_ylabel('Biomass (kg/ha)', size=12, labelpad=5)
    axs[1,idx].set_xlabel(None)

for idx, ax in enumerate(axs.flatten()):
    ax.set_xticklabels(ax.get_xticklabels(), size=12.0)
    ax.set_xticklabels(ax.get_xticklabels(), size=12.0)
    ax.tick_params(axis='y', labelsize=12.0)
    if (idx == 0) | (idx == len(axs.flatten())/axs.shape[0]):
        continue
    else:
        ax.axes.yaxis.set_ticks([])
        ax.set_ylabel('')
    if idx == 4:
        ax.set_xlabel('Sub-season', size=12.0)

fig.legend(handles, labels, loc='center right', 
           title='Plant community', fontsize=12.0, title_fontsize=12.0)
#plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/violinplots_CP_BM_X_Season_X_PCdmt.png', 
#            bbox_inches='tight', dpi=300)

# %%
"""
FIGURE: Varibility in crude protein (a) and biomass (b) by sub-season across plant communities
"""
fig, axs = plt.subplots(nrows=2, ncols=len(df_wkly_grid_train['Year'].unique()),
                        figsize=(12, 6), sharex=True, gridspec_kw={'right': 0.825})
for idx, yr in enumerate(df_wkly_grid_train['Year'].unique()):
    p1 = sns.violinplot(x='season', y='CP_orig', hue='TPC_c',  bw=0.5, cut=0, inner=None, linewidth=0.75,
                data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[0, idx],
                       hue_order=['Highlands', 'Open Slopes', 'Flat Plains', 'Lowlands', 'Other'])
    
    axs[0, idx].fill_between(np.arange(-0.5, 3), 7, 8, color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
    axs[0, idx].fill_between(np.arange(-0.5, 3), 0, 7, color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
    handles, labels = axs[0,idx].get_legend_handles_labels()
    p1.legend().remove()
    p1.set_ylim((5,13))
    p1.set_xmargin(0.0)
    p1.set_title(yr, size=12.0)
    p1_mean = sns.pointplot(x='season', y='CP_orig',  hue='TPC_c', errorbar=None,
                  hue_order=['Highlands', 'Open Slopes', 'Flat Plains', 'Lowlands', 'Other'], join=False, dodge=0.65, scale=0.3, color='black',
                  data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[0, idx])
    p1_mean.legend().remove()
    axs[0,idx].set_ylabel('Crude protein (%)', size=12, labelpad=5)
    axs[0,idx].set_xlabel(None)

    p2 = sns.violinplot(x='season', y='Biomass_orig', hue='TPC_c',  bw=0.5, cut=0, inner=None, linewidth=0.75,
                data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[1, idx],
                       hue_order=['Highlands', 'Open Slopes', 'Flat Plains', 'Lowlands', 'Other'])
    axs[1,idx].fill_between(np.arange(-0.5, 3), 350, 700, color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
    axs[1,idx].fill_between(np.arange(-0.5, 3), 0, 350, color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
    p2.legend().remove()
    p2.set_ylim((0, 3500))
    p2.set_xmargin(0.0)
    p2_mean = sns.pointplot(x='season', y='Biomass_orig',  hue='TPC_c', errorbar=None,
              hue_order=['Highlands', 'Open Slopes', 'Flat Plains', 'Lowlands', 'Other'], join=False, dodge=0.65, scale=0.3, color='black',
              data=df_wkly_grid_train[df_wkly_grid_train['Year'] == yr], ax=axs[1, idx])
    p2_mean.legend().remove()
    axs[1,idx].set_ylabel('Biomass (kg/ha)', size=12, labelpad=5)
    axs[1,idx].set_xlabel(None)

for idx, ax in enumerate(axs.flatten()):
    ax.set_xticklabels(ax.get_xticklabels(), size=12.0)
    ax.set_xticklabels(ax.get_xticklabels(), size=12.0)
    ax.tick_params(axis='y', labelsize=12.0)
    if (idx == 0) | (idx == len(axs.flatten())/axs.shape[0]):
        continue
    else:
        ax.axes.yaxis.set_ticks([])
        ax.set_ylabel('')
    if idx == 4:
        ax.set_xlabel('Sub-season', size=12.0)

fig.legend(handles, labels, loc='center right', 
           title='Topographic position', fontsize=12.0, title_fontsize=12.0)
#plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/violinplots_CP_BM_X_Season_X_TPC.png', 
#            bbox_inches='tight', dpi=300)

# %%
test = df_wkly_grid_train.groupby(
                ['TPC_c', 'PC_dmt']).count()['Year'].reset_index()
test['prop'] = test['Year'] / test.groupby('TPC_c')['Year'].transform('sum')
test = test.pivot(columns='PC_dmt', index='TPC_c', values='prop')

# %%
test.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='TPC_c'>

# %%
"""
Create dataframe of plant community coefficients by model and season
"""

pd.set_option('display.max_rows', 100)
#coefs_PC_seas = df_coefs[df_coefs['Param'].str.contains('C\(PC_dmt\, Treatment\(reference\="C3_C4_mix"\)\)\[.*\]$', regex=True)].copy(deep=True)
coefs_PC_seas = df_coefs_seas[df_coefs_seas['Param'].isin(['C4', 'C3', 'Saltgrass', 'Other'])].copy(deep=True)
#coefs_PC_seas['Param'] = coefs_PC_seas['Param'].apply(lambda x: re.sub('C\(PC_dmt, Treatment\(reference\="C3_C4_mix"\)\)\[T\.', '', x))
#coefs_PC_seas['Param'] = coefs_PC_seas['Param'].apply(lambda x: re.sub('\]', '', x))
#coefs_PC_seas = coefs_PC_seas.groupby(['Year', 'Season', 'week', 'Pasture', 'Model', 'Formula', 'Param']).mean().reset_index()
#coefs_PC_seas = coefs_PC_seas.join(df_coefs_seas.set_index(['Model', 'Year', 'Season', 'Param']).drop(columns=['coef']),
#                                                           on=['Model', 'Year', 'Season', 'Param'])
coefs_PC_seas['season'] = pd.Categorical(coefs_PC_seas['season_str'], ['early', 'mid', 'late'])
coefs_PC_seas['Param'] = pd.Categorical(coefs_PC_seas['Param'], ['C4', 'C3', 'Saltgrass', 'Other'])
coefs_PC_seas_grps = []
for grp, data in coefs_PC_seas[coefs_PC_seas['Model'].isin(['M_best'])].groupby(
    ['Year', 'season', 'Param', 'significant']).mean().reset_index().groupby(['Year', 'season']):
    coefs_PC_seas_grps.append(data.sort_values('Param'))

#coefs_PC_seas_agg = coefs_PC_seas.groupby(['Model', 'Year', 'Season', 'week', 'Pasture', 'Param']).mean().reset_index().dropna().groupby(['Model', 'Season', 'Param'])['coef'].agg(
#    [('coef_mean', np.mean),
#     ('coef_lwr95', lambda x: sms.DescrStatsW(x).zconfint_mean()[0]),
#     ('coef_upr95', lambda x: sms.DescrStatsW(x).zconfint_mean()[1]),
#     ('pval', lambda x: np.round(ttest_1samp(x, 0.0)[1], 4))])#.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14470/2264253989.py in <module>
#       5 pd.set_option('display.max_rows', 100)
#       6 #coefs_PC_seas = df_coefs[df_coefs['Param'].str.contains('C\(PC_dmt\, Treatment\(reference\="C3_C4_mix"\)\)\[.*\]$', regex=True)].copy(deep=True)
# ----> 7 coefs_PC_seas = df_coefs_seas[df_coefs_seas['Param'].isin(['C4', 'C3', 'Saltgrass', 'Other'])].copy(deep=True)
#       8 #coefs_PC_seas['Param'] = coefs_PC_seas['Param'].apply(lambda x: re.sub('C\(PC_dmt, Treatment\(reference\="C3_C4_mix"\)\)\[T\.', '', x))
#       9 #coefs_PC_seas['Param'] = coefs_PC_seas['Param'].apply(lambda x: re.sub('\]', '', x))
#
# NameError: name 'df_coefs_seas' is not defined

# %%
#coefs_PC_seas_best
#df_coefs_seas[(df_coefs_seas['Model'] == 'M_best') & (df_coefs_seas['Year'] == 2016)]

# %%
"""
Figure: Plant community coefficients and 95% CI by sub-season and by pasture for the plant-community-only model (M3_pc) and best model (M5)
"""
coefs_PC_seas_best = coefs_PC_seas[coefs_PC_seas['Model'].isin(['M_best']) &
                                   (coefs_PC_seas['significant'] == 'Yes')].copy(deep=True)
import matplotlib.ticker as ticker
g = sns.FacetGrid(coefs_PC_seas_best, margin_titles=True, height=2.25, aspect=1.5,
                  col='season', row='Year', legend_out=True, sharey=True, gridspec_kws={"hspace":0.25, "wspace":0.1})
#plt.figure()
g.map_dataframe(sns.pointplot, x='coef', y='Param', estimator=np.mean,
                join=False, dodge=None, scale=0.75, errwidth=0.75, ci=None, color='black')

#sns.pointplot()
axs = g.axes
for idx, ax in enumerate(axs.flat):
    #ax.collections[0]
    ax.set_xlim((-1.5, 1.5))
    ax.axvline(x=0, linestyle='dotted', color='black')
    box = ax.get_position()
    #ax.set_position([box.x0, box.y0, box.width, box.height*0.75])
    cur_title = ax.get_title()
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.1f}'.format(x)))
    plt.setp(ax.texts, text="") # remove the original texts
    df_tmp = coefs_PC_seas_grps[idx].copy(deep=True)
    df_tmp['lwr'] = df_tmp['coef'] - df_tmp['coef_ci_lwr']
    df_tmp['upr'] = df_tmp['coef_ci_upr'] - df_tmp['coef'] 
    df_tmp_ns = df_tmp[df_tmp['significant'] == 'No'].copy(deep=True)
    df_tmp = df_tmp[df_tmp['significant'] == 'Yes'].copy(deep=True)
    ax.errorbar(x=df_tmp['coef'],
                y=df_tmp['Param'], 
                xerr=(df_tmp[['lwr', 'upr']].values).transpose(),
                color='black', fmt='o', zorder=0)
    ax.errorbar(x=df_tmp_ns['coef'],
            y=df_tmp_ns['Param'], 
            xerr=(df_tmp_ns[['lwr', 'upr']].values).transpose(), fmt='o', markerfacecolor='white', color='black', zorder=0)

g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
g.set(xticks=np.arange(-1.5, 1.5, 0.5))
g.set_xlabels('Coefficient')
plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/PC_dmt.png', 
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\matplotlib\axes\_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\matplotlib\axes\_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\matplotlib\axes\_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\matplotlib\axes\_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
"""
Create dataframe of topographic position class coefficients by model and season
"""
#coefs_TPC_seas = df_coefs[df_coefs['Param'].str.contains('C\(TPC_c\, Treatment\(reference\="Flat Plains"\)\)\[.*\]$', regex=True)].copy(deep=True)
coefs_TPC_seas = df_coefs_seas[df_coefs_seas['Param'].isin(['Highlands', 'Open Slopes', 'Lowlands', 'Complex'])]
#coefs_TPC_seas['Param'] = coefs_TPC_seas['Param'].apply(lambda x: re.sub('C\(TPC_c, Treatment\(reference\="Flat Plains"\)\)\[T\.', '', x))
#coefs_TPC_seas['Param'] = coefs_TPC_seas['Param'].apply(lambda x: re.sub('\]', '', x))
#coefs_TPC_seas = coefs_TPC_seas.groupby(['Year', 'Season', 'week', 'Pasture', 'Model', 'Formula', 'Param']).mean().reset_index()
#coefs_TPC_seas = coefs_TPC_seas.join(df_coefs_seas.set_index(['Model', 'Year', 'Season', 'Param']).drop(columns=['coef']),
#                                                           on=['Model', 'Year', 'Season', 'Param'])
coefs_TPC_seas['season'] = pd.Categorical(coefs_TPC_seas['season_str'], ['early', 'mid', 'late'])
coefs_TPC_seas['Param'] = pd.Categorical(coefs_TPC_seas['Param'], ['Highlands', 'Open Slopes', 'Lowlands', 'Complex'])
coefs_TPC_seas_grps = []
for grp, data in coefs_TPC_seas[coefs_TPC_seas['Model'].isin(['M_best'])].groupby(
    ['Year', 'season', 'Param', 'significant']).mean().reset_index().groupby(['Year', 'season']):
    coefs_TPC_seas_grps.append(data.sort_values('Param'))
    
#coefs_TPC_seas_agg = coefs_TPC_seas.groupby(['Model','week', 'Season', 'Year',  'Pasture', 'Param']).mean().reset_index().dropna().groupby(['Model', 'Season', 'Param'])['coef'].agg(
#    [('coef_mean', np.mean),
#     ('coef_lwr95', lambda x: sms.DescrStatsW(x).zconfint_mean()[0]),
#     ('coef_upr95', lambda x: sms.DescrStatsW(x).zconfint_mean()[1]),
#     ('pval', lambda x: np.round(ttest_1samp(x, 0.0)[1], 4))])#.reset_index()
#coefs_TPC_seas_agg[coefs_TPC_seas_agg.index.isin(['M1', 'M_best'], level='Model')].dropna()
# Out:
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
#coefs_TPC_seas

# %%
"""
Figure: Plant community coefficients and 95% CI by sub-season and by pasture for the plant-community-only model (M3_pc) and best model (M5)
"""
coefs_TPC_seas_best = coefs_TPC_seas[coefs_TPC_seas['Model'].isin(['M_best']) & (coefs_TPC_seas['significant'] == 'Yes')].copy(deep=True)
import matplotlib.ticker as ticker
g = sns.FacetGrid(coefs_TPC_seas_best, margin_titles=True, height=2.25, aspect=1.5,
                  col='season', row='Year', legend_out=True, sharey=True, gridspec_kws={"hspace":0.25, "wspace":0.1})
#plt.figure()
g.map_dataframe(sns.pointplot, x='coef', y='Param', estimator=np.mean,
                join=False, dodge=None, scale=0.75, errwidth=0.75, ci=None, color='black')

#sns.pointplot()
axs = g.axes
for idx, ax in enumerate(axs.flat):
    #ax.collections[0]
    ax.set_xlim((-1.5, 1.5))
    ax.axvline(x=0, linestyle='dotted', color='black')
    box = ax.get_position()
    #ax.set_position([box.x0, box.y0, box.width, box.height*0.75])
    cur_title = ax.get_title()
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.1f}'.format(x)))
    plt.setp(ax.texts, text="") # remove the original texts
    df_tmp = coefs_TPC_seas_grps[idx].copy(deep=True)
    df_tmp['lwr'] = df_tmp['coef'] - df_tmp['coef_ci_lwr']
    df_tmp['upr'] = df_tmp['coef_ci_upr'] - df_tmp['coef'] 
    df_tmp_ns = df_tmp[df_tmp['significant'] == 'No'].copy(deep=True)
    df_tmp = df_tmp[df_tmp['significant'] == 'Yes'].copy(deep=True)
    ax.errorbar(x=df_tmp['coef'],
                y=df_tmp['Param'], 
                xerr=(df_tmp[['lwr', 'upr']].values).transpose(),
                color='black', fmt='o', zorder=0)
    ax.errorbar(x=df_tmp_ns['coef'],
            y=df_tmp_ns['Param'], 
            xerr=(df_tmp_ns[['lwr', 'upr']].values).transpose(), fmt='o', markerfacecolor='white', color='black', zorder=0)

g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
g.set(xticks=np.arange(-1.5, 1.5, 0.5))
g.set_xlabels('Coefficient')
plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/TPC.png', 
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\matplotlib\axes\_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\matplotlib\axes\_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
"""
Check if biomass and CP are significant in M_best models
"""
display(df_coefs_seas[(df_coefs_seas['Model'] == 'M_best') &
              (df_coefs_seas['Param'].str.contains('CP'))].sort_values(['Year', 'season']))
display(df_coefs_seas[(df_coefs_seas['Model'] == 'M_best') &
              (df_coefs_seas['Param'].str.contains('Biomass'))].sort_values(['Year', 'season']))
# Out:
#                  Param    coef  std err       z  P>|z|  [0.025  0.975]  \
# 21                  CP  0.0535    0.045   1.196  0.232  -0.034   0.141
# 22               C3:CP -0.1436    0.157  -0.912  0.362  -0.452   0.165
# 23               C4:CP  0.3825    0.055   6.916  0.000   0.274   0.491
# 24            Other:CP  0.3873    0.169   2.292  0.022   0.056   0.718
# 25        Saltgrass:CP  0.2093    0.086   2.445  0.014   0.042   0.377
# 26          Biomass:CP  0.1096    0.024   4.641  0.000   0.063   0.156
# 27  I(Biomass ** 2):CP  0.0317    0.013   2.464  0.014   0.006   0.057
# 35           PC_div:CP -0.0652    0.024  -2.685  0.007  -0.113  -0.018
# 13                  CP  0.2236    0.046   4.905  0.000   0.134   0.313
# 14               C3:CP -0.3413    0.094  -3.636  0.000  -0.525  -0.157
# 15               C4:CP  0.2613    0.063   4.145  0.000   0.138   0.385
# 16            Other:CP  0.2530    0.154   1.647  0.100  -0.048   0.554
# 17        Saltgrass:CP  0.2437    0.072   3.392  0.001   0.103   0.385
# 18          Biomass:CP  0.0847    0.032   2.666  0.008   0.022   0.147
# 19  I(Biomass ** 2):CP -0.0110    0.006  -1.808  0.071  -0.023   0.001
# 21                  CP -0.5101    0.049 -10.423  0.000  -0.606  -0.414
# 22               C3:CP -0.0479    0.126  -0.381  0.703  -0.294   0.198
# 23               C4:CP  0.1326    0.071   1.880  0.060  -0.006   0.271
# 24            Other:CP  0.8122    0.168   4.835  0.000   0.483   1.141
# 25        Saltgrass:CP  0.4684    0.077   6.069  0.000   0.317   0.620
# 26          Biomass:CP  0.1068    0.033   3.265  0.001   0.043   0.171
# 27  I(Biomass ** 2):CP  0.0257    0.006   4.098  0.000   0.013   0.038
# 35           PC_div:CP  0.0090    0.025   0.351  0.725  -0.041   0.059
# 21                  CP -0.0629    0.050  -1.247  0.212  -0.162   0.036
# 22               C3:CP  0.4731    0.178   2.663  0.008   0.125   0.821
# 23               C4:CP  0.1165    0.069   1.697  0.090  -0.018   0.251
# 24            Other:CP -0.3105    0.104  -2.992  0.003  -0.514  -0.107
# 25        Saltgrass:CP  0.7159    0.098   7.312  0.000   0.524   0.908
# 26          Biomass:CP  0.0247    0.031   0.790  0.429  -0.037   0.086
# 27  I(Biomass ** 2):CP -0.0056    0.005  -1.072  0.284  -0.016   0.005
# 35           PC_div:CP  0.1197    0.029   4.146  0.000   0.063   0.176
# 21                  CP  0.2356    0.044   5.411  0.000   0.150   0.321
# 22               C3:CP -0.1806    0.227  -0.795  0.427  -0.626   0.265
# 23               C4:CP -0.1068    0.056  -1.909  0.056  -0.216   0.003
# 24            Other:CP  0.4480    0.123   3.629  0.000   0.206   0.690
# 25        Saltgrass:CP  0.2522    0.096   2.623  0.009   0.064   0.441
# 26          Biomass:CP  0.1358    0.033   4.149  0.000   0.072   0.200
# 27  I(Biomass ** 2):CP -0.0137    0.007  -1.916  0.055  -0.028   0.000
# 35           PC_div:CP  0.0323    0.024   1.334  0.182  -0.015   0.080
# 13                  CP  0.1688    0.035   4.856  0.000   0.101   0.237
# 14          Biomass:CP -0.0119    0.040  -0.302  0.763  -0.089   0.066
# 15  I(Biomass ** 2):CP  0.0110    0.008   1.304  0.192  -0.006   0.027
# 21                  CP  0.0550    0.045   1.208  0.227  -0.034   0.144
# 22               C3:CP  0.4831    0.308   1.568  0.117  -0.121   1.087
# 23               C4:CP  0.0179    0.066   0.271  0.786  -0.112   0.148
# 24            Other:CP  0.3430    0.253   1.356  0.175  -0.153   0.839
# 25        Saltgrass:CP  1.3039    0.165   7.898  0.000   0.980   1.627
# 26          Biomass:CP  0.3169    0.051   6.223  0.000   0.217   0.417
# 27  I(Biomass ** 2):CP -0.0396    0.018  -2.154  0.031  -0.076  -0.004
# 13                  CP  0.0817    0.021   3.824  0.000   0.040   0.124
# 14          Biomass:CP  0.1075    0.019   5.728  0.000   0.071   0.144
# 15  I(Biomass ** 2):CP -0.0108    0.004  -2.608  0.009  -0.019  -0.003
# 21                  CP -0.0790    0.037  -2.150  0.032  -0.151  -0.007
# 22               C3:CP  0.1267    0.104   1.218  0.223  -0.077   0.330
# 23               C4:CP  0.1552    0.055   2.809  0.005   0.047   0.263
# 24            Other:CP  0.2206    0.118   1.872  0.061  -0.010   0.451
# 25        Saltgrass:CP  0.2308    0.089   2.581  0.010   0.056   0.406
# 26          Biomass:CP  0.0272    0.025   1.082  0.279  -0.022   0.076
# 27  I(Biomass ** 2):CP  0.0024    0.005   0.499  0.618  -0.007   0.012
# 35           PC_div:CP -0.0523    0.025  -2.133  0.033  -0.100  -0.004
#
#    season_str  Year   Model  coef_ci_lwr  coef_ci_upr significant season
# 21      early  2016  M_best       -0.034        0.141          No  early
# 22      early  2016  M_best       -0.452        0.165          No  early
# 23      early  2016  M_best        0.274        0.491         Yes  early
# 24      early  2016  M_best        0.056        0.718         Yes  early
# 25      early  2016  M_best        0.042        0.377         Yes  early
# 26      early  2016  M_best        0.063        0.156         Yes  early
# 27      early  2016  M_best        0.006        0.057         Yes  early
# 35      early  2016  M_best       -0.113       -0.018         Yes  early
# 13        mid  2016  M_best        0.134        0.313         Yes    mid
# 14        mid  2016  M_best       -0.525       -0.157         Yes    mid
# 15        mid  2016  M_best        0.138        0.385         Yes    mid
# 16        mid  2016  M_best       -0.048        0.554          No    mid
# 17        mid  2016  M_best        0.103        0.385         Yes    mid
# 18        mid  2016  M_best        0.022        0.147         Yes    mid
# 19        mid  2016  M_best       -0.023        0.001          No    mid
# 21       late  2016  M_best       -0.606       -0.414         Yes   late
# 22       late  2016  M_best       -0.294        0.198          No   late
# 23       late  2016  M_best       -0.006        0.271          No   late
# 24       late  2016  M_best        0.483        1.141         Yes   late
# 25       late  2016  M_best        0.317        0.620         Yes   late
# 26       late  2016  M_best        0.043        0.171         Yes   late
# 27       late  2016  M_best        0.013        0.038         Yes   late
# 35       late  2016  M_best       -0.041        0.059          No   late
# 21      early  2017  M_best       -0.162        0.036          No  early
# 22      early  2017  M_best        0.125        0.821         Yes  early
# 23      early  2017  M_best       -0.018        0.251          No  early
# 24      early  2017  M_best       -0.514       -0.107         Yes  early
# 25      early  2017  M_best        0.524        0.908         Yes  early
# 26      early  2017  M_best       -0.037        0.086          No  early
# 27      early  2017  M_best       -0.016        0.005          No  early
# 35      early  2017  M_best        0.063        0.176         Yes  early
# 21        mid  2017  M_best        0.150        0.321         Yes    mid
# 22        mid  2017  M_best       -0.626        0.265          No    mid
# 23        mid  2017  M_best       -0.216        0.003          No    mid
# 24        mid  2017  M_best        0.206        0.690         Yes    mid
# 25        mid  2017  M_best        0.064        0.441         Yes    mid
# 26        mid  2017  M_best        0.072        0.200         Yes    mid
# 27        mid  2017  M_best       -0.028        0.000          No    mid
# 35        mid  2017  M_best       -0.015        0.080          No    mid
# 13       late  2017  M_best        0.101        0.237         Yes   late
# 14       late  2017  M_best       -0.089        0.066          No   late
# 15       late  2017  M_best       -0.006        0.027          No   late
# 21      early  2018  M_best       -0.034        0.144          No  early
# 22      early  2018  M_best       -0.121        1.087          No  early
# 23      early  2018  M_best       -0.112        0.148          No  early
# 24      early  2018  M_best       -0.153        0.839          No  early
# 25      early  2018  M_best        0.980        1.627         Yes  early
# 26      early  2018  M_best        0.217        0.417         Yes  early
# 27      early  2018  M_best       -0.076       -0.004         Yes  early
# 13        mid  2018  M_best        0.040        0.124         Yes    mid
# 14        mid  2018  M_best        0.071        0.144         Yes    mid
# 15        mid  2018  M_best       -0.019       -0.003         Yes    mid
# 21       late  2018  M_best       -0.151       -0.007         Yes   late
# 22       late  2018  M_best       -0.077        0.330          No   late
# 23       late  2018  M_best        0.047        0.263         Yes   late
# 24       late  2018  M_best       -0.010        0.451          No   late
# 25       late  2018  M_best        0.056        0.406         Yes   late
# 26       late  2018  M_best       -0.022        0.076          No   late
# 27       late  2018  M_best       -0.007        0.012          No   late
# 35       late  2018  M_best       -0.100       -0.004         Yes   late
#                         Param    coef  std err       z  P>|z|  [0.025  0.975]  \
# 11                    Biomass -0.1782    0.024  -7.363  0.000  -0.226  -0.131
# 12                 C3:Biomass -0.0861    0.070  -1.228  0.220  -0.223   0.051
# 13                 C4:Biomass  0.0828    0.031   2.653  0.008   0.022   0.144
# 14              Other:Biomass -0.2329    0.082  -2.851  0.004  -0.393  -0.073
# 15          Saltgrass:Biomass  0.2801    0.077   3.635  0.000   0.129   0.431
# 16            I(Biomass ** 2)  0.0721    0.015   4.677  0.000   0.042   0.102
# 17         C3:I(Biomass ** 2) -0.0989    0.043  -2.324  0.020  -0.182  -0.015
# 18         C4:I(Biomass ** 2)  0.0478    0.022   2.210  0.027   0.005   0.090
# 19      Other:I(Biomass ** 2) -0.0586    0.024  -2.439  0.015  -0.106  -0.012
# 20  Saltgrass:I(Biomass ** 2) -0.0847    0.030  -2.850  0.004  -0.143  -0.026
# 26                 Biomass:CP  0.1096    0.024   4.641  0.000   0.063   0.156
# 27         I(Biomass ** 2):CP  0.0317    0.013   2.464  0.014   0.006   0.057
# 33             PC_div:Biomass -0.0237    0.014  -1.679  0.093  -0.051   0.004
# 34     PC_div:I(Biomass ** 2)  0.0042    0.007   0.575  0.566  -0.010   0.019
# 11                    Biomass -0.3112    0.017 -18.624  0.000  -0.344  -0.278
# 12            I(Biomass ** 2)  0.0381    0.014   2.743  0.006   0.011   0.065
# 18                 Biomass:CP  0.0847    0.032   2.666  0.008   0.022   0.147
# 19         I(Biomass ** 2):CP -0.0110    0.006  -1.808  0.071  -0.023   0.001
# 11                    Biomass  0.0109    0.032   0.344  0.731  -0.051   0.073
# 12                 C3:Biomass -0.0896    0.065  -1.377  0.169  -0.217   0.038
# 13                 C4:Biomass -0.4052    0.061  -6.599  0.000  -0.526  -0.285
# 14              Other:Biomass -0.5192    0.089  -5.831  0.000  -0.694  -0.345
# 15          Saltgrass:Biomass -0.0489    0.098  -0.498  0.618  -0.241   0.143
# 16            I(Biomass ** 2)  0.0197    0.026   0.770  0.441  -0.030   0.070
# 17         C3:I(Biomass ** 2) -0.0814    0.034  -2.375  0.018  -0.149  -0.014
# 18         C4:I(Biomass ** 2) -0.0282    0.046  -0.617  0.537  -0.118   0.061
# 19      Other:I(Biomass ** 2) -0.1957    0.037  -5.328  0.000  -0.268  -0.124
# 20  Saltgrass:I(Biomass ** 2) -0.2078    0.040  -5.195  0.000  -0.286  -0.129
# 26                 Biomass:CP  0.1068    0.033   3.265  0.001   0.043   0.171
# 27         I(Biomass ** 2):CP  0.0257    0.006   4.098  0.000   0.013   0.038
# 33             PC_div:Biomass -0.0162    0.018  -0.910  0.363  -0.051   0.019
# 34     PC_div:I(Biomass ** 2) -0.0120    0.007  -1.729  0.084  -0.026   0.002
# 11                    Biomass -0.2375    0.036  -6.649  0.000  -0.307  -0.167
# 12                 C3:Biomass  0.0527    0.084   0.626  0.531  -0.112   0.218
# 13                 C4:Biomass -0.2803    0.050  -5.626  0.000  -0.378  -0.183
# 14              Other:Biomass -0.0646    0.080  -0.808  0.419  -0.221   0.092
# 15          Saltgrass:Biomass -0.1154    0.086  -1.346  0.178  -0.283   0.053
# 16            I(Biomass ** 2)  0.0726    0.019   3.780  0.000   0.035   0.110
# 17         C3:I(Biomass ** 2)  0.0194    0.046   0.419  0.675  -0.071   0.110
# 18         C4:I(Biomass ** 2)  0.0951    0.041   2.344  0.019   0.016   0.175
# 19      Other:I(Biomass ** 2) -0.0251    0.024  -1.061  0.288  -0.072   0.021
# 20  Saltgrass:I(Biomass ** 2) -0.0407    0.026  -1.577  0.115  -0.091   0.010
# 26                 Biomass:CP  0.0247    0.031   0.790  0.429  -0.037   0.086
# 27         I(Biomass ** 2):CP -0.0056    0.005  -1.072  0.284  -0.016   0.005
# 33             PC_div:Biomass  0.0242    0.018   1.343  0.179  -0.011   0.060
# 34     PC_div:I(Biomass ** 2) -0.0079    0.003  -2.261  0.024  -0.015  -0.001
# 11                    Biomass -0.3473    0.045  -7.693  0.000  -0.436  -0.259
# 12                 C3:Biomass  0.0417    0.114   0.367  0.714  -0.181   0.265
# 13                 C4:Biomass -0.1744    0.063  -2.767  0.006  -0.298  -0.051
# 14              Other:Biomass -0.4013    0.130  -3.093  0.002  -0.656  -0.147
# 15          Saltgrass:Biomass -0.2907    0.115  -2.521  0.012  -0.517  -0.065
# 16            I(Biomass ** 2) -0.0610    0.028  -2.213  0.027  -0.115  -0.007
# 17         C3:I(Biomass ** 2) -0.0113    0.044  -0.256  0.798  -0.098   0.075
# 18         C4:I(Biomass ** 2)  0.0398    0.050   0.797  0.425  -0.058   0.138
# 19      Other:I(Biomass ** 2)  0.1243    0.032   3.880  0.000   0.062   0.187
# 20  Saltgrass:I(Biomass ** 2)  0.1152    0.036   3.240  0.001   0.046   0.185
# 26                 Biomass:CP  0.1358    0.033   4.149  0.000   0.072   0.200
# 27         I(Biomass ** 2):CP -0.0137    0.007  -1.916  0.055  -0.028   0.000
# 33             PC_div:Biomass  0.0652    0.023   2.842  0.004   0.020   0.110
# 34     PC_div:I(Biomass ** 2) -0.0032    0.005  -0.662  0.508  -0.013   0.006
# 11                    Biomass -0.2991    0.023 -13.248  0.000  -0.343  -0.255
# 12            I(Biomass ** 2)  0.0489    0.011   4.485  0.000   0.028   0.070
# 14                 Biomass:CP -0.0119    0.040  -0.302  0.763  -0.089   0.066
# 15         I(Biomass ** 2):CP  0.0110    0.008   1.304  0.192  -0.006   0.027
# 21             PC_div:Biomass  0.0048    0.020   0.235  0.814  -0.035   0.045
# 22     PC_div:I(Biomass ** 2) -0.0114    0.006  -2.005  0.045  -0.022  -0.000
# 11                    Biomass -0.3566    0.034 -10.452  0.000  -0.423  -0.290
# 12                 C3:Biomass  0.0230    0.098   0.234  0.815  -0.170   0.216
# 13                 C4:Biomass  0.0011    0.056   0.020  0.984  -0.109   0.111
# 14              Other:Biomass -0.0284    0.124  -0.229  0.819  -0.272   0.215
# 15          Saltgrass:Biomass  0.0144    0.099   0.146  0.884  -0.179   0.208
# 16            I(Biomass ** 2)  0.0820    0.028   2.929  0.003   0.027   0.137
# 17         C3:I(Biomass ** 2) -0.0025    0.056  -0.045  0.964  -0.112   0.107
# 18         C4:I(Biomass ** 2)  0.1196    0.053   2.253  0.024   0.016   0.224
# 19      Other:I(Biomass ** 2) -0.0327    0.036  -0.915  0.360  -0.103   0.037
# 20  Saltgrass:I(Biomass ** 2) -0.0386    0.037  -1.057  0.290  -0.110   0.033
# 26                 Biomass:CP  0.3169    0.051   6.223  0.000   0.217   0.417
# 27         I(Biomass ** 2):CP -0.0396    0.018  -2.154  0.031  -0.076  -0.004
# 11                    Biomass -0.3351    0.023 -14.711  0.000  -0.380  -0.290
# 12            I(Biomass ** 2)  0.0478    0.017   2.772  0.006   0.014   0.082
# 14                 Biomass:CP  0.1075    0.019   5.728  0.000   0.071   0.144
# 15         I(Biomass ** 2):CP -0.0108    0.004  -2.608  0.009  -0.019  -0.003
# 21             PC_div:Biomass  0.0242    0.019   1.267  0.205  -0.013   0.062
# 22     PC_div:I(Biomass ** 2) -0.0031    0.006  -0.484  0.628  -0.015   0.009
# 11                    Biomass -0.2230    0.037  -6.101  0.000  -0.295  -0.151
# 12                 C3:Biomass  0.1642    0.079   2.081  0.037   0.010   0.319
# 13                 C4:Biomass -0.0034    0.048  -0.070  0.944  -0.098   0.091
# 14              Other:Biomass  0.2739    0.093   2.954  0.003   0.092   0.456
# 15          Saltgrass:Biomass  0.1369    0.082   1.675  0.094  -0.023   0.297
# 16            I(Biomass ** 2)  0.0538    0.023   2.371  0.018   0.009   0.098
# 17         C3:I(Biomass ** 2) -0.1047    0.035  -3.005  0.003  -0.173  -0.036
# 18         C4:I(Biomass ** 2) -0.1936    0.036  -5.370  0.000  -0.264  -0.123
# 19      Other:I(Biomass ** 2) -0.0836    0.032  -2.574  0.010  -0.147  -0.020
# 20  Saltgrass:I(Biomass ** 2) -0.0685    0.032  -2.146  0.032  -0.131  -0.006
# 26                 Biomass:CP  0.0272    0.025   1.082  0.279  -0.022   0.076
# 27         I(Biomass ** 2):CP  0.0024    0.005   0.499  0.618  -0.007   0.012
# 33             PC_div:Biomass  0.0526    0.017   3.116  0.002   0.020   0.086
# 34     PC_div:I(Biomass ** 2) -0.0039    0.006  -0.688  0.491  -0.015   0.007
#
#    season_str  Year   Model  coef_ci_lwr  coef_ci_upr significant season
# 11      early  2016  M_best       -0.226       -0.131         Yes  early
# 12      early  2016  M_best       -0.223        0.051          No  early
# 13      early  2016  M_best        0.022        0.144         Yes  early
# 14      early  2016  M_best       -0.393       -0.073         Yes  early
# 15      early  2016  M_best        0.129        0.431         Yes  early
# 16      early  2016  M_best        0.042        0.102         Yes  early
# 17      early  2016  M_best       -0.182       -0.015         Yes  early
# 18      early  2016  M_best        0.005        0.090         Yes  early
# 19      early  2016  M_best       -0.106       -0.012         Yes  early
# 20      early  2016  M_best       -0.143       -0.026         Yes  early
# 26      early  2016  M_best        0.063        0.156         Yes  early
# 27      early  2016  M_best        0.006        0.057         Yes  early
# 33      early  2016  M_best       -0.051        0.004          No  early
# 34      early  2016  M_best       -0.010        0.019          No  early
# 11        mid  2016  M_best       -0.344       -0.278         Yes    mid
# 12        mid  2016  M_best        0.011        0.065         Yes    mid
# 18        mid  2016  M_best        0.022        0.147         Yes    mid
# 19        mid  2016  M_best       -0.023        0.001          No    mid
# 11       late  2016  M_best       -0.051        0.073          No   late
# 12       late  2016  M_best       -0.217        0.038          No   late
# 13       late  2016  M_best       -0.526       -0.285         Yes   late
# 14       late  2016  M_best       -0.694       -0.345         Yes   late
# 15       late  2016  M_best       -0.241        0.143          No   late
# 16       late  2016  M_best       -0.030        0.070          No   late
# 17       late  2016  M_best       -0.149       -0.014         Yes   late
# 18       late  2016  M_best       -0.118        0.061          No   late
# 19       late  2016  M_best       -0.268       -0.124         Yes   late
# 20       late  2016  M_best       -0.286       -0.129         Yes   late
# 26       late  2016  M_best        0.043        0.171         Yes   late
# 27       late  2016  M_best        0.013        0.038         Yes   late
# 33       late  2016  M_best       -0.051        0.019          No   late
# 34       late  2016  M_best       -0.026        0.002          No   late
# 11      early  2017  M_best       -0.307       -0.167         Yes  early
# 12      early  2017  M_best       -0.112        0.218          No  early
# 13      early  2017  M_best       -0.378       -0.183         Yes  early
# 14      early  2017  M_best       -0.221        0.092          No  early
# 15      early  2017  M_best       -0.283        0.053          No  early
# 16      early  2017  M_best        0.035        0.110         Yes  early
# 17      early  2017  M_best       -0.071        0.110          No  early
# 18      early  2017  M_best        0.016        0.175         Yes  early
# 19      early  2017  M_best       -0.072        0.021          No  early
# 20      early  2017  M_best       -0.091        0.010          No  early
# 26      early  2017  M_best       -0.037        0.086          No  early
# 27      early  2017  M_best       -0.016        0.005          No  early
# 33      early  2017  M_best       -0.011        0.060          No  early
# 34      early  2017  M_best       -0.015       -0.001         Yes  early
# 11        mid  2017  M_best       -0.436       -0.259         Yes    mid
# 12        mid  2017  M_best       -0.181        0.265          No    mid
# 13        mid  2017  M_best       -0.298       -0.051         Yes    mid
# 14        mid  2017  M_best       -0.656       -0.147         Yes    mid
# 15        mid  2017  M_best       -0.517       -0.065         Yes    mid
# 16        mid  2017  M_best       -0.115       -0.007         Yes    mid
# 17        mid  2017  M_best       -0.098        0.075          No    mid
# 18        mid  2017  M_best       -0.058        0.138          No    mid
# 19        mid  2017  M_best        0.062        0.187         Yes    mid
# 20        mid  2017  M_best        0.046        0.185         Yes    mid
# 26        mid  2017  M_best        0.072        0.200         Yes    mid
# 27        mid  2017  M_best       -0.028        0.000          No    mid
# 33        mid  2017  M_best        0.020        0.110         Yes    mid
# 34        mid  2017  M_best       -0.013        0.006          No    mid
# 11       late  2017  M_best       -0.343       -0.255         Yes   late
# 12       late  2017  M_best        0.028        0.070         Yes   late
# 14       late  2017  M_best       -0.089        0.066          No   late
# 15       late  2017  M_best       -0.006        0.027          No   late
# 21       late  2017  M_best       -0.035        0.045          No   late
# 22       late  2017  M_best       -0.022       -0.000          No   late
# 11      early  2018  M_best       -0.423       -0.290         Yes  early
# 12      early  2018  M_best       -0.170        0.216          No  early
# 13      early  2018  M_best       -0.109        0.111          No  early
# 14      early  2018  M_best       -0.272        0.215          No  early
# 15      early  2018  M_best       -0.179        0.208          No  early
# 16      early  2018  M_best        0.027        0.137         Yes  early
# 17      early  2018  M_best       -0.112        0.107          No  early
# 18      early  2018  M_best        0.016        0.224         Yes  early
# 19      early  2018  M_best       -0.103        0.037          No  early
# 20      early  2018  M_best       -0.110        0.033          No  early
# 26      early  2018  M_best        0.217        0.417         Yes  early
# 27      early  2018  M_best       -0.076       -0.004         Yes  early
# 11        mid  2018  M_best       -0.380       -0.290         Yes    mid
# 12        mid  2018  M_best        0.014        0.082         Yes    mid
# 14        mid  2018  M_best        0.071        0.144         Yes    mid
# 15        mid  2018  M_best       -0.019       -0.003         Yes    mid
# 21        mid  2018  M_best       -0.013        0.062          No    mid
# 22        mid  2018  M_best       -0.015        0.009          No    mid
# 11       late  2018  M_best       -0.295       -0.151         Yes   late
# 12       late  2018  M_best        0.010        0.319         Yes   late
# 13       late  2018  M_best       -0.098        0.091          No   late
# 14       late  2018  M_best        0.092        0.456         Yes   late
# 15       late  2018  M_best       -0.023        0.297          No   late
# 16       late  2018  M_best        0.009        0.098         Yes   late
# 17       late  2018  M_best       -0.173       -0.036         Yes   late
# 18       late  2018  M_best       -0.264       -0.123         Yes   late
# 19       late  2018  M_best       -0.147       -0.020         Yes   late
# 20       late  2018  M_best       -0.131       -0.006         Yes   late
# 26       late  2018  M_best       -0.022        0.076          No   late
# 27       late  2018  M_best       -0.007        0.012          No   late
# 33       late  2018  M_best        0.020        0.086         Yes   late
# 34       late  2018  M_best       -0.015        0.007          No   late

# %%
df_pred_bm_old = df_pred_bm.copy(deep=True)

# %%
"""
Biomass: how does selection change with biomass across pastures and models
"""
ref_TPC = 'Flat Plains'
ref_pc = 'C3_C4_mix'
df_pred_bm = pd.DataFrame(columns=['Year', 'season','dFence_orig', 'dTank_orig', 'Biomass_orig', 'CP_orig','PC_div_orig',
                                'PC_dmt', 'TPC_c', 'Model'])
print('Creating dataset...')
for mod in tqdm(['M_best', 'M4_top', 'M2_top']):
    for yr in yrly_mod_dict:
        for wk in yrly_mod_dict[yr]:
            for past in yrly_mod_dict[yr][wk]:
                df_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) &
                                            (df_wkly_grid_train['week'] == wk) &
                                            (df_wkly_grid_train['Pasture'] == past) &
                                            (df_wkly_grid_train['pred_rel_freq_' + mod].notnull())]
                
                for ref_pc in df_sub['PC_dmt'].unique():
                    if yrly_mod_dict[yr][wk][past][mod].params.index.str.contains('TPC_c').any():
                        for ref_TPC in df_sub['TPC_c'].unique():
                            df_tmp = df_sub[(df_sub['TPC_c'] == ref_TPC) & (df_sub['PC_dmt'] == ref_pc)]
                    else:
                        df_tmp = df_sub[df_sub['PC_dmt'] == ref_pc]
                        ref_TPC = 'All'
                    if len(df_tmp) < 10:
                        continue
                    else:
                        df_pred_bm = df_pred_bm.append(pd.DataFrame({
                            'Year': yr,
                            'week': wk,
                            'Pasture': past,
                            'season': df_tmp['season'].unique()[0],
                            'dFence_orig': df_tmp['dFence_orig'].median(),
                            'dTank_orig': df_tmp['dTank_orig'].median(),
                            'Biomass_orig': np.arange(round(df_tmp['Biomass_orig'].quantile(0.025), -1), 
                                                      round(df_tmp['Biomass_orig'].quantile(0.975), -1),  10),
                            'CP_orig': df_tmp['CP_orig'].median(),
                            'PC_div_orig': df_tmp['PC_div_orig'].median(),
                            'PC_dmt': ref_pc,
                            'TPC_c': ref_TPC,
                            'subset_wt': len(df_tmp)/len(df_sub),
                            'Model': mod
                        }))
                if len(df_sub) > 0:
                        continue
                else:
                    for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
                        scaler = scaler_dict[yr][df_sub['season'].unique()[0]][c]
                        df_pred_bm.loc[(df_pred_bm['Year'] == yr) & 
                                    (df_pred_bm['week'] == wk) &
                                    (df_pred_bm['Pasture'] == past), c] = scaler.transform(
                            df_pred_bm.loc[(df_pred_bm['Year'] == yr) & 
                                        (df_pred_bm['week'] == wk) &
                                        (df_pred_bm['Pasture'] == past), c + '_orig'].values.reshape(-1, 1)).flatten()
                    df_pred_bm.loc[(df_pred_bm['Year'] == yr) & 
                                (df_pred_bm['week'] == wk) &
                                (df_pred_bm['Pasture'] == past) &
                                (df_pred_bm['Model'] == mod), 
                                'marg_pred_bm'] = yrly_mod_dict[yr][wk][past][mod].predict(df_pred_bm.loc[(df_pred_bm['Year'] == yr) & 
                                                                                                   (df_pred_bm['week'] == wk) & 
                                                                                                   (df_pred_bm['Pasture'] == past) &
                                                                                                   (df_pred_bm['Model'] == mod)])


"""
Calculate relative frequency from predictions
"""
print('Calculating relative frequencies')
# Out:
# Creating dataset...
#   0%|          | 0/3 [00:00<?, ?it/s]
# Calculating relative frequencies

# %%
#df_pred_bm['season'] = pd.Categorical(df_pred_bm['season'], ['early', 'mid', 'late'])"""
df_pred_bm = df_pred_bm_old
df_pred_bm_old = df_pred_bm.copy(deep=True)
df_pred_bm = df_pred_bm[df_pred_bm['marg_pred_bm'].notnull()].groupby(['Year', 'week', 'season', 'Pasture', 'Model', 'Biomass_orig']).apply(lambda x: pd.Series({'marg_pred_bm':
                                                                                                                 np.average(x['marg_pred_bm'],
                                                                                                                            weights=x['subset_wt'])})).reset_index()

# %%
df_pred_bm['marg_rel_freq_bm_nm'] = df_pred_bm.groupby(['Year', 'week', 'Pasture', 'Model'])['marg_pred_bm'].transform(lambda x: x / np.nanmean(x))
df_pred_bm.loc[df_pred_bm['marg_rel_freq_bm_nm'] > 10, 'marg_rel_freq_bm_nm'] = 10

# %%
#df_pred_bm['marg_rel_freq_bm_nm_old'] = df_pred_bm['marg_rel_freq_bm_nm']

# %%
#df_pred_bm['marg_rel_freq_bm_nm'] = df_pred_bm.groupby(['Year', 'week', 'Pasture', 'Model'])['marg_pred_bm'].transform(lambda x: x / np.mean(x))
#df_pred_bm.loc[df_pred_bm['marg_rel_freq_bm_nm'] > 10, 'marg_rel_freq_bm_nm'] = 10

# %%
#pd.set_option('display.max_rows', None)
#df_pred_bm.groupby(['Year', 'Pasture', 'week'])['Model'].value_counts()

# %%
df_pred_bm[(df_pred_bm['Model'] == 'M_best') &
           (df_pred_bm['Pasture'] == '7NW') &
           (df_pred_bm['season'] == 'early')].groupby(['week'])[['marg_rel_freq_bm_nm', 'Biomass_orig']].max()
# Out:
#       marg_rel_freq_bm_nm  Biomass_orig
# week
# 20.0             1.344834        2090.0
# 21.0             1.801799        2290.0
# 22.0             2.696062        2380.0
# 23.0             3.004738        2130.0
# 24.0             3.001315        2190.0
# 25.0             5.680274        2090.0

# %%
df_wkly_grid_train.columns
# Out:
# Index(['Unnamed: 0', 'Pasture', 'week', 'season_str', 'Year', 'UTM_X', 'UTM_Y',
#        'Biomass', 'CP', 'dFence', 'dTank', 'PC_div', 'Biomass_orig', 'CP_orig',
#        'dFence_orig', 'dTank_orig', 'PC_div_orig', 'TPC_c', 'PC_dmt',
#        'grazing_secs', 'mod_data', 'grazing_wkly_sum', 'grazing_rel_freq',
#        'pred_prop_M2_top', 'pred_prop_M3_top', 'pred_prop_M4_top',
#        'pred_prop_M_best', 'pred_rel_freq_M2_top', 'pred_rel_freq_M3_top',
#        'pred_rel_freq_M4_top', 'pred_rel_freq_M_best', 'grazing_grp',
#        'pred_grp_M2_top', 'pred_grp_M3_top', 'pred_grp_M4_top',
#        'pred_grp_M_best', 'season'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 100)
#df_wkly_grid_train_long2

# %%
cp_bins
# Out:
# array([], dtype=float64)

# %%
bm_bins = np.arange(round(df_wkly_grid_train['Biomass_orig'].min(), -1),
                    round(df_wkly_grid_train['Biomass_orig'].max(), -1), 50)
bm_bin_labs = np.arange(len(bm_bins)-1)
bm_bin_vals = pd.cut(df_wkly_grid_train['Biomass_orig'], 
                                          bins=bm_bins, 
                                          labels=bm_bin_labs,
                                          include_lowest=True).values
df_wkly_grid_train.loc[:, 'bm_bin'] = bm_bin_vals

cp_bins = np.arange(int(df_wkly_grid_train['CP_orig'].min()),
                    np.ceil(df_wkly_grid_train['CP_orig'].max()), 0.5)
cp_bin_labs = np.arange(len(cp_bins)-1)
cp_bin_vals = pd.cut(df_wkly_grid_train['CP_orig'], 
                                          bins=cp_bins, 
                                          labels=cp_bin_labs,
                                          include_lowest=True).values
df_wkly_grid_train.loc[:, 'cp_bin'] = cp_bin_vals
# Out:
# /home/spkearney/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
df_wkly_grid_train_long2 = pd.wide_to_long(df_wkly_grid_train, stubnames='pred_rel_freq', 
                i='Unnamed: 0',
                j='mod_pred_grp', sep='_', suffix='.*').reset_index()

# %%
df_wkly_grid_train['cp_bin_ct'] = df_wkly_grid_train.groupby(['Year', 'season', 'cp_bin'])['bm_bin'].transform(lambda x: np.sum(x.notnull()))
# Out:
# /tmp/ipykernel_19719/3427406746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wkly_grid_train['cp_bin_ct'] = df_wkly_grid_train.groupby(['Year', 'season', 'cp_bin'])['bm_bin'].transform(lambda x: np.sum(x.notnull()))

# %%
t_dat = df_wkly_grid_train_long2[
           (df_wkly_grid_train_long2['Pasture'] == '7NW') &
           (df_wkly_grid_train_long2['season'] == 'early') &
           (df_wkly_grid_train_long2['week'] == 25) &
           (df_wkly_grid_train_long2['Year'] == 2016)]#.sort_values('Biomass_orig').plot(x='Biomass_orig', y='pred_rel_freq_M_best')
bm_bins = np.arange(round(df_wkly_grid_train['Biomass_orig'].min(), -1),
                    round(df_wkly_grid_train['Biomass_orig'].max(), -1), 50)
bm_bin_labs = np.arange(len(bm_bins)-1)
t_dat['bm_bin'] = pd.cut(t_dat['Biomass_orig'], 
                                          bins=bm_bins, 
                                          labels=bm_bin_labs,
                                          include_lowest=True)
#g = sns.FacetGrid(data=t_dat.groupby(['mod_pred_grp', 'bm_bin']).mean().reset_index(), hue='mod_pred_grp')
#g.map_dataframe(sns.regplot, x='Biomass_orig', y='pred_rel_freq', order=2)
p_dat = df_wkly_grid_train[df_wkly_grid_train['cp_bin_ct'] > 2500].groupby(['Year', 'season', 'Pasture', 'bm_bin', 'cp_bin']).mean().reset_index()
#p_dat = p_dat
g = sns.FacetGrid(p_dat, 
                      col='season', row='Year', hue='cp_bin', 
                      col_order=['early', 'mid', 'late'],
                      #hue_order=['7NW', '15E', '17N', '20SE', '25SE', '26E', '31E'],
                      margin_titles=True,
                      legend_out=True, sharey=False, sharex=True, palette=sns.color_palette('viridis'),
                      height=2.25, aspect=1.75, gridspec_kws={"hspace":0.2, "wspace":0.0})
g.map_dataframe(sns.regplot, x='Biomass_orig', y='pred_rel_freq_M2_top',
                line_kws={'linewidth': 1}, n_boot=25, ci=None, #x_bins=10, x_ci='sd',
                order=3, scatter=True, scatter_kws={'s': 2, 
                                                    'alpha': 0.25,
                                                    'marker': 'o',
                                                    'edgecolor': 'None'}).add_legend()
# Out:
# /tmp/ipykernel_19719/3421448586.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_dat['bm_bin'] = pd.cut(t_dat['Biomass_orig'],
# /home/spkearney/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self._figure.tight_layout(*args, **kwargs)
# /home/spkearney/miniconda3/envs/py_geo_env/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self._figure.tight_layout(*args, **kwargs)

# %%
bm_bins
# Out:
# array([ 160.,  210.,  260.,  310.,  360.,  410.,  460.,  510.,  560.,
#         610.,  660.,  710.,  760.,  810.,  860.,  910.,  960., 1010.,
#        1060., 1110., 1160., 1210., 1260., 1310., 1360., 1410., 1460.,
#        1510., 1560., 1610., 1660., 1710., 1760., 1810., 1860., 1910.,
#        1960., 2010., 2060., 2110., 2160., 2210., 2260., 2310., 2360.,
#        2410., 2460., 2510., 2560., 2610., 2660., 2710., 2760., 2810.,
#        2860., 2910., 2960., 3010., 3060., 3110., 3160., 3210., 3260.,
#        3310., 3360., 3410., 3460., 3510., 3560., 3610., 3660., 3710.,
#        3760., 3810., 3860., 3910., 3960., 4010., 4060., 4110., 4160.,
#        4210., 4260., 4310., 4360., 4410., 4460., 4510., 4560., 4610.,
#        4660., 4710., 4760., 4810., 4860.])

# %%
plt.figure()
df_pred_bm[(df_pred_bm['Model'] == 'M_best') &
           (df_pred_bm['Pasture'] == '7NW') &
           (df_pred_bm['season'] == 'early') &
           (df_pred_bm['week'] == 25) &
           (df_pred_bm['Year'] == 2016)].sort_values('Biomass_orig').plot(x='Biomass_orig', y='marg_rel_freq_bm_nm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19719/2361870603.py in <module>
#       1 plt.figure()
# ----> 2 df_pred_bm[(df_pred_bm['Model'] == 'M_best') &
#       3            (df_pred_bm['Pasture'] == '7NW') &
#       4            (df_pred_bm['season'] == 'early') &
#       5            (df_pred_bm['week'] == 25) &
#
# NameError: name 'df_pred_bm' is not defined

# %%
"""
Plot marginal effects of biomass by model across weeks
"""
print('Plotting datasets and saving plots to disk')
x_var = 'Biomass_orig'

for mod in tqdm(['M_best', 'M4_top', 'M2_top']):
    g = sns.FacetGrid(df_pred_bm[df_pred_bm['Model'] == mod].groupby(['Year',
                                                                       'season',
                                                                       'Pasture',
                                                                     'Biomass_orig']).mean().reset_index(), 
                      col='season', row='Year',# hue='Pasture', 
                      col_order=['early', 'mid', 'late'],
                      #hue_order=['7NW', '15E', '17N', '20SE', '25SE', '26E', '31E'],
                      margin_titles=True,
                      legend_out=True, sharey=False, sharex=True, palette=sns.color_palette('deep'),
                      height=2.25, aspect=1.75, gridspec_kws={"hspace":0.2, "wspace":0.0})
    #plt.figure()
    g.map_dataframe(sns.regplot, x=x_var, y='marg_rel_freq_bm_nm',
                    line_kws={'linewidth': 1}, n_boot=25, ci=99, x_bins=10, x_ci='sd',
                    order=2, scatter=True, scatter_kws={'s': 2, 
                                                        'alpha': 0.25,
                                                        'marker': 'o',
                                                        'edgecolor': 'None'}).add_legend()
    g.set_xlabels('Biomass (kg/ha)')
    g.set_ylabels(None)
    axes = g.fig.axes
    for idx, ax in enumerate(axes):
        ax.axhline(y=1.0, linestyle='dashed', color='grey')
        #ax.set_ylim((0.0, ax.get_ylim()[-1]))
        ax.set_ylim((0.0, 5.0))
        ax.set_xlim((0, 2600))
        cur_title = ax.get_title()
        box = ax.get_position()
        ax.set_position([box.x0, box.y0, box.width*0.80, box.height])
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
        ax.xaxis.set_minor_locator(MultipleLocator(250))
        #ax.axvline(x=500, linestyle='solid', color='red')
        #ax.fill_between(range(700, 3500), 0, 1, transform=ax.get_xaxis_transform(), color='#117733', alpha=0.2, edgecolor=None, zorder=0)
        ax.fill_between(range(350, 700), 0, 1, transform=ax.get_xaxis_transform(), color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
        ax.fill_between(range(0, 350), 0, 1, transform=ax.get_xaxis_transform(), color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
        plt.setp(ax.texts, text="") # remove the original texts
        if idx == 3:
            ax.set_ylabel('Relative probability of selection', labelpad=10)

    # Define a new Axes where the colorbar will go
    #cax = g.fig.add_axes([.90, .20, .02, .6])
    #cax.set_title('CP')
    # Get a mappable object with the same colormap as the data
    #points = plt.scatter([], [], c=[], vmin=vmin, vmax=vmax, cmap=cmap)
    # Draw the colorbar
    #g.fig.colorbar(points, cax=cax)
    g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
    g.set(xticks=np.arange(0, 3000, 500))
    for lh in g._legend.legendHandles: 
        lh.set_alpha(1)
        lh._sizes = [10]
    g.fig.suptitle('Marginal biomass effects: ' + mod)
    plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/Biomass_wkly_marg_' + mod  +'.png', 
                bbox_inches='tight', dpi=300)
    plt.close()
#plt.tight_layout()
# Out:
# Plotting datasets and saving plots to disk
#   0%|          | 0/3 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)

# %%
"""
CP: how does selection change with crude protein across pastures and models
"""
ref_TPC = 'Flat Plains'
ref_pc = 'C3_C4_mix'
df_pred_cp = pd.DataFrame(columns=['Year', 'season','dFence_orig', 'dTank_orig', 'Biomass_orig', 'CP_orig','PC_div_orig',
                                'PC_dmt', 'TPC_c', 'Model'])
print('Creating dataset...')
for mod in tqdm(mod_list):
    for yr in yrly_mod_dict:
        for wk in yrly_mod_dict[yr]:
            for past in yrly_mod_dict[yr][wk]:
                df_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) &
                                            (df_wkly_grid_train['week'] == wk) &
                                            (df_wkly_grid_train['Pasture'] == past) &
                                            (df_wkly_grid_train['pred_rel_freq_' + mod].notnull())]
                if ref_TPC is not None:
                    df_tmp = df_sub[(df_sub['TPC_c'] == ref_TPC) & (df_sub['PC_dmt'] == ref_pc)]
                else:
                    df_tmp = df_sub[(df_sub['PC_dmt'] == ref_pc)]
                if len(df_sub) < 50:
                    continue
                else:
                    df_pred_cp = df_pred_cp.append(pd.DataFrame({
                        'Year': yr,
                        'week': wk,
                        'Pasture': past,
                        'season': df_tmp['season'].unique()[0],
                        'dFence_orig': df_tmp['dFence_orig'].median(),
                        'dTank_orig': df_tmp['dTank_orig'].median(),
                        'Biomass_orig': df_tmp['Biomass_orig'].median(),
                        'CP_orig': np.arange(df_tmp['CP_orig'].quantile(0.025), df_tmp['CP_orig'].quantile(0.975), 0.1),
                        'PC_div_orig': df_tmp['PC_div_orig'].median(),
                        'PC_dmt': ref_pc,
                        'TPC_c': ref_TPC,
                        'Model': mod
                    }))
                for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
                    scaler = scaler_dict[yr][df_tmp['season'].unique()[0]][c]
                    df_pred_cp.loc[(df_pred_cp['Year'] == yr) & 
                                (df_pred_cp['week'] == wk) &
                                (df_pred_cp['Pasture'] == past), c] = scaler.transform(
                        df_pred_cp.loc[(df_pred_cp['Year'] == yr) & 
                                    (df_pred_cp['week'] == wk) &
                                    (df_pred_cp['Pasture'] == past), c + '_orig'].values.reshape(-1, 1)).flatten()
                df_pred_cp.loc[(df_pred_cp['Year'] == yr) & 
                            (df_pred_cp['week'] == wk) &
                            (df_pred_cp['Pasture'] == past) &
                            (df_pred_cp['Model'] == mod), 
                            'marg_pred_cp'] = yrly_mod_dict[yr][wk][past][mod].predict(df_pred_cp.loc[(df_pred_cp['Year'] == yr) & 
                                                                                               (df_pred_cp['week'] == wk) & 
                                                                                               (df_pred_cp['Pasture'] == past) &
                                                                                               (df_pred_cp['Model'] == mod)])
        

"""
Calculate relative frequency from predictions
"""
print('Calculating relative frequencies')
df_pred_cp['marg_rel_freq_cp'] = np.nan
for mod in tqdm(mod_list):
    for yr in df_pred_cp.Year.unique():
        for wk in df_pred_cp[df_pred_cp['Year'] == yr]['week'].unique():
            for past in df_pred_cp[(df_pred_cp['Year'] == yr) & (df_pred_cp['week'] == wk)]['Pasture'].unique():
                df_wkly_grid_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) & 
                                                     (df_wkly_grid_train['week'] == wk) & 
                                                     (df_wkly_grid_train['Pasture'] == past)]
                df_pred_cp.loc[(df_pred_cp['Year'] == yr) & 
                            (df_pred_cp['week'] == wk) &
                            (df_pred_cp['Pasture'] == past) &
                            (df_pred_cp['Model'] == mod),
                             'marg_rel_freq_cp'] = (df_pred_cp.loc[(df_pred_cp['Year'] == yr) &
                                                                (df_pred_cp['week'] == wk) &
                                                                (df_pred_cp['Pasture'] == past) &
                                                                (df_pred_cp['Model'] == mod),
                                                                'marg_pred_cp'] * df_wkly_grid_sub[
                    'grazing_wkly_sum'].mean()) / (df_wkly_grid_sub['grazing_wkly_sum'].mean() / df_wkly_grid_sub[
                    'grazing_wkly_sum'].count())

df_pred_cp['season'] = pd.Categorical(df_pred_cp['season'], ['early', 'mid', 'late'])
df_pred_cp['marg_rel_freq_cp_nm'] = df_pred_cp.groupby(['Year', 'week', 'Pasture', 'Model'])['marg_rel_freq_cp'].transform(lambda x: x / np.mean(x))

"""
Plot marginal effects of biomass and relative CP by model and season
"""
print('Plotting datasets and saving plots to disk')
x_var = 'CP_orig'

for mod in tqdm(mod_list):
    g = sns.FacetGrid(df_pred_cp[df_pred_cp['Model'] == mod], 
                      col='season', row='Year', hue='Pasture', 
                      col_order=['early', 'mid', 'late'], margin_titles=True,
                      legend_out=True, sharey=False, sharex=True, palette=sns.color_palette('deep'),
                      height=2.25, aspect=1.75, gridspec_kws={"hspace":0.2, "wspace":0.0})
    #plt.figure()
    g.map_dataframe(sns.regplot, x=x_var, y='marg_rel_freq_cp_nm',
                    line_kws={'linewidth': 1}, n_boot=25,
                    order=1, scatter=True, scatter_kws={'s': 2, 
                                                        'alpha': 0.25,
                                                        'marker': 'o',
                                                        'edgecolor': 'None'}).add_legend()
    g.set_xlabels('CP (%)')
    g.set_ylabels(None)
    axes = g.fig.axes
    for idx, ax in enumerate(axes):
        ax.axhline(y=1.0, linestyle='dashed', color='grey')
        ax.set_ylim((0.0, ax.get_ylim()[-1]))
        if ax.get_ylim()[-1] < 3.0:
            ax.set_ylim((0.0, 3.0))
        elif ax.get_ylim()[-1] < 5.0:
            ax.set_ylim((0.0, 5.0))
        elif ax.get_ylim()[-1] < 10.0:
            ax.set_ylim((0.0, 10.0))
        ax.set_xlim((5, 13))
        cur_title = ax.get_title()
        box = ax.get_position()
        ax.set_position([box.x0, box.y0, box.width*0.80, box.height])
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
        ax.xaxis.set_minor_locator(MultipleLocator(0.5))
        #ax.axvline(x=500, linestyle='solid', color='red')
        #ax.fill_between(range(700, 3500), 0, 1, transform=ax.get_xaxis_transform(), color='#117733', alpha=0.2, edgecolor=None, zorder=0)
        ax.fill_between(range(7, 9), 0, 1, transform=ax.get_xaxis_transform(), color='#DDCC77', alpha=0.4, edgecolor=None, zorder=0)
        ax.fill_between(range(5, 8), 0, 1, transform=ax.get_xaxis_transform(), color='#CC6677', alpha=0.4, edgecolor=None, zorder=0)
        plt.setp(ax.texts, text="") # remove the original texts
        if idx == 3:
            ax.set_ylabel('Relative probability of selection', labelpad=10)

    # Define a new Axes where the colorbar will go
    #cax = g.fig.add_axes([.90, .20, .02, .6])
    #cax.set_title('CP')
    # Get a mappable object with the same colormap as the data
    #points = plt.scatter([], [], c=[], vmin=vmin, vmax=vmax, cmap=cmap)
    # Draw the colorbar
    #g.fig.colorbar(points, cax=cax)
    g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
    g.set(xticks=np.arange(5, 13, 1))
    for lh in g._legend.legendHandles: 
        lh.set_alpha(1)
        lh._sizes = [10]
    g.fig.suptitle('Marginal CP effects: ' + mod)
    plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/CP_wkly_marg_' + mod  +'.png', 
                bbox_inches='tight', dpi=300)
    plt.close()
#plt.tight_layout()

# %%
"""
Diversity: how does selection change with crude protein across pastures and models
"""
ref_TPC = 'Flat Plains'
ref_pc = 'C3_C4_mix'
df_pred_div = pd.DataFrame(columns=['Year', 'season','dFence_orig', 'dTank_orig', 'Biomass_orig', 'CP_orig','PC_div_orig',
                                'PC_dmt', 'TPC_c', 'Model'])
print('Creating dataset...')
for mod in tqdm(mod_list):
    for yr in yrly_mod_dict:
        for wk in yrly_mod_dict[yr]:
            for past in yrly_mod_dict[yr][wk]:
                df_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) &
                                            (df_wkly_grid_train['week'] == wk) &
                                            (df_wkly_grid_train['Pasture'] == past) &
                                            (df_wkly_grid_train['pred_rel_freq_' + mod].notnull())]
                if ref_TPC is not None:
                    df_tmp = df_sub[(df_sub['TPC_c'] == ref_TPC) & (df_sub['PC_dmt'] == ref_pc)]
                else:
                    df_tmp = df_sub[(df_sub['PC_dmt'] == ref_pc)]
                if len(df_sub) < 50:
                    continue
                else:
                    df_pred_div = df_pred_div.append(pd.DataFrame({
                        'Year': yr,
                        'week': wk,
                        'Pasture': past,
                        'season': df_tmp['season'].unique()[0],
                        'dFence_orig': df_tmp['dFence_orig'].median(),
                        'dTank_orig': df_tmp['dTank_orig'].median(),
                        'Biomass_orig': df_tmp['Biomass_orig'].median(),
                        'CP_orig': df_tmp['CP_orig'].median(),
                        'PC_div_orig': np.arange(df_tmp['PC_div_orig'].quantile(0.025), df_tmp['PC_div_orig'].quantile(0.975), 0.1),
                        'PC_dmt': ref_pc,
                        'TPC_c': ref_TPC,
                        'Model': mod
                    }))
                for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
                    scaler = scaler_dict[yr][df_tmp['season'].unique()[0]][c]
                    df_pred_div.loc[(df_pred_div['Year'] == yr) & 
                                (df_pred_div['week'] == wk) &
                                (df_pred_div['Pasture'] == past), c] = scaler.transform(
                        df_pred_div.loc[(df_pred_div['Year'] == yr) & 
                                    (df_pred_div['week'] == wk) &
                                    (df_pred_div['Pasture'] == past), c + '_orig'].values.reshape(-1, 1)).flatten()
                df_pred_div.loc[(df_pred_div['Year'] == yr) & 
                            (df_pred_div['week'] == wk) &
                            (df_pred_div['Pasture'] == past) &
                            (df_pred_div['Model'] == mod), 
                            'marg_pred_div'] = yrly_mod_dict[yr][wk][past][mod].predict(df_pred_div.loc[(df_pred_div['Year'] == yr) & 
                                                                                               (df_pred_div['week'] == wk) & 
                                                                                               (df_pred_div['Pasture'] == past) &
                                                                                               (df_pred_div['Model'] == mod)])
        

"""
Calculate relative frequency from predictions
"""
print('Calculating relative frequencies')
df_pred_div['marg_rel_freq_div'] = np.nan
for mod in tqdm(mod_list):
    for yr in df_pred_div.Year.unique():
        for wk in df_pred_div[df_pred_div['Year'] == yr]['week'].unique():
            for past in df_pred_div[(df_pred_div['Year'] == yr) & (df_pred_div['week'] == wk)]['Pasture'].unique():
                df_wkly_grid_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) & 
                                                     (df_wkly_grid_train['week'] == wk) & 
                                                     (df_wkly_grid_train['Pasture'] == past)]
                df_pred_div.loc[(df_pred_div['Year'] == yr) & 
                            (df_pred_div['week'] == wk) &
                            (df_pred_div['Pasture'] == past) &
                            (df_pred_div['Model'] == mod),
                             'marg_rel_freq_div'] = (df_pred_div.loc[(df_pred_div['Year'] == yr) &
                                                                (df_pred_div['week'] == wk) &
                                                                (df_pred_div['Pasture'] == past) &
                                                                (df_pred_div['Model'] == mod),
                                                                'marg_pred_div'] * df_wkly_grid_sub[
                    'grazing_wkly_sum'].mean()) / (df_wkly_grid_sub['grazing_wkly_sum'].mean() / df_wkly_grid_sub[
                    'grazing_wkly_sum'].count())

df_pred_div['season'] = pd.Categorical(df_pred_div['season'], ['early', 'mid', 'late'])
df_pred_div['marg_rel_freq_div_nm'] = df_pred_div.groupby(['Year', 'week', 'Pasture', 'Model'])['marg_rel_freq_div'].transform(lambda x: x / np.mean(x))

"""
Plot marginal effects
"""
print('Plotting datasets and saving plots to disk')
x_var = 'PC_div_orig'

for mod in tqdm(mod_list):
    g = sns.FacetGrid(df_pred_div[df_pred_div['Model'] == mod], 
                      col='season', row='Year', hue='Pasture', 
                      col_order=['early', 'mid', 'late'], margin_titles=True,
                      legend_out=True, sharey=False, sharex=True, palette=sns.color_palette('deep'),
                      height=2.25, aspect=1.75, gridspec_kws={"hspace":0.2, "wspace":0.0})
    #plt.figure()
    g.map_dataframe(sns.regplot, x=x_var, y='marg_rel_freq_div_nm',
                    line_kws={'linewidth': 1}, n_boot=25,
                    order=1, scatter=True, scatter_kws={'s': 2, 
                                                        'alpha': 0.25,
                                                        'marker': 'o',
                                                        'edgecolor': 'None'}).add_legend()
    g.set_xlabels('Plant community diversity (Shannon-H)')
    g.set_ylabels(None)
    axes = g.fig.axes
    for idx, ax in enumerate(axes):
        ax.axhline(y=1.0, linestyle='dashed', color='grey')
        ax.set_ylim((0.0, ax.get_ylim()[-1]))
        if ax.get_ylim()[-1] < 3.0:
            ax.set_ylim((0.0, 3.0))
        elif ax.get_ylim()[-1] < 5.0:
            ax.set_ylim((0.0, 5.0))
        elif ax.get_ylim()[-1] < 10.0:
            ax.set_ylim((0.0, 10.0))
        ax.set_xlim((0, 2.0))
        cur_title = ax.get_title()
        box = ax.get_position()
        ax.set_position([box.x0, box.y0, box.width*0.80, box.height])
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
        ax.xaxis.set_minor_locator(MultipleLocator(0.1))
        plt.setp(ax.texts, text="") # remove the original texts
        if idx == 3:
            ax.set_ylabel('Relative probability of selection', labelpad=10)

    # Define a new Axes where the colorbar will go
    #cax = g.fig.add_axes([.90, .20, .02, .6])
    #cax.set_title('CP')
    # Get a mappable object with the same colormap as the data
    #points = plt.scatter([], [], c=[], vmin=vmin, vmax=vmax, cmap=cmap)
    # Draw the colorbar
    #g.fig.colorbar(points, cax=cax)
    g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
    g.set(xticks=np.arange(0, 2.5, 0.5))
    for lh in g._legend.legendHandles: 
        lh.set_alpha(1)
        lh._sizes = [10]
    g.fig.suptitle('Marginal Diversity effects: ' + mod)
    plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/DIV_wkly_marg_' + mod  +'.png', 
                bbox_inches='tight', dpi=300)
    plt.close()
#plt.tight_layout()
# Out:
# Creating dataset...
#   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating relative frequencies
#   0%|          | 0/4 [00:00<?, ?it/s]
# Plotting datasets and saving plots to disk
#   0%|          | 0/4 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)

# %%
"""
Plant Community: how does selection change with plant community class across pastures and models
"""
ref_TPC = 'Flat Plains'
df_pred_pc = pd.DataFrame(columns=['Year', 'season','dFence_orig', 'dTank_orig', 'Biomanp.average', 'CP_orig','PC_div_orig',
                                'PC_dmt', 'TPC_c', 'Model', 'TPC_wt'])
print('Creating dataset...')
idx=0
for mod in tqdm(mod_list):
    for yr in yrly_mod_dict:
        for wk in yrly_mod_dict[yr]:
            for past in yrly_mod_dict[yr][wk]:
                df_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) &
                                            (df_wkly_grid_train['week'] == wk) &
                                            (df_wkly_grid_train['Pasture'] == past) &
                                            (df_wkly_grid_train['pred_rel_freq_' + mod].notnull())]
                for ref_pc in df_sub['PC_dmt'].unique():
                    if yrly_mod_dict[yr][wk][past][mod].params.index.str.contains('TPC_c').any():
                        for ref_TPC in df_sub['TPC_c'].unique():
                            df_tmp = df_sub[(df_sub['TPC_c'] == ref_TPC) & (df_sub['PC_dmt'] == ref_pc)]
                            if len(df_tmp) < 10:
                                continue
                            else:
                                df_pred_pc = df_pred_pc.append(pd.DataFrame({
                                    'Year': yr,
                                    'week': wk,
                                    'Pasture': past,
                                    'season': df_tmp['season'].unique()[0],
                                    'dFence_orig': df_tmp['dFence_orig'].median(),
                                    'dTank_orig': df_tmp['dTank_orig'].median(),
                                    'Biomass_orig': df_tmp['Biomass_orig'].median(),
                                    'CP_orig': df_tmp['CP_orig'].median(),
                                    'PC_div_orig': df_tmp['PC_div_orig'].median(),
                                    'PC_dmt': ref_pc,
                                    'TPC_c': ref_TPC,
                                    'Model': mod,
                                    'TPC_wt': len(df_tmp)/len(df_sub[df_sub['PC_dmt'] == ref_pc])
                                }, index=[idx]))
                                idx+=1
                    else:
                        df_tmp = df_sub[(df_sub['PC_dmt'] == ref_pc)]
                    if len(df_tmp) < 10:
                        continue
                    else:
                        df_pred_pc = df_pred_pc.append(pd.DataFrame({
                            'Year': yr,
                            'week': wk,
                            'Pasture': past,
                            'season': df_tmp['season'].unique()[0],
                            'dFence_orig': df_tmp['dFence_orig'].median(),
                            'dTank_orig': df_tmp['dTank_orig'].median(),
                            'Biomass_orig': df_tmp['Biomass_orig'].median(),
                            'CP_orig': df_tmp['CP_orig'].median(),
                            'PC_div_orig': df_tmp['PC_div_orig'].median(),
                            'PC_dmt': ref_pc,
                            'TPC_c': ref_TPC,
                            'Model': mod,
                            'TPC_wt': len(df_tmp)/len(df_sub[df_sub['PC_dmt'] == ref_pc])
                        }, index=[idx]))
                        idx+=1
                    for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
                        scaler = scaler_dict[yr][df_tmp['season'].unique()[0]][c]
                        df_pred_pc.loc[(df_pred_pc['Year'] == yr) & 
                                    (df_pred_pc['week'] == wk) &
                                    (df_pred_pc['Pasture'] == past), c] = scaler.transform(
                            df_pred_pc.loc[(df_pred_pc['Year'] == yr) & 
                                        (df_pred_pc['week'] == wk) &
                                        (df_pred_pc['Pasture'] == past), c + '_orig'].values.reshape(-1, 1)).flatten()
                    df_pred_pc.loc[(df_pred_pc['Year'] == yr) & 
                                (df_pred_pc['week'] == wk) &
                                (df_pred_pc['Pasture'] == past) &
                                (df_pred_pc['Model'] == mod), 
                                'marg_pred_pc'] = yrly_mod_dict[yr][wk][past][mod].predict(df_pred_pc.loc[(df_pred_pc['Year'] == yr) & 
                                                                                                   (df_pred_pc['week'] == wk) & 
                                                                                                   (df_pred_pc['Pasture'] == past) &
                                                                                                   (df_pred_pc['Model'] == mod)])
df_pred_pc = df_pred_pc.groupby(['Year',
                                 'season',
                                 'week', 
                                 'Pasture', 
                                 'Model', 
                                 'PC_dmt']).apply(lambda x: pd.Series({'marg_pred_pc':
                                                                       np.average(x['marg_pred_pc'], weights=x['TPC_wt'])})).reset_index()
# Out:
# Creating dataset...
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
"""
Calculate relative frequency from predictions
"""
print('Calculating relative frequencies')
df_pred_pc['marg_rel_freq_pc'] = np.nan
for mod in tqdm(mod_list):
    for yr in df_pred_pc.Year.unique():
        for wk in df_pred_pc[df_pred_pc['Year'] == yr]['week'].unique():
            for past in df_pred_pc[(df_pred_pc['Year'] == yr) & (df_pred_pc['week'] == wk)]['Pasture'].unique():
                df_wkly_grid_sub = df_wkly_grid_train[(df_wkly_grid_train['Year'] == yr) & 
                                                     (df_wkly_grid_train['week'] == wk) & 
                                                     (df_wkly_grid_train['Pasture'] == past)]
                df_pred_pc.loc[(df_pred_pc['Year'] == yr) & 
                            (df_pred_pc['week'] == wk) &
                            (df_pred_pc['Pasture'] == past) &
                            (df_pred_pc['Model'] == mod),
                             'marg_rel_freq_pc'] = (df_pred_pc.loc[(df_pred_pc['Year'] == yr) &
                                                                (df_pred_pc['week'] == wk) &
                                                                (df_pred_pc['Pasture'] == past) &
                                                                (df_pred_pc['Model'] == mod),
                                                                'marg_pred_pc'] * df_wkly_grid_sub[
                    'grazing_wkly_sum'].mean()) / (df_wkly_grid_sub['grazing_wkly_sum'].mean() / df_wkly_grid_sub[
                    'grazing_wkly_sum'].count())

df_pred_pc['marg_rel_freq_pc_nm'] = df_pred_pc.groupby(['Year', 'week', 'Pasture', 'Model'])['marg_rel_freq_pc'].transform(lambda x: x / np.mean(x))
df_pred_pc['season'] = pd.Categorical(df_pred_pc['season'], ['early', 'mid', 'late'])
df_pred_pc['PC_dmt'] = pd.Categorical(df_pred_pc['PC_dmt'], ['C4', 'C3_C4_mix', 'C3', 'Saltgrass', 'Other'])
# Out:
# Calculating relative frequencies
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
df_pred_pc[(df_pred_pc['Pasture'] == '25SE') & (df_pred_pc['Model'] == 'M_best')].groupby(['Year', 'season'])['PC_dmt'].value_counts()
# Out:
# Year    season
# 2016.0  early   C4           4
#                 C3_C4_mix    4
#                 C3           0
#                 Saltgrass    0
#                 Other        0
#         mid     C4           6
#                 C3_C4_mix    6
#                 Other        2
#                 C3           0
#                 Saltgrass    0
#         late    C4           6
#                 C3_C4_mix    6
#                 Other        4
#                 C3           0
#                 Saltgrass    0
# 2017.0  early   C4           6
#                 C3_C4_mix    6
#                 Other        2
#                 C3           0
#                 Saltgrass    0
#         mid     C4           4
#                 C3_C4_mix    4
#                 C3           0
#                 Saltgrass    0
#                 Other        0
#         late    C4           4
#                 C3_C4_mix    4
#                 Other        1
#                 C3           0
#                 Saltgrass    0
# 2018.0  early   C4           6
#                 C3_C4_mix    6
#                 Other        2
#                 C3           0
#                 Saltgrass    0
#         mid     C4           6
#                 C3_C4_mix    6
#                 Other        3
#                 C3           0
#                 Saltgrass    0
#         late    C4           4
#                 C3_C4_mix    4
#                 Other        3
#                 C3           0
#                 Saltgrass    0
# Name: PC_dmt, dtype: int64

# %%
"""
Plot marginal effects
"""
print('Plotting datasets and saving plots to disk')
y_var = 'PC_dmt'

for mod in tqdm(['M_best', 'M3_top', 'M4_top']):
    #g = sns.FacetGrid(df_pred_pc[df_pred_pc['Model'] == mod], 
    #                  col='season', row='Year', hue='Pasture', 
    #                  col_order=['early', 'mid', 'late'], margin_titles=True,
    #                  legend_out=True, sharey=True, sharex=True, palette=sns.color_palette('deep'),
    #                  height=2.25, aspect=1.75, gridspec_kws={"hspace":0.2, "wspace":0.0})
    #plt.figure()
    g = sns.factorplot(x='marg_rel_freq_pc_nm', y=y_var, data=df_pred_pc[df_pred_pc['Model'] == mod],
                    join=False, orient='h', dodge=0.4,
                      col='season', row='Year', hue='Pasture', 
                      col_order=['early', 'mid', 'late'], margin_titles=True,
                      legend_out=True, sharey=True, sharex=True, palette=sns.color_palette('deep'),
                      height=2.25, aspect=1.75, gridspec_kws={"hspace":0.2, "wspace":0.0})
    #g.map_dataframe(sns.pointplot, x='marg_rel_freq_pc_nm', y=y_var,
    #                join=False, orient='h').add_legend()
    g.set_xlabels('Relative probability of selection')
    g.set_ylabels(None)
    axes = g.fig.axes
    for idx, ax in enumerate(axes):
        ax.axvline(x=1.0, linestyle='dashed', color='grey')
        #ax.set_ylim((-1.0, 5.0))
        #if ax.get_xlim()[-1] < 3.0:
        #    ax.set_xlim((0.0, 3.0))
        #elif ax.get_xlim()[-1] < 5.0:
        #    ax.set_xlim((0.0, 5.0))
        #elif ax.get_xlim()[-1] < 10.0:
        #    ax.set_xlim((0.0, 10.0))
        cur_title = ax.get_title()
        box = ax.get_position()
        ax.set_position([box.x0, box.y0, box.width*0.80, box.height*0.85])
        ax.xaxis.set_minor_locator(MultipleLocator(0.5))
        plt.setp(ax.texts, text="") # remove the original texts
        if idx == 3:
            ax.set_ylabel('Plant community', labelpad=10)
        else:
            ax.set_ylabel('')

    # Define a new Axes where the colorbar will go
    #cax = g.fig.add_axes([.90, .20, .02, .6])
    #cax.set_title('CP')
    # Get a mappable object with the same colormap as the data
    #points = plt.scatter([], [], c=[], vmin=vmin, vmax=vmax, cmap=cmap)
    # Draw the colorbar
    #g.fig.colorbar(points, cax=cax)
    g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
    g.set(yticks=[0, 1, 2, 3, 4, 5])
    #for lh in g._legend.legendHandles: 
    #    lh.set_alpha(1)
    #    lh._sizes = [10]
    g.fig.suptitle('Marginal Plant Community effects: ' + mod)
    plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/PC_wkly_marg_' + mod  +'.png', 
                bbox_inches='tight', dpi=300)
    plt.close()
#plt.tight_layout()
# Out:
# Plotting datasets and saving plots to disk
#   0%|          | 0/3 [00:00<?, ?it/s]
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %%
"""
Compare top model by plant community diversity: how does selection change with plant community diversity within dominant plant communities?
"""
ref_TPC = 'Flat Plains'
df_pred = pd.DataFrame(columns=['Year', 'season', 'dFence_orig', 'dTank_orig', 'Biomass_orig', 'CP_orig','PC_div_orig',
                                'PC_dmt', 'TPC_c'])
for (yr, seas), df_sub in df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'train'].groupby(['Year', 'season']):
    print(yr, seas)
    if ref_TPC is not None:
        df_tmp = df_sub[(df_sub['TPC_c'] == ref_TPC)]
    else:
        df_tmp = df_sub
    if not (coefs_dict[yr][seas]['M_best']['Param'] == 'PC_div').any():
        continue
    if np.sign(coefs_dict[yr][seas]['M_best'].set_index('Param').loc['PC_div']['[0.025']) != \
    np.sign(coefs_dict[yr][seas]['M_best'].set_index('Param').loc['PC_div']['0.975]']):
        continue
    if (coefs_dict[yr][seas]['M_best']['Param'] == 'C3').any():
        if (coefs_dict[yr][seas]['M_best']['Param'] == 'C3:PC_div').any():
            for ref_pc in df_wkly_grid_full['PC_dmt'][df_wkly_grid_full['mod_data'] == 'train'].unique():
                df_tmp2 = df_tmp[df_tmp['PC_dmt'] == ref_pc]
                if len(df_tmp2) < 50:
                    continue
                if ref_pc != 'C3_C4_mix':
                    if np.sign(coefs_dict[yr][seas]['M_best'].set_index('Param').loc[ref_pc + ':PC_div']['[0.025']) != \
                    np.sign(coefs_dict[yr][seas]['M_best'].set_index('Param').loc[ref_pc + ':PC_div']['0.975]']):
                        continue
                df_pred = df_pred.append(pd.DataFrame({
                    'Year': yr,
                    'season': seas,
                    'dFence_orig': df_tmp2['dFence_orig'].median(),
                    'dTank_orig': df_tmp2['dTank_orig'].median(),
                    'Biomass_orig': df_tmp2['Biomass_orig'].median(),
                    'CP_orig': df_tmp2['CP_orig'].median(),
                    'PC_div_orig': np.linspace(df_tmp2['PC_div_orig'].quantile(0.005),
                                               df_tmp2['PC_div_orig'].quantile(0.995), 25),
                    'PC_dmt': ref_pc,
                    'TPC_c': ref_TPC,
                    'step': np.arange(25)
                }))
            
        else:
            ref_pc = 'C3_C4_mix'
            df_tmp = df_tmp[(df_tmp['PC_dmt'] == ref_pc)]
            if len(df_tmp) < 50:
                continue
            df_pred = df_pred.append(pd.DataFrame({
                'Year': yr,
                'season': seas,
                'dFence_orig': df_tmp['dFence_orig'].median(),
                'dTank_orig': df_tmp['dTank_orig'].median(),
                'Biomass_orig': df_tmp['Biomass_orig'].median(),
                'CP_orig': df_tmp['CP_orig'].median(),
                'PC_div_orig': np.linspace(df_tmp['PC_div_orig'].quantile(0.005),
                                           df_tmp['PC_div_orig'].quantile(0.995), 25),
                'PC_dmt': ref_pc,
                'TPC_c': ref_TPC,
                'step': np.arange(25)
            }))
    else:
        if len(df_tmp) < 50:
            continue
        df_pred = df_pred.append(pd.DataFrame({
            'Year': yr,
            'season': seas,
            'dFence_orig': df_tmp['dFence_orig'].median(),
            'dTank_orig': df_tmp['dTank_orig'].median(),
            'Biomass_orig': df_tmp['Biomass_orig'].median(),
            'CP_orig': df_tmp['CP_orig'].median(),
            'PC_div_orig': np.linspace(df_tmp['PC_div_orig'].quantile(0.005), 
                                       df_tmp['PC_div_orig'].quantile(0.995), 25),
            'PC_dmt': 'Overall',
            'TPC_c': ref_TPC,
            'step': np.arange(25)
        }))
    for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
        scaler = scaler_dict[yr][seas][c]
        df_pred.loc[(df_pred['Year'] == yr) & 
                    (df_pred['season'] == seas), c] = scaler.transform(
            df_pred.loc[(df_pred['Year'] == yr) & 
                        (df_pred['season'] == seas), c + '_orig'].values.reshape(-1, 1)).flatten()
    df_pred.loc[(df_pred['Year'] == yr) & 
                (df_pred['season'] == seas), 
                'mod_pred'] = yrly_mod_dict[yr][seas]['M_best'].predict(df_pred.loc[(df_pred['Year'] == yr) &
                                                                               (df_pred['season'] == seas)])
    
df_pred['season'] = pd.Categorical(df_pred['season'], ['early', 'mid', 'late'])
df_pred['pred_rel_freq'] = np.nan
for yr in df_pred.Year.unique():
    for seas in df_pred.season.unique():
        df_wkly_grid_sub = df_wkly_grid_full[(df_wkly_grid_full['Year'] == yr) & 
                                             (df_wkly_grid_full['season'] == seas) & 
                                             (df_wkly_grid_full['mod_data'] == 'train')]
        df_pred.loc[(df_pred['Year'] == yr) & 
                    (df_pred['season'] == seas), 'pred_rel_freq'] = (df_pred.loc[(df_pred['Year'] == yr) &
                                                                                 (df_pred['season'] == seas), 'mod_pred'] * df_wkly_grid_sub['grazing_wkly_sum'].mean()) / (df_wkly_grid_sub.groupby('Pasture')['grazing_wkly_sum'].mean().mean() / df_wkly_grid_sub.groupby(
            ['Pasture'])['grazing_wkly_sum'].count().mean())
        
        #if not (mbest_coefs_dict[yr][seas]['Param'] == 'PC_dmt:C3').any():
        #    df_pred_tmp = df_pred[(df_pred['Year'] == yr) &
        #                          (df_pred['season'] == seas)].groupby(['step']).mean()
        #    df_pred_tmp['PC_dmt'] = 'Average'
        #    df_pred_tmp['season'] = seas
        #    df_pred_tmp['Year'] = yr
        #    df_pred = df_pred[~((df_pred['Year'] == yr) &
        #                        (df_pred['season'] == seas))]
        #    df_pred = df_pred.append(df_pred_tmp)
# Out:
# 2016 early
# 2016 mid
# 2016 late
# 2017 early
# 2017 mid
# 2017 late
# 2018 early
# 2018 mid
# 2018 late

# %%
"""
Plot marginal effects of plant community diversity by dominant plant community and season
"""
x_var = 'PC_div_orig'
hue_order = [x for x in ['C4', 'C3_C4_mix', 'C3', 'Saltgrass', 'Other', 'Overall'] if x in df_pred['PC_dmt'].unique()]
hue_labels = ['C3/C4 mix' if x == 'C3_C4_mix' else x for x in hue_order]
g = sns.FacetGrid(df_pred, col='season', row='Year', hue='PC_dmt',
                  col_order=['early', 'mid', 'late'], 
                  hue_order=hue_order, palette=['blue', 'olive', 'darkorange', 'pink', 'grey', 'black'],
                  margin_titles=True,
                  legend_out=True, sharey=False, height=2.25, aspect=1.5, gridspec_kws={"hspace":0.2, "wspace":0.2})
#plt.figure()
g.map_dataframe(sns.lineplot, x=x_var, y='pred_rel_freq').add_legend(bbox_to_anchor=(1.075, 0.5))
g.set_xlabels(None)
g.set_ylabels(None)
axes = g.axes.flat
for idx, ax in enumerate(axes):
    ax.axhline(y=1.0, linestyle='dashed', color='grey')
    ax.set_ylim((0.0, ax.get_ylim()[-1]))
    #if ax.get_ylim()[-1] < 3.0:
    ax.set_ylim((0.0, 3.0))
    cur_title = ax.get_title()
    plt.setp(ax.texts, text="") # remove the original texts
    if idx == 3:
        ax.set_ylabel('Relative probability of selection', labelpad=10)
    if idx == 7:
        ax.set_xlabel('Plant community diversity (Shannon H)', labelpad=10)
if len(hue_order) > 1:
    for ax in axes:
        box = ax.get_position()
        ax.set_position([box.x0, box.y0, box.width*0.6, box.height*0.9])
    leg = g.legend
    # change legend texts
    new_title = 'Plant community'
    leg.set_title(new_title, prop={'weight': 'bold',
            'size': 12,
            })
    new_labels=hue_labels
    for t, l in zip(leg.texts, new_labels):
        t.set_text(l)
else:
    g.legend.remove()
g.set(xticks=np.arange(0, 2.5, 0.5))
g.set_titles(row_template = '{row_name}', col_template = '{col_name}-season', fontweight='bold')
plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/PC_div_X_PC_dmt.png',
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\sean.kearney\.conda\envs\py_geo_env\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout(*args, **kwargs)

# %%
df_wkly_grid_full[(df_wkly_grid_full.Year == 2016)&
            (df_wkly_grid_full.season == 'mid') &
                  (df_wkly_grid_full.TPC_c == 'Flat Plains') &
                 (df_wkly_grid_full.PC_dmt == 'Other') &
                 (df_wkly_grid_full.mod_data == 'test')]['PC_div_orig'].describe()

# %%
df_wkly_grid_full.columns

# %%
df_wkly_grid_train['Pasture'].unique()

# %%
import xarray as xr
xr_dat_past = df_wkly_grid_train[df_wkly_grid_train['Pasture'] == '7NW'].set_index(['Year', 'week', 'UTM_Y', 'UTM_X']).to_xarray()

# %%
#df_wkly_grid_train_means[df_wkly_grid_train_means['Pasture'] == '7NW']['pred_seas_grp_val']#.value_counts()

# %%
pc_dmt_dict = {
    'C4': 1.0,
    'C3_C4_mix': 2.0,
    'C3': 3.0,
    'Saltgrass': 4.0,
    'Other': 5.0
}

tpc_dict = {
    'Highlands': 1.0,
    'Open Slopes': 2.0,
    'Flat Plains': 3.0,
    'Lowlands': 4.0,
    'Other': 5.0
}

pred_grps_dict = {
    'Low': 1,
    'Mod. Low': 2,
    'Avg.': 3,
    'Mod. Hi': 4,
    'Hi': 5
}


def convert_from_dict(x, set_dict):
    return set_dict[x] if x in set_dict else x
    
xr_dat_past['PC_dmt_val'] = xr.apply_ufunc(convert_from_dict, xr_dat_past['PC_dmt'],
                                           kwargs={'set_dict': pc_dmt_dict}, vectorize=True, dask='parallelized')
xr_dat_past['TPC_val'] = xr.apply_ufunc(convert_from_dict, xr_dat_past['TPC_c'],
                                           kwargs={'set_dict': tpc_dict}, vectorize=True, dask='parallelized')
xr_dat_past['pred_seas_grp_val'] = xr.apply_ufunc(convert_from_dict, xr_dat_past['pred_seas_grp'],
                                                   kwargs={'set_dict': pred_grps_dict}, vectorize=True, dask='parallelized')
#xr_dat_past['PC_div'] = xr_dat_past['PC_div'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_9220/2619229057.py in <module>
#      31 xr_dat_past['TPC_val'] = xr.apply_ufunc(convert_from_dict, xr_dat_past['TPC_c'],
#      32                                            kwargs={'set_dict': tpc_dict}, vectorize=True, dask='parallelized')
# ---> 33 xr_dat_past['pred_seas_grp_val'] = xr.apply_ufunc(convert_from_dict, xr_dat_past['pred_seas_grp'],
#      34                                                    kwargs={'set_dict': pred_grps_dict}, vectorize=True, dask='parallelized')
#      35 #xr_dat_past['PC_div'] = xr_dat_past['PC_div'].fillna(0)
#
# ~\.conda\envs\py_geo_env\lib\site-packages\xarray\core\computation.py in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, *args)
#    1169     # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1170     elif any(isinstance(a, DataArray) for a in args):
# -> 1171         return apply_dataarray_vfunc(
#    1172             variables_vfunc,
#    1173             *args,
#
# ~\.conda\envs\py_geo_env\lib\site-packages\xarray\core\computation.py in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     286
#     287     data_vars = [getattr(a, "variable", a) for a in args]
# --> 288     result_var = func(*data_vars)
#     289
#     290     if signature.num_outputs > 1:
#
# ~\.conda\envs\py_geo_env\lib\site-packages\xarray\core\computation.py in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     737             )
#     738
# --> 739     result_data = func(*input_data)
#     740
#     741     if signature.num_outputs == 1:
#
# ~\.conda\envs\py_geo_env\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# ~\.conda\envs\py_geo_env\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2247
#    2248             if ufunc.nout == 1:
# -> 2249                 res = asanyarray(outputs, dtype=otypes[0])
#    2250             else:
#    2251                 res = tuple([asanyarray(x, dtype=t)
#
# ValueError: cannot convert float NaN to integer

# %%
#xr_dat_early['grazing_rel_freq'].quantile(0.98)

# %%
from matplotlib.gridspec import GridSpec
from matplotlib import colors, cm
import matplotlib.patches as mpatches
from mpl_toolkits.axes_grid1 import make_axes_locatable

tpc_labels = ['Complex' if x == 'Other' else x for x in tpc_dict.keys()]

tpc_cmap = colors.ListedColormap(['orange', 'yellow', 'lightgreen', 'darkgreen', 'red'])
tpc_patches =[mpatches.Patch(color=c, label=list(tpc_labels)[i]) for i, c in enumerate(tpc_cmap.colors)]

pc_dmt_cmap = colors.ListedColormap(['blue', 'olive', 'darkorange', 'pink', 'grey'])
pc_patches =[mpatches.Patch(color=c, label=list(pc_dmt_dict.keys())[i]) for i, c in enumerate(pc_dmt_cmap.colors)]

rel_use_breaks = [0, 0.001, 0.5, 0.75, 0.9, 1.0, 1.25, 2.0, 3.0, 4.0, 1000]
rel_use_labels = ['None', 'V. low', 'Low', 'Mod. low', 'Avg.', 'Mod. hi', 'Hi', 'V. Hi', 'Ext. Hi']
rel_use_cmap = cm.get_cmap('Spectral_r', len(rel_use_breaks))
res_use_patches =[mpatches.Patch(color=rel_use_cmap(i), 
                                   label=rel_use_labels[i]) for i in np.arange(len(rel_use_labels))]
# Create the colormap
cmap_rel_use = colors.LinearSegmentedColormap.from_list(
            'Relative use', [rel_use_cmap(i) for i in np.arange(len(rel_use_labels))],
    N=len(rel_use_labels))
norm = colors.BoundaryNorm(rel_use_breaks, len(rel_use_breaks))


yr = 2016
xr_dat_early = xr_dat_past.sel(Year=yr, week=21)
xr_dat_mid = xr_dat_past.sel(Year=yr, week=27)
xr_dat_late = xr_dat_past.sel(Year=yr, week=33)

cax_fsize=8
cax_title_fsize=10
cax_pad=0.10

fig = plt.figure(figsize=(14, 10))

gs1 = GridSpec(1, 3, top=0.98, bottom=0.65, wspace=0.05)
ax1 = fig.add_subplot(gs1[0])
ax2 = fig.add_subplot(gs1[1])
ax3 = fig.add_subplot(gs1[2])
ax1.imshow(xr_dat_early['TPC_val'].sortby('UTM_Y', ascending=False).data, cmap=tpc_cmap)
ax1.legend(handles=tpc_patches, ncol=3, bbox_to_anchor=(0.5, 1.4), fontsize=8, 
           loc='upper center', frameon=False,
           title="$\\bf{Topographic\ Position\ Class}$", title_fontsize=10)
divider1 = make_axes_locatable(ax1)
cax1 = divider1.append_axes('top', size='10%', pad=cax_pad)
cax1.axes.set_visible(False)

ax2.imshow(xr_dat_early['PC_dmt_val'].sortby('UTM_Y', ascending=False).data, cmap=pc_dmt_cmap)
ax2.legend(handles=pc_patches, ncol=3, bbox_to_anchor=(0.5, 1.4), fontsize=8, 
           loc='upper center', frameon=False,
           title="$\\bf{Dominant\ Plant\ Community (PC)}$", title_fontsize=10)
divider2 = make_axes_locatable(ax2)
cax2 = divider2.append_axes('top', size='10%', pad=cax_pad)
cax2.axes.set_visible(False)

im3 = ax3.imshow(xr_dat_early['PC_div_orig'].sortby('UTM_Y', ascending=False).data, cmap='cividis', vmin=0.0, vmax=1.5)
divider3 = make_axes_locatable(ax3)
cax3 = divider3.append_axes('top', size='10%', pad=cax_pad)
cbar3 = fig.colorbar(im3, cax=cax3, orientation='horizontal')
cax3.xaxis.set_ticks_position('top')
cax3.set_title("$\\bf{PC\ Diversity\ (Shannon\ H)}$", fontsize=10)
cbar3.ax.tick_params(labelsize=8)

gs2 = GridSpec(3, 4, top=0.65, bottom=0.02, hspace=0.01)
ax4 = fig.add_subplot(gs2[0, 0])
ax5 = fig.add_subplot(gs2[0, 1])
ax6 = fig.add_subplot(gs2[0, 2])
ax7 = fig.add_subplot(gs2[0, 3])
im4 = ax4.imshow(xr_dat_early['Biomass_orig'].sortby('UTM_Y', ascending=False).data, cmap='magma', vmin=200, vmax=2500)
divider4 = make_axes_locatable(ax4)
cax4 = divider4.append_axes('top', size='10%', pad=cax_pad)
cbar4 = fig.colorbar(im4, cax=cax4, orientation='horizontal')
cax4.xaxis.set_ticks_position('top')
cax4.set_title("$\\bf{Biomass\ (kg/ha)}$", fontsize=10)
cbar4.ax.tick_params(labelsize=8)
#cax4left = divider4.append_axes('left', size='5%', pad=0.05)
#cax4left.yaxis.set_label("early-season")

im5 = ax5.imshow(xr_dat_early['CP_orig'].sortby('UTM_Y', ascending=False).data, cmap='viridis', vmin=6, vmax=12)
divider5 = make_axes_locatable(ax5)
cax5 = divider5.append_axes('top', size='10%', pad=cax_pad)
cbar5 = fig.colorbar(im5, cax=cax5, orientation='horizontal')
cax5.xaxis.set_ticks_position('top')
cax5.set_title("$\\bf{Crude\ Protein\ (\%)}$", fontsize=10)
cbar5.ax.tick_params(labelsize=8)

im6 = ax6.imshow(xr_dat_early['grazing_rel_freq'].sortby('UTM_Y', ascending=False).data, cmap='Spectral_r', vmin=0, vmax=4)
divider6 = make_axes_locatable(ax6)
cax6 = divider6.append_axes('top', size='10%', pad=cax_pad)
cbar6 = fig.colorbar(im6, cax=cax6, orientation='horizontal')
cax6.xaxis.set_ticks_position('top')
cax6.set_title("$\\bf{Relative\ use}$", fontsize=10)
cbar6.ax.tick_params(labelsize=8)

ax7.imshow(xr_dat_early['pred_seas_grp_val'].sortby('UTM_Y', ascending=False).data, cmap=pred_grps_cmap)
divider7 = make_axes_locatable(ax7)
cax7 = divider7.append_axes('top', size='10%', pad=cax_pad)
cax7.axes.set_visible(False)
ax7.legend(handles=pred_grps_patches, ncol=3, bbox_to_anchor=(0.5, 1.55), fontsize=8, 
           loc='upper center', frameon=False, title="$\\bf{Predicted\ use}$", title_fontsize=10)

ax8 = fig.add_subplot(gs2[1, 0])
ax9 = fig.add_subplot(gs2[1, 1])
ax10 = fig.add_subplot(gs2[1, 2])
ax11 = fig.add_subplot(gs2[1, 3])
ax8.imshow(xr_dat_mid['Biomass_orig'].sortby('UTM_Y', ascending=False).data, cmap='magma', vmin=200, vmax=2500)
ax9.imshow(xr_dat_mid['CP_orig'].sortby('UTM_Y', ascending=False).data, cmap='viridis', vmin=6, vmax=12)
ax10.imshow(xr_dat_mid['grazing_rel_freq'].sortby('UTM_Y', ascending=False).data, cmap='Spectral_r', vmin=0.0, vmax=4)
ax11.imshow(xr_dat_mid['pred_seas_grp_val'].sortby('UTM_Y', ascending=False).data, cmap=pred_grps_cmap)

ax12 = fig.add_subplot(gs2[2, 0])
ax13 = fig.add_subplot(gs2[2, 1])
ax14 = fig.add_subplot(gs2[2, 2])
ax15 = fig.add_subplot(gs2[2, 3])
ax12.imshow(xr_dat_late['Biomass_orig'].sortby('UTM_Y', ascending=False).data, cmap='magma', vmin=200, vmax=2500)
ax13.imshow(xr_dat_late['CP_orig'].sortby('UTM_Y', ascending=False).data, cmap='viridis', vmin=6, vmax=12)
ax14.imshow(xr_dat_late['grazing_rel_freq'].sortby('UTM_Y', ascending=False).data, cmap='Spectral_r', vmin=0.0, vmax=4)
ax15.imshow(xr_dat_late['pred_seas_grp_val'].sortby('UTM_Y', ascending=False).data, cmap=pred_grps_cmap)

for ax in [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15]:
    #ax.axis('off')
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    
ax4.set_ylabel("$\\bf{early{-}season}$" + "\n(week 21)", fontdict={'size': 12}, labelpad=15)
ax8.set_ylabel("$\\bf{mid{-}season}$" + "\n(week 27)", fontdict={'size': 12}, labelpad=15)
ax12.set_ylabel("$\\bf{late{-}season}$" + "\n(week 33)", fontdict={'size': 12}, labelpad=15)


plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/Pasture_example_' + str(yr) + '.png',
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_9220/290824820.py in <module>
#      94 cbar6.ax.tick_params(labelsize=8)
#      95
# ---> 96 ax7.imshow(xr_dat_early['pred_seas_grp_val'].sortby('UTM_Y', ascending=False).data, cmap=pred_grps_cmap)
#      97 divider7 = make_axes_locatable(ax7)
#      98 cax7 = divider7.append_axes('top', size='10%', pad=cax_pad)
#
# NameError: name 'pred_grps_cmap' is not defined

# %%
from matplotlib.gridspec import GridSpec
from matplotlib import colors, cm
import matplotlib.patches as mpatches
from mpl_toolkits.axes_grid1 import make_axes_locatable

tpc_labels = ['Complex' if x == 'Other' else x for x in tpc_dict.keys()]

tpc_cmap = colors.ListedColormap(['orange', 'yellow', 'lightgreen', 'darkgreen', 'red'])
tpc_patches =[mpatches.Patch(color=c, label=list(tpc_labels)[i]) for i, c in enumerate(tpc_cmap.colors)]

pc_dmt_cmap = colors.ListedColormap(['blue', 'olive', 'darkorange', 'pink', 'grey'])
pc_patches =[mpatches.Patch(color=c, label=list(pc_dmt_dict.keys())[i]) for i, c in enumerate(pc_dmt_cmap.colors)]

rel_use_breaks = [0, 0.001, 0.5, 0.75, 0.9, 1.0, 1.25, 2.5, 4.0, 1000]
rel_use_labels = ['None', '', 'Low', '', 'Avg.', '', 'Hi', '', 'V. Hi', '']
rel_use_cmap = cm.get_cmap('Spectral_r', len(rel_use_breaks))
res_use_patches =[mpatches.Patch(color=rel_use_cmap(i), 
                                   label=rel_use_labels[i]) for i in np.arange(len(rel_use_labels))]
# Create the colormap
cmap_rel_use = colors.LinearSegmentedColormap.from_list(
            'Relative use', [rel_use_cmap(i) for i in np.arange(len(rel_use_labels))],
    N=len(rel_use_labels))
norm_rel_use = colors.BoundaryNorm(rel_use_breaks, len(rel_use_breaks))

yr = 2017
xr_dat_early = xr_dat_past.sel(Year=yr, week=21)
xr_dat_mid = xr_dat_past.sel(Year=yr, week=27)
xr_dat_late = xr_dat_past.sel(Year=yr, week=33)

cax_fsize=8
cax_title_fsize=10
cax_pad=0.10

fig = plt.figure(figsize=(14, 10))

gs1 = GridSpec(1, 3, top=0.98, bottom=0.65, wspace=0.05)
ax1 = fig.add_subplot(gs1[0])
ax2 = fig.add_subplot(gs1[1])
ax3 = fig.add_subplot(gs1[2])
ax1.imshow(xr_dat_early['TPC_val'].sortby('UTM_Y', ascending=False).data, cmap=tpc_cmap)
ax1.legend(handles=tpc_patches, ncol=3, bbox_to_anchor=(0.5, 1.4), fontsize=8, 
           loc='upper center', frameon=False,
           title="$\\bf{Topographic\ Position\ Class}$", title_fontsize=10)
divider1 = make_axes_locatable(ax1)
cax1 = divider1.append_axes('top', size='10%', pad=cax_pad)
cax1.axes.set_visible(False)

ax2.imshow(xr_dat_early['PC_dmt_val'].sortby('UTM_Y', ascending=False).data, cmap=pc_dmt_cmap)
ax2.legend(handles=pc_patches, ncol=3, bbox_to_anchor=(0.5, 1.4), fontsize=8, 
           loc='upper center', frameon=False,
           title="$\\bf{Dominant\ Plant\ Community (PC)}$", title_fontsize=10)
divider2 = make_axes_locatable(ax2)
cax2 = divider2.append_axes('top', size='10%', pad=cax_pad)
cax2.axes.set_visible(False)

im3 = ax3.imshow(xr_dat_early['PC_div_orig'].sortby('UTM_Y', ascending=False).data, cmap='cividis', vmin=0.0, vmax=1.5)
divider3 = make_axes_locatable(ax3)
cax3 = divider3.append_axes('top', size='10%', pad=cax_pad)
cbar3 = fig.colorbar(im3, cax=cax3, orientation='horizontal')
cax3.xaxis.set_ticks_position('top')
cax3.set_title("$\\bf{PC\ Diversity\ (Shannon\ H)}$", fontsize=10)
cbar3.ax.tick_params(labelsize=8)

gs2 = GridSpec(3, 3, top=0.65, bottom=0.02, hspace=0.01)
ax4 = fig.add_subplot(gs2[0, 0])
ax5 = fig.add_subplot(gs2[0, 1])
ax6 = fig.add_subplot(gs2[0, 2])
im4 = ax4.imshow(xr_dat_early['Biomass_orig'].sortby('UTM_Y', ascending=False).data, cmap='magma', vmin=200, vmax=2500)
divider4 = make_axes_locatable(ax4)
cax4 = divider4.append_axes('top', size='10%', pad=cax_pad)
cbar4 = fig.colorbar(im4, cax=cax4, orientation='horizontal')
cax4.xaxis.set_ticks_position('top')
cax4.set_title("$\\bf{Biomass\ (kg/ha)}$", fontsize=10)
cbar4.ax.tick_params(labelsize=8)
#cax4left = divider4.append_axes('left', size='5%', pad=0.05)
#cax4left.yaxis.set_label("early-season")

im5 = ax5.imshow(xr_dat_early['CP_orig'].sortby('UTM_Y', ascending=False).data, cmap='viridis', vmin=6, vmax=12)
divider5 = make_axes_locatable(ax5)
cax5 = divider5.append_axes('top', size='10%', pad=cax_pad)
cbar5 = fig.colorbar(im5, cax=cax5, orientation='horizontal')
cax5.xaxis.set_ticks_position('top')
cax5.set_title("$\\bf{Crude\ Protein\ (\%)}$", fontsize=10)
cbar5.ax.tick_params(labelsize=8)

im6 = ax6.imshow(xr_dat_early['grazing_rel_freq'].sortby('UTM_Y', ascending=False).data, cmap=cmap_rel_use, norm=norm_rel_use)
divider6 = make_axes_locatable(ax6)
cax6 = divider6.append_axes('top', size='10%', pad=cax_pad)
cbar6 = fig.colorbar(im6, cax=cax6, orientation='horizontal')
cax6.xaxis.set_ticks_position('top')
cax6.set_title("$\\bf{Relative\ use}$", fontsize=10)
cbar6.ax.tick_params(labelsize=8)
cbar6.ax.set_xticklabels(rel_use_labels)

ax8 = fig.add_subplot(gs2[1, 0])
ax9 = fig.add_subplot(gs2[1, 1])
ax10 = fig.add_subplot(gs2[1, 2])
ax8.imshow(xr_dat_mid['Biomass_orig'].sortby('UTM_Y', ascending=False).data, cmap='magma', vmin=200, vmax=2500)
ax9.imshow(xr_dat_mid['CP_orig'].sortby('UTM_Y', ascending=False).data, cmap='viridis', vmin=6, vmax=12)
ax10.imshow(xr_dat_mid['grazing_rel_freq'].sortby('UTM_Y', ascending=False).data, cmap=cmap_rel_use, norm=norm_rel_use)

ax12 = fig.add_subplot(gs2[2, 0])
ax13 = fig.add_subplot(gs2[2, 1])
ax14 = fig.add_subplot(gs2[2, 2])
ax12.imshow(xr_dat_late['Biomass_orig'].sortby('UTM_Y', ascending=False).data, cmap='magma', vmin=200, vmax=2500)
ax13.imshow(xr_dat_late['CP_orig'].sortby('UTM_Y', ascending=False).data, cmap='viridis', vmin=6, vmax=12)
ax14.imshow(xr_dat_late['grazing_rel_freq'].sortby('UTM_Y', ascending=False).data, cmap=cmap_rel_use, norm=norm_rel_use)

for ax in [ax1, ax2, ax3, ax4, ax5, ax6, ax8, ax9, ax10, ax12, ax13, ax14]:
    #ax.axis('off')
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    
ax1.set_ylabel("$\\bf{static}$", fontdict={'size': 12}, labelpad=15)
ax4.set_ylabel("$\\bf{early{-}season}$" + "\n(week 21)", fontdict={'size': 12}, labelpad=15)
ax8.set_ylabel("$\\bf{mid{-}season}$" + "\n(week 27)", fontdict={'size': 12}, labelpad=15)
ax12.set_ylabel("$\\bf{late{-}season}$" + "\n(week 33)", fontdict={'size': 12}, labelpad=15)


plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/Pasture_example_' + str(yr) + '_no_pred.png',
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
xr_dat_early['Biomass_orig'].isel(dict(UTM_X=10, UTM_Y=15))['UTM_X']
# Out:
# <xarray.DataArray 'UTM_X' ()>
# array(525945.)
# Coordinates:
#     Year     int64 2018
#     week     int64 21
#     UTM_Y    float64 4.521e+06
#     UTM_X    float64 5.259e+05

# %%
'te' in 'test'
# Out:
# True

# %%
"""
Compare models by season: how does selection change with distance to fence and watertank
"""
ref_TPC = 'Flat Plains'
ref_pc = 'C3_C4_mix'
df_pred = pd.DataFrame(columns=['season','dFence_orig', 'dTank_orig', 'Biomass_orig', 'CP_orig','PC_div_orig',
                                'PC_dmt', 'TPC_c', 'Feature', 'Model'])
for mod in tqdm(['M1', 'M_best']):
    for seas, df_sub in df_wkly_grid_full[df_wkly_grid_full['mod_data'] == 'train'].groupby('season'):
        if len(df_sub[(df_sub['PC_dmt'] == ref_pc) & (df_sub['TPC_c'] == ref_TPC)]) < 100:
            continue
        else:
            df_tmp = df_sub[(df_sub['TPC_c'] == ref_TPC) & (df_sub['PC_dmt'] == ref_pc)]
            for feat in ['Fence', 'Tank']:
                if feat == 'Fence':
                    dFence = np.arange(df_tmp['dFence_orig'].min(), df_tmp['dFence_orig'].max(), 10)
                else:
                    dFence = df_tmp['dFence_orig'].median()
                if feat == 'Tank':
                    dTank = np.arange(df_tmp['dTank_orig'].min(), df_tmp['dTank_orig'].max(), 10)
                else:
                    dTank = df_tmp['dTank_orig'].median()
                    
                df_pred = df_pred.append(pd.DataFrame({
                    'season': seas,
                    'dFence_orig': dFence,
                    'dTank_orig': dTank,
                    'Biomass_orig': df_tmp['Biomass_orig'].median(),
                    'CP_orig': df_tmp['CP_orig'].median(),
                    'PC_div_orig': df_tmp['PC_div_orig'].median(),
                    'PC_dmt': ref_pc,
                    'TPC_c': ref_TPC,
                    'Feature': feat,
                    'Model': mod
                }))
        for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
            scaler = scaler_dict[seas][c]
            df_pred.loc[df_pred['season'] == seas, c] = scaler.transform(
                df_pred.loc[df_pred['season'] == seas, c + '_orig'].values.reshape(-1, 1)).flatten()
        df_pred.loc[(df_pred['season'] == seas) & (df_pred['Model'] == mod), 
                    'mod_pred'] = seas_mod_dict[seas][mod].predict(df_pred.loc[(df_pred['season'] == seas) & (df_pred['Model'] == mod)])
df_pred['season'] = pd.Categorical(df_pred['season'], ['early', 'mid', 'late'])
df_pred['pred_rel_freq'] = np.nan
for seas in df_pred.season.unique():
    df_wkly_grid_sub = df_wkly_grid_full[(df_wkly_grid_full['season'] == seas) & (df_wkly_grid_full['mod_data'] == 'train')]
    df_pred.loc[df_pred['season'] == seas, 'pred_rel_freq'] = (df_pred.loc[df_pred['season'] == seas, 'mod_pred'] * df_wkly_grid_sub['grazing_wkly_sum'].mean()) / (df_wkly_grid_sub['grazing_wkly_sum'].mean() / df_wkly_grid_sub.groupby(
        ['week', 'Pasture', 'Steer_ID'])['grazing_wkly_sum'].count().mean())
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_29540/761240472.py in <module>
#      35                 }))
#      36         for c in ['dFence', 'dTank', 'Biomass', 'CP', 'PC_div']:
# ---> 37             scaler = scaler_dict[seas][c]
#      38             df_pred.loc[df_pred['season'] == seas, c] = scaler.transform(
#      39                 df_pred.loc[df_pred['season'] == seas, c + '_orig'].values.reshape(-1, 1)).flatten()
#
# KeyError: 'early'

# %%
df_pred['dFence_orig'][df_pred['Feature'] == 'Tank'] = np.nan
df_pred['dTank_orig'][df_pred['Feature'] == 'Fence'] = np.nan
df_pred_long = pd.melt(df_pred, id_vars=['season', 'Model', 'Feature', 'pred_rel_freq'], value_vars=['dFence_orig', 'dTank_orig'], value_name='Distance')
# Out:
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_6360/1498154917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred['dFence_orig'][df_pred['Feature'] == 'Tank'] = np.nan
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_6360/1498154917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred['dTank_orig'][df_pred['Feature'] == 'Fence'] = np.nan

# %%
"""
Plot marginal effects of distance to fence by model and season
"""
x_var = 'Distance'
g = sns.FacetGrid(df_pred_long[(df_pred_long['Model'].isin(['M1', 'M_best'])) & (df_pred_long['Feature'] == 'Fence')],
                  col='season', hue='Model',
                               col_order=['early', 'mid', 'late'], 
                  legend_out=True, sharey='col', sharex=True)
#plt.figure()
g.map_dataframe(sns.lineplot, x=x_var, y='pred_rel_freq').add_legend(bbox_to_anchor=(0.5, 0.98), 
                                                                     loc='upper center',
                                                                                                   borderaxespad=0, 
                                                                                                   ncol=2, 
                                                                                                   frameon=True)
g.set_xlabels('Distance to nearest fence (m)')
g.set_ylabels('Relative probability of selection')
axes = g.fig.axes
for ax in axes:
    ax.axhline(y=1.0, linestyle='dashed', color='grey')
    ax.set_ylim((0.0, ax.get_ylim()[-1]))
    if ax.get_ylim()[-1] < 2.0:
        ax.set_ylim((0.0, 2.0))
    cur_title = ax.get_title()
    ax.set_title(re.sub('season = ', '', cur_title + '-season'))
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width, box.height*0.8])
leg = g.legend
# change legend texts
new_title = 'Model type'
leg.set_title(new_title, prop={'weight': 'bold',
        'size': 12,
        })
new_labels = ['Null model (M0)', 'Fully paramaterized (M5)']
for t, l in zip(leg.texts, new_labels):
    t.set_text(l)
plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/dfence.png', 
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
Plot marginal effects of distance to water tank by model and season
"""
x_var = 'Distance'
g = sns.FacetGrid(df_pred_long[(df_pred_long['Model'].isin(['M1', 'M_best'])) & (df_pred_long['Feature'] == 'Tank')],
                  col='season', hue='Model',
                               col_order=['early', 'mid', 'late'], 
                  legend_out=True, sharey='col', sharex=True)
#plt.figure()
g.map_dataframe(sns.lineplot, x=x_var, y='pred_rel_freq').add_legend(bbox_to_anchor=(0.5, 0.98), 
                                                                     loc='upper center',
                                                                                                   borderaxespad=0, 
                                                                                                   ncol=2, 
                                                                                                   frameon=True)
g.set_xlabels('Distance to water tank (m)')
g.set_ylabels('Relative probability of selection')
axes = g.fig.axes
for ax in axes:
    ax.axhline(y=1.0, linestyle='dashed', color='grey')
    ax.set_ylim((0.0, ax.get_ylim()[-1]))
    if ax.get_ylim()[-1] < 2.0:
        ax.set_ylim((0.0, 2.0))
    cur_title = ax.get_title()
    ax.set_title(re.sub('season = ', '', cur_title + '-season'))
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width, box.height*0.8])
leg = g.legend
# change legend texts
new_title = 'Model type'
leg.set_title(new_title, prop={'weight': 'bold',
        'size': 12,
        })
new_labels = ['Null model (M0)', 'Fully paramaterized (M5)']
for t, l in zip(leg.texts, new_labels):
    t.set_text(l)
plt.savefig('C:/Users/sean.kearney/OneDrive - USDA/Documents/Projects/GPS_v_hetgen/figures/dtank.png', 
            bbox_inches='tight', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
sns.kdeplot(x='grazing_rel_freq', hue='season', 
            data=df_wkly_grid_train, bw_adjust=2.0, clip=(0, None),
           common_norm=False, cumulative=False, common_grid=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='grazing_rel_freq', ylabel='Density'>

# %%
df_wkly_grid_train['grazing_rel_freq_seas'] = (df_wkly_grid_train.groupby(['season', 'Pasture', 'Steer_ID', 'UTM_X', 'UTM_Y']).grazing_secs.transform('sum') /\
(df_wkly_grid_train.groupby(['season', 'Pasture', 'Steer_ID', 'UTM_X', 'UTM_Y']).grazing_wkly_sum.transform('sum') /\
 df_wkly_grid_train.groupby(['week', 'season', 'Pasture', 'Steer_ID']).grazing_secs.transform(lambda x: np.mean(len(x))))).reset_index(drop=True)

# %%
#df_wkly_grid_train[df_wkly_grid_train['mod_data'] == 'train']

# %%
#df_wkly_grid_train[(df_wkly_grid_train.Pasture == '7NW') &
#                 (df_wkly_grid_train.UTM_X == 524055.0) & 
#                 (df_wkly_grid_train.UTM_Y == 4522695.0) &
                  #(df_wkly_grid_train.Steer_ID == '2287_D1_2017') & 
#                 (df_wkly_grid_train.mod_data == 'train')].sort_values('Steer_ID')

# %%
df_wkly_grid_train['grazing_rel_freq_seas_grp'] = pd.cut(df_wkly_grid_train.groupby(['season', 'Pasture', 'UTM_X', 'UTM_Y'])['grazing_rel_freq_seas'].transform('mean'), 
                                          bins=rel_freq_bins, 
                                          labels=bin_labs,
                                          include_lowest=True)
df_wkly_grid_train['grazing_rel_freq_past_grp'] = pd.cut(df_wkly_grid_train.groupby(['week', 'Pasture', 'UTM_X', 'UTM_Y'])['grazing_rel_freq'].transform('mean'), 
                                          bins=rel_freq_bins, 
                                          labels=bin_labs,
                                          include_lowest=True)

# %%
df_wkly_grid_train.groupby('season')['grazing_secs'].apply(lambda x: np.sum(np.isnan(x)))
# Out:
# season
# early    1
# mid      0
# late     0
# Name: grazing_secs, dtype: int64

# %%
df_seas_grid = df_wkly_grid_train.groupby(['season', 'mod_data', 'Pasture',
                           'UTM_X', 'UTM_Y'])[['grazing_rel_freq_seas', 
                                                           'grazing_rel_freq_seas_grp',
                                                           'Biomass_orig',
                                                           'CP_orig', 
                                                           'PC_dmt', 
                                                           'PC_div_orig']].aggregate(func={
    'grazing_rel_freq_seas': 'last',
    'grazing_rel_freq_seas_grp': 'last',
    'Biomass_orig': np.mean,
    'CP_orig': np.mean,
    'PC_dmt': 'last',
    'PC_div_orig': 'last'
}).reset_index()
    #['mod_data', 'Pasture', 'Steer_ID', 'UTM_X', 'UTM_Y'])['grazing_rel_freq_wkly_grp'].transform(lambda x: '_'.join(x.astype('str')))

# %%
df_seas_grid['grazing_rel_freq_seas_grp'].dropna()
# Out:
# 691397      Low
# 691398      Low
# 691399      Low
# 691400     Avg.
# 691401      Low
#            ...
# 4128583    Avg.
# 4128584      Hi
# 4128585      Hi
# 4128586      Hi
# 4128904      Hi
# Name: grazing_rel_freq_seas_grp, Length: 25953, dtype: category
# Categories (5, object): ['Low' < 'Mod. Low' < 'Avg.' < 'Mod. Hi' < 'Hi']

# %%
df_seas_grid = df_seas_grid[df_seas_grid['mod_data'] == 'train']
df_seas_grid['grazing_rel_freq_seas_traj'] = df_seas_grid.groupby(['mod_data', 'Pasture', 
                      'UTM_X', 'UTM_Y'])['grazing_rel_freq_seas_grp'].transform('_'.join)
df_seas_grid['season'] = pd.Categorical(df_seas_grid['season'], ['early', 'mid', 'late'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_6360/3190138036.py in <module>
#       1 df_seas_grid = df_seas_grid[df_seas_grid['mod_data'] == 'train']
# ----> 2 df_seas_grid['grazing_rel_freq_seas_traj'] = df_seas_grid.groupby(['mod_data', 'Pasture',
#       3                       'UTM_X', 'UTM_Y'])['grazing_rel_freq_seas_grp'].transform('_'.join)
#       4 df_seas_grid['season'] = pd.Categorical(df_seas_grid['season'], ['early', 'mid', 'late'])
#
# ~\.conda\envs\py_geo_env\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     503     @Appender(_transform_template)
#     504     def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 505         return self._transform(
#     506             func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     507         )
#
# ~\.conda\envs\py_geo_env\lib\site-packages\pandas\core\groupby\groupby.py in _transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1422
#    1423         if not isinstance(func, str):
# -> 1424             return self._transform_general(func, *args, **kwargs)
#    1425
#    1426         elif func not in base.transform_kernel_allowlist:
#
# ~\.conda\envs\py_geo_env\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     534             # this setattr is needed for test_transform_lambda_with_datetimetz
#     535             object.__setattr__(group, "name", name)
# --> 536             res = func(group, *args, **kwargs)
#     537
#     538             results.append(klass(res, index=group.index))
#
# TypeError: sequence item 0: expected str instance, float found

# %%
plt.figure()
sns.pointplot(x='season', y='Biomass', hue='grazing_rel_freq_seas_traj', 
            data=df_seas_grid[df_seas_grid['grazing_rel_freq_seas_traj'].isin(['Low_Low_Low',
                                                                               'Hi_Hi_Hi'])])
# Out:
# C:\Users\SEAN~1.KEA\AppData\Local\Temp/ipykernel_96040/2580292971.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='season', ylabel='Biomass'>

# %%
plt.figure()
sns.pointplot(x='season', y='PC_div', hue='grazing_rel_freq_seas_traj', 
            data=df_seas_grid[df_seas_grid['grazing_rel_freq_seas_traj'].isin(['Low_Low_Low',
                                                                               'Hi_Hi_Hi'])])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='season', ylabel='PC_div'>

# %%
df_seas_grid['grazing_rel_freq_seas_traj'][df_seas_grid['season'] == 'late'].value_counts()
# Out:
# Low_Low_Low                 733
# Hi_Hi_Hi                    296
# Mod. Low_Low_Low            276
# Low_Mod. Low_Low            245
# Low_Low_Mod. Low            171
#                            ...
# Mod. Hi_Mod. Hi_Mod. Hi      15
# Mod. Hi_Mod. Hi_Mod. Low     13
# Mod. Low_Mod. Hi_Mod. Hi     12
# Mod. Hi_Mod. Low_Mod. Hi     11
# Low_Mod. Hi_Mod. Hi           8
# Name: grazing_rel_freq_seas_traj, Length: 125, dtype: int64

# %%
#plt.figure()
df_plot = df_wkly_grid_train[df_wkly_grid_train['mod_data'] == 'train'].groupby(
    ['season', 'week', 'Pasture', 'Steer_ID'])['grazing_rel_freq_seas_grp'].value_counts().reset_index().groupby(
    ['season', 'Pasture', 'level_4']).mean().reset_index().pivot(columns='level_4',
                                                               index=['season', 'Pasture'], values='grazing_rel_freq_seas_grp').reset_index()#.plot(kind='bar', stacked=True)
df_plot['pct_Hi'] = df_plot[['Hi']].sum(axis=1) / df_plot[['Low', 'Mod. Low', 'Avg.', 
                                                  'Mod. Hi', 'Hi']].sum(axis=1)
df_plot['season'] = pd.Categorical(df_plot['season'], ['early', 'mid', 'late'])
#df_plot
plt.figure()
sns.pointplot(x='season', y='pct_Hi', hue='Pasture', data=df_plot)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='season', ylabel='pct_Hi'>

# %%
df_wkly_grid_train[df_wkly_grid_train['mod_data'] == 'train'].pivot(index=['Pasture', 'UTM_X', 'UTM_Y'])
# Out:
# level_4 season Pasture         Low    Mod. Low        Avg.     Mod. Hi  \
# 0        early     15E  524.833333  253.000000  208.666667  122.166667
# 1        early     17N  393.833333  342.000000  261.000000   97.666667
# 2        early    20SE  422.000000  294.000000  315.333333  119.666667
# 3        early     26E  415.333333  313.000000  272.000000  125.333333
# 4        early     31E  402.666667  355.333333  360.666667  179.333333
# 5        early     7NW  392.833333  318.000000  270.500000  140.833333
# 6         late     15E  354.250000  246.250000  368.500000  166.750000
# 7         late     17N  486.750000  249.750000  266.000000   97.250000
# 8         late    20SE  424.750000  291.250000  287.250000  141.250000
# 9         late     26E  450.500000  251.500000  264.000000  116.500000
# 10        late     31E  426.500000  345.000000  372.000000  172.000000
# 11        late     7NW  373.000000  292.000000  301.000000  150.666667
# 12         mid     15E  499.833333  256.500000  231.000000  127.666667
# 13         mid     17N  446.750000  263.000000  269.250000  110.250000
# 14         mid    20SE  365.666667  310.000000  338.666667  137.333333
# 15         mid     26E  449.000000  249.000000  269.666667  114.000000
# 16         mid     31E  425.666667  331.000000  373.333333  169.000000
# 17         mid     7NW  504.333333  192.000000  246.666667  118.333333
#
# level_4          Hi    pct_Hi
# 0        318.833333  0.223351
# 1        288.333333  0.208509
# 2        269.000000  0.189437
# 3        249.333333  0.181333
# 4        323.666667  0.199589
# 5        264.500000  0.190745
# 6        295.000000  0.206186
# 7        283.000000  0.204665
# 8        276.250000  0.194440
# 9        295.000000  0.214156
# 10       309.000000  0.190212
# 11       271.000000  0.195292
# 12       314.500000  0.220007
# 13       292.000000  0.211403
# 14       264.666667  0.186867
# 15       294.666667  0.214095
# 16       323.333333  0.199301
# 17       325.000000  0.234431

# %%
#plt.figure()
df_plot = df_wkly_grid_train[df_wkly_grid_train['mod_data'] == 'train'].groupby(
    ['season', 'week', 'Pasture', 'Steer_ID'])['grazing_rel_freq_seas_grp'].value_counts().reset_index().groupby(
    ['season', 'Pasture', 'level_4']).mean().reset_index().pivot(columns='level_4',
                                                               index=['season', 'Pasture'], values='grazing_rel_freq_seas_grp').reset_index()#.plot(kind='bar', stacked=True)
df_plot['pct_Hi'] = df_plot[['Hi']].sum(axis=1) / df_plot[['Low', 'Mod. Low', 'Avg.', 
                                                  'Mod. Hi', 'Hi']].sum(axis=1)
df_plot['season'] = pd.Categorical(df_plot['season'], ['early', 'mid', 'late'])
#df_plot
plt.figure()
sns.pointplot(x='season', y='pct_Hi', hue='Pasture', data=df_plot)

# %%
"""
Save data to make Sankey diagrams in R
"""
df_sankey = pd.DataFrame(columns=['class_early', 'class_mid', 'class_late', 'value'])
df_sankey['class_early'] = df_seas_grid[df_seas_grid['season'] == 'early']['grazing_rel_freq_seas_grp'].reset_index(drop=True)
df_sankey['class_mid'] = df_seas_grid[df_seas_grid['season'] == 'mid']['grazing_rel_freq_seas_grp'].reset_index(drop=True)
df_sankey['class_late'] = df_seas_grid[df_seas_grid['season'] == 'late']['grazing_rel_freq_seas_grp'].reset_index(drop=True)
df_sankey['value'] = 1
sankey_grp = df_sankey.groupby(['class_early', 'class_mid', 'class_late']).sum().reset_index(drop=False)
sankey_grp = sankey_grp.reindex(columns=sankey_grp.columns.tolist())
sankey_grp.to_csv('C:/SPK_local/zTEMP/gps_grid_sankey2.csv')

# %%
aicw_func = lambda x: np.exp(-0.5 * (x - x.min())) / np.sum(np.exp(-0.5 * (x - x.min())))
aicd_func = lambda x: x - x.min()

# %%
"""
Analyze best results for specific model comparisons defined in dictionary above
"""
for k in mod_aic_dict:
    df_results.loc[df_results['model'].isin(mod_aic_dict[k]), 
                   'AICw_' + k] = df_results.loc[df_results['model'].isin(mod_aic_dict[k])].groupby(
        ['week', 'Pasture'])['AIC'].transform(aicw_func)
    df_results.loc[df_results['model'].isin(mod_aic_dict[k]), 
                   'AICd_' + k] = df_results.loc[df_results['model'].isin(mod_aic_dict[k])].groupby(
        ['week', 'Pasture'])['AIC'].transform(aicd_func)
    df_results['top_model_' + k] = df_results.groupby(['week', 'Pasture'])['AICw_' + k].transform(
        lambda x: [int(i) for i in x == x.max()])
    df_results['candidate_model_' + k] = df_results.groupby(['week', 'Pasture'])['AICd_' + k].transform(
        lambda x: [int(i) for i in x <= 2.0])

# %%
"""
Display the results for the desired model comparison
"""
mod_grp = 'Hw2'
display(df_results.loc[df_results['model'].isin(mod_aic_dict[mod_grp])].groupby(['season', 'model'])[['top_model_' + mod_grp, 'candidate_model_' + mod_grp,
                                                                                'AICw_' + mod_grp, 'AICd_' + mod_grp]].aggregate(
    func={'AICd_' + mod_grp: [np.median, np.std], 'AICw_' + mod_grp: [np.mean, np.std], 
         'top_model_' + mod_grp: np.sum, 'candidate_model_' + mod_grp: np.sum}, axis=1).sort_values(['season', ('AICd_' + mod_grp, 'median')]))
display(df_results.loc[df_results['model'].isin(mod_aic_dict[mod_grp])].groupby(['model'])[['top_model_' + mod_grp, 'candidate_model_' + mod_grp, 
                                                                      'AICw_' + mod_grp, 'AICd_' + mod_grp]].aggregate(
    func={'AICd_' + mod_grp: [np.median, np.std], 'AICw_' + mod_grp: [np.mean, np.std], 
          'top_model_' + mod_grp: np.sum, 'candidate_model_' + mod_grp: np.sum}, axis=1).sort_values(('AICd_' + mod_grp, 'median')))
# Out:
#              AICd_Hw2                  AICw_Hw2           top_model_Hw2  \
#                median         std          mean       std           sum
# season model
# early  M2g      0.275    1.081198  5.061748e-01  0.296941             9
#        M2f      3.650   15.116630  2.215112e-01  0.240397             4
#        M2e      6.540   15.016862  1.527321e-01  0.249046             3
#        M2d     19.350   53.099368  3.105445e-02  0.063824             0
#        M2b     28.545   41.595856  4.482712e-02  0.091801             1
#        M2a     46.480   59.347148  2.105054e-02  0.066307             0
#        M2c     55.240   83.766058  2.264990e-02  0.095805             1
# late   M2g      0.000    1.393833  5.669245e-01  0.357838             7
#        M2f      3.970   13.607834  1.704526e-01  0.196187             2
#        M2e     17.635   17.977953  1.075712e-01  0.192545             1
#        M2d     22.035   29.178889  6.553204e-02  0.153503             1
#        M2b     28.425   32.462956  8.392830e-02  0.201161             1
#        M2c     34.785  163.188775  6.374583e-04  0.001683             0
#        M2a     48.850   38.307737  4.953916e-03  0.011591             0
# mid    M2g      0.000    1.147310  6.540285e-01  0.360957            12
#        M2f     10.395   34.692182  1.217726e-01  0.168370             2
#        M2e     16.580   29.966809  1.357531e-01  0.215604             2
#        M2d     35.230   36.685161  5.904228e-02  0.134963             1
#        M2b     90.820  106.598850  2.932907e-02  0.123558             1
#        M2a    105.395  110.054974  7.381332e-05  0.000313             0
#        M2c    160.450  114.654101  5.493250e-07  0.000002             0
#
#              candidate_model_Hw2
#                              sum
# season model
# early  M2g                    16
#        M2f                     8
#        M2e                     5
#        M2d                     3
#        M2b                     2
#        M2a                     1
#        M2c                     1
# late   M2g                    10
#        M2f                     5
#        M2e                     3
#        M2d                     2
#        M2b                     2
#        M2c                     0
#        M2a                     0
# mid    M2g                    16
#        M2f                     6
#        M2e                     5
#        M2d                     2
#        M2b                     1
#        M2a                     0
#        M2c                     0
#       AICd_Hw2              AICw_Hw2           top_model_Hw2  \
#         median         std      mean       std           sum
# model
# M2g      0.000    1.166435  0.576807  0.336463            28
# M2f      4.550   25.114508  0.171345  0.205110             8
# M2e     13.790   22.678330  0.135075  0.219630             6
# M2d     20.395   41.549821  0.050169  0.117503             2
# M2b     38.480   83.472705  0.048791  0.136041             3
# M2a     71.340   89.428555  0.009160  0.041377             0
# M2c     87.710  120.894697  0.008653  0.058657             1
#
#       candidate_model_Hw2
#                       sum
# model
# M2g                    42
# M2f                    19
# M2e                    13
# M2d                     7
# M2b                     5
# M2a                     1
# M2c                     1
